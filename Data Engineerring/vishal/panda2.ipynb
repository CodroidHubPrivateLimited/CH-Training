# %%
import pandas as pd

# %% [markdown]
# #### There are two keys data structure in the pandas library
# #### series(1 Dimenstial)
# #### DataFrame(2 Dimenstial)

# %%
s=pd.Series([1,2,3,4,5],index=['a','b','c','d','e'])
print(s)
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
df=pd.DataFrame({"names":["vishal","nishant","rohan","subham"],"marks":[100,53,78,90]})

# %%
df
# Out:
#      names  marks
# 0   vishal    100
# 1  nishant     53
# 2    rohan     78
# 3   subham     90

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   names   4 non-null      object
#  1   marks   4 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 196.0+ bytes

# %%
df.describe()
# Out:
#            marks
# count    4.00000
# mean    80.25000
# std     20.27108
# min     53.00000
# 25%     71.75000
# 50%     84.00000
# 75%     92.50000
# max    100.00000

# %%
df.tail()
# Out:
#      names  marks
# 0   vishal    100
# 1  nishant     53
# 2    rohan     78
# 3   subham     90

# %%
#data slection

# %%
type(df["names"])
# Out:
# pandas.core.series.Series

# %%
df
# Out:
#      names  marks
# 0   vishal    100
# 1  nishant     53
# 2    rohan     78
# 3   subham     90

# %%
df.iloc[0]
# Out:
# names    vishal
# marks       100
# Name: 0, dtype: object

# %%
type(df["names"])
# Out:
# pandas.core.series.Series

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   names   4 non-null      object
#  1   marks   4 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 196.0+ bytes

# %%
df['names']=df['names'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   names   4 non-null      category
#  1   marks   4 non-null      int64
# dtypes: category(1), int64(1)
# memory usage: 372.0 bytes

# %%
df["names"][0]
# Out:
# 'vishal'

# %%
type(df["names"])
# Out:
# pandas.core.series.Series

# %%
print(df["names"].cat.categories)
# Out:
# Index(['nishant', 'rohan', 'subham', 'vishal'], dtype='object')

# %%
print(pd.__version__)
# Out:
# 2.3.1

# %%
len(df)
# Out:
# 4

# %%
df["zero"]=[0 for i in range(len(df))]

# %%
df
# Out:
#      names  marks  zero
# 0   vishal    100     0
# 1  nishant     53     0
# 2    rohan     78     0
# 3   subham     90     0

# %%
def fx(a):
    return a+1
df["zero+1"]=df["zero"].apply(fx)

# %%
df
# Out:
#      names  marks  zero  zero+1
# 0   vishal    100     0       1
# 1  nishant     53     0       1
# 2    rohan     78     0       1
# 3   subham     90     0       1

# %%
df1=pd.DataFrame({"name":["harry","rohan","subham","shivam","divya","aperna","khushi"]
                  ,"marks":[100,53,45,3,100,95,3]})

# %%
df1
# Out:
#      name  marks
# 0   harry    100
# 1   rohan     53
# 2  subham     45
# 3  shivam      3
# 4   divya    100
# 5  aperna     95
# 6  khushi      3

# %%
df2=pd.DataFrame({"name":["akash","vishal","rukmani","rahul","abhi","kartik","keshav"]
                  ,"marks":[13,58,44,35,10,96,25]})

# %%
df2
# Out:
#       name  marks
# 0    akash     13
# 1   vishal     58
# 2  rukmani     44
# 3    rahul     35
# 4     abhi     10
# 5   kartik     96
# 6   keshav     25

# %%
pd.concat([df1,df2])
# Out:
#       name  marks
# 0    harry    100
# 1    rohan     53
# 2   subham     45
# 3   shivam      3
# 4    divya    100
# 5   aperna     95
# 6   khushi      3
# 0    akash     13
# 1   vishal     58
# 2  rukmani     44
# 3    rahul     35
# 4     abhi     10
# 5   kartik     96
# 6   keshav     25

# %%
df1=pd.DataFrame({"name":["akash","priyanka"],"marks":[13,58]})

# %%
df2=pd.DataFrame({"name":["akash","priyanka"],"roll":[1244,1245]})

# %%
pd.merge(df1,df2,on="name")
# Out:
#        name  marks  roll
# 0     akash     13  1244
# 1  priyanka     58  1245

# %%
pd.merge(df1,df2,on="name",how="outer")
# Out:
#        name  marks  roll
# 0     akash     13  1244
# 1  priyanka     58  1245

# %%
# !pip install selenium # use for scraping data from website
# Out:
# ...
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.6 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.6 MB 2.6 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.3/9.6 MB 2.8 MB/s eta 0:00:03
#    -------- ------------------------------- 2.1/9.6 MB 2.9 MB/s eta 0:00:03
#    ------------ --------------------------- 2.9/9.6 MB 3.1 MB/s eta 0:00:03
#    --------------- ------------------------ 3.7/9.6 MB 3.3 MB/s eta 0:00:02
#    ------------------- -------------------- 4.7/9.6 MB 3.6 MB/s eta 0:00:02
#    ------------------------ --------------- 5.8/9.6 MB 3.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.1/9.6 MB 4.1 MB/s eta 0:00:01
#    ------------------------------------ --- 8.7/9.6 MB 4.5 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.6 MB 4.5 MB/s eta 0:00:01
#    ---------------------------------------- 9.6/9.6 MB 4.5 MB/s  0:00:02
# ...
#
# ...

# %%
# !pip install webdriver-manager # use for managing the web driver for selenium, it automatically downloads and sets up the web driver for you, so you don't have to manually download and configure it.
# Out:
# ...
#
#    -------------------- ------------------- 1/2 [webdriver-manager]
#    -------------------- ------------------- 1/2 [webdriver-manager]
#    ---------------------------------------- 2/2 [webdriver-manager]
#
# ...
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
#start browser
driver=webdriver.Chrome(service=Service(ChromeDriverManager().install()))

# %% [markdown]
# <div style="text-align: center; padding: 20px;">
#     <h1>Alex Johnson</h1>
#     <h2>Exploratory Data Analysis on Sales Data</h2>
#     <p style="font-size: 16px; max-width: 700px; margin: auto;">
#         This notebook explores historical sales data to uncover trends, patterns,
#         and actionable insights using Python and data visualization techniques.
#     </p>
#     <hr style="width: 60%;">
# </div>
