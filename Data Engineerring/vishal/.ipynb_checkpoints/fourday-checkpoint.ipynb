# %%
import pyjokes
import pyttsx3
engine=pyttsx3.init()
engine.say("Ram ram  ke haal hai vishal ji")
engine.runAndWait()

print("printing a jokes for you")
joks=pyjokes.get_joke()
print(joks)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pyjokes
#       2 import pyttsx3
#       3 engine=pyttsx3.init()
#
# ModuleNotFoundError: No module named 'pyjokes'

# %%
pip install pyjokes
# Out:
# ...
#
#   Using cached pyjokes-0.8.3-py3-none-any.whl.metadata (3.4 kB)
# Using cached pyjokes-0.8.3-py3-none-any.whl (47 kB)
# ...

# %%
import pyjokes
import pyttsx3
engine=pyttsx3.init()
engine.say("Ram ram  ke haal hai vishal ji")
engine.runAndWait()

print("printing a jokes for you")
joks=pyjokes.get_joke()
print(joks)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 2
#       1 import pyjokes
# ----> 2 import pyttsx3
#       3 engine=pyttsx3.init()
#       4 engine.say("Ram ram  ke haal hai vishal ji")
#
# ModuleNotFoundError: No module named 'pyttsx3'

# %%
pip install pyttsx3
# Out:
# ...
#   Using cached pypiwin32-223-py3-none-any.whl.metadata (236 bytes)
# ...
# Using cached pypiwin32-223-py3-none-any.whl (1.7 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyjokes
import pyttsx3
engine=pyttsx3.init()
engine.say("Ram ram  ke haal hai vishal ji")
engine.runAndWait()

print("printing a jokes for you")
joks=pyjokes.get_joke()
print(joks)
# Out:
# printing a jokes for you
# The program is absolutely right; therefore the computer must be wrong.

# %%
import pyjokes
import pyttsx3
engine=pyttsx3.init()
engine.say("Ram ram  ke haal hai vishal ji")
engine.runAndWait()

print("printing a jokes for you")
joks=pyjokes.get_joke()
print(joks)
# Out:
# printing a jokes for you
# If Ruby is not and Perl is the answer, you don't understand the question.

# %%
 name="vishal"
print(name[-5:-1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 2
#       1 name="vishal"
# ----> 2 print(name[-5:-1])
#
# TypeError: 'str' object is not callable

# %%
print(name[1:5])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 print(name[1:5])
#
# TypeError: 'str' object is not callable

# %%
word="sachdeva"
print=(word[1:5])

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 2
#       1 word="sachdeva"
# ----> 2 print(word[1:5])
#
# TypeError: 'str' object is not callable

# %%
wre="davashi"
print(wre[1:4])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 2
#       1 wre="davashi"
# ----> 2 print(wre[1:4])
#
# TypeError: 'str' object is not callable

# %%
name="sachdeva"
print(name[1:2])
# Out:
# a

# %%
wre="davashi"
print(wre[1:5])
# Out:
# avas

# %%
print(wre[1:5:3])
# Out:
# as

# %%
print(len(name))#len function print the length of the name...
# Out:
# 8

# %%
print(name.endswith("eva"))
# Out:
# True

# %%
print(name.startswith("sac"))
# Out:
# True

# %%
num1="hello  world"
ks=num1.find("world")
print(ks)
# Out:
# 7

# %%
a=num1.replace("world","dlrow)
print(a)
# Out:
#   Cell In[23], line 1
#     a=num1.replace("world","dlrow)
#                            ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
 a="vishal is a good boy"
 a.replace("good","bad")
'vishal is a bad boy'
# Out:
# 'vishal is a bad boy'

# %%
b="vishal is a good boy\n but not a bad boy"
print(b)
# Out:
# vishal is a good boy
#  but not a bad boy

# %%
b='vishal is a good boy\n but not a \"bad boy\"'
print(b)
# Out:
# vishal is a good boy
#  but not a "bad boy"

# %% [markdown]
# practice question

# %%
name=input("name of the student")
print(name)
# Out:
# name of the student vishal
# vishal

# %%
name=input("name of the student is:")
print(f"good afternoon {name}")
# Out:
# name of the student is: vishal
# good afternoon vishal

# %%
#write a program to fill ina letter template given below with name and date.
letter='''
        dear vishal
        you are selected
        date 8september 2005'''
print(letter)
# Out:
#         dear vishal
#         you are selected
#         date 8september 2005

# %%
#write a program to detect double space in a string
name ="vishal is a good  boy and"
print(name.find("  "))
# Out:
# 16

# %%
#replace the double space from problem 3 with single space
name ="vishal is a good  boy and"
print(name.replace("  "," "))
# Out:
# vishal is a good boy and

# %%
#write a program to format the following letter using escape sequence character
letter="Dear vishal,\n\tThis course is nice.\n\t\tThanks!"
print(letter)
# Out:
# Dear vishal,
# 	This course is nice.
# 		Thanks!

# %%
#introduced the:the list are the container to store a set of value of any datatypes
friend=["apple","orange",5,345.6,False,"aakash","rahan"]
print(friend[5])
# Out:
# aakash

# %%
friend=["apple","orange",5,345.6,False,"aakash","rahan"]
print(friend)
# Out:
# ['apple', 'orange', 5, 345.6, False, 'aakash', 'rahan']

# %%
friend=["apple","orange",5,345.6,False,"aakash","rahan"]
print("the value of list is:",friend)#the list before changing the list
print(friend[5])#the value of before update
friend[5]="Banana"
print(friend[5])#the after update
print("the full ist is",friend)#the value is after the changing list
print(friend[1:4])
# Out:
# the value of list is: ['apple', 'orange', 5, 345.6, False, 'aakash', 'rahan']
# aakash
# Banana
# the full ist is ['apple', 'orange', 5, 345.6, False, 'Banana', 'rahan']
# ['orange', 5, 345.6]

# %%
friend=["apple","orange",5,345.6,False,"aakash","rahan"]
print(friend)
friend.append("vishal")
print(friend)
# Out:
# ['apple', 'orange', 5, 345.6, False, 'aakash', 'rahan']
# ['apple', 'orange', 5, 345.6, False, 'aakash', 'rahan', 'vishal']

# %%
l1=[1,34,62,2,6,11]
l1.sort()
print(l1)
# Out:
# [1, 2, 6, 11, 34, 62]

# %%
#if you are insert the number at the middle of the list then use the insert fuction 
l1=[1,34,62,2,6,11]
l1.insert(3,79)#insert 79 such that its index in the list is 3
l1.sort()
print(l1)
# Out:
# [1, 2, 6, 11, 34, 62, 79]

# %%
#use the pop() method
l1=[1,34,62,2,6,11]
l1.sort()
print(l1)
l1.pop(3)
print(l1)
# Out:
# [1, 2, 6, 11, 34, 62]
# [1, 2, 6, 34, 62]

# %%
l1.remove(34)
print(l1)
# Out:
# [1, 2, 6, 62]

# %%
l1.insert(2,10)
print(l1)
# Out:
# [1, 2, 10, 6, 62]

# %%
b=[1,2,3,4,5]
c=(1,2,3,4,5)
print(type(b))#printing the type of b
print(type(c))#printing the type of c
# Out:
# <class 'list'>
# <class 'tuple'>

# %%
#type conversion question
a=15.75
print(type(a))
a=int(15.75)
print(type(a))
# Out:
# <class 'float'>
# <class 'int'>

# %%
number = 100
# Convert 100 to "100" and then add " percent"
result = str(number) + " percent"

print(result)
print(type(result))
# Out:
# 100 percent
# <class 'str'>

# %%
c="banana"#string banana
d=c.count("a")
print("the number of a in the banana",d)
# Out:
# the number of a in the banana 3

# %%
colour=["red","blue","green"]
a=colour.append("yellow")
print("add the colour at the end",a)
print(colour)
n=colour.insert(2,"purple")
print("insert  the colour at the second position",b)
print(colour)
r=colour.remove("blue")
print("remove the colour from the list",r)
print(colour)
# Out:
# add the colour at the end None
# ['red', 'blue', 'green', 'yellow']
# insert  the colour at the second position 100
# ['red', 'blue', 'purple', 'green', 'yellow']
# remove the colour from the list None
# ['red', 'purple', 'green', 'yellow']
