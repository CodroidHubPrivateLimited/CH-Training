# %%
prefix = "Py"

prefix + "thon"
# Out:
# 'Python'

# %%
a=5
b=10
c=a+b
print("addition of two numbers is:",c)

# %%
a=5
b=10
c=a-b
print("subtraction of two numbers is:",c)
# Out:
# subtraction of two numbers is: -5

# %%
a=20
b=5
c=a*b
print("multiply of two numbers is:",c)
# Out:
# multiply of two numbers is: 100

# %%
a=20
b=5
c=a/b
print("division of two numbers is:",c)
# Out:
# division of two numbers is: 4.0

# %%
a=20
b=5
c=a%b
print("modules of two numbers is:",c)
# Out:
# modules of two numbers is: 0

# %%
num1="this is the first program of .\n my python language"
print(num1)
num2=r'i am learing ppython language'
print (num2)
# Out:
# this is the first program of .
#  my python language
# i am learing ppython language

# %%
num1="this is the first program of .\n my python language"
print(num1)
num2=r'vishal\nishant'
print(num2)
# Out:
# this is the first program of .
#  my python language
# vishal\nishant

# %%
va='py'
br='thon'
bv=va+br
print(bv)
# Out:
# python

# %%
var='py'
print(var+'thon')
# Out:
# python

# %%
num5=('Put several strings within parentheses '
        'to have them joined together.')
print(num5)
# Out:
# Put several strings within parentheses to have them joined together.

# %%
word='python'
first=word[0]
print(first)
# Out:
# p

# %%
word="vishal"
lastfirst=word[-1]
print(lastfirst)
# Out:
# l

# %%
word="nishant"
middle=word[4]
print(middle)
# Out:
# a

# %%
vag="hub"
bg="gsd"
lastw=vag[2]
ban=lastw+bg
print(ban)
# Out:
# bgsd

# %%
num6='coding'
len(num6)
# Out:
# 6

# %%
square=[1,4,5,6,8]
print(square)
# Out:
# [1, 4, 5, 6, 8]

# %%
square=[1,4,5,6,8]
third=square[3]
lastfirst=square[-1]
print(third)
print(lastfirst)
# Out:
# 6
# 8

# %%
square=[1,4,5,6,8]
third=square[3]*3
print(third)
# Out:
# 18

# %%
rgb = ["Red", "Green", "Blue"]
rgba = rgb
print(rgb)
# Out:
# ['Red', 'Green', 'Blue']

# %%
letters=['a','b','c','d','f']
len(letters)
# Out:
# 5

# %%
letters=['a','b','c','d','f']
numb=letters[2:4]
print(numb)
print(letters)
# Out:
# ['c', 'd']
# ['a', 'b', 'c', 'd', 'f']

# %%
a = ['a', 'b', 'c']
n = [1, 2, 3]
x = ['a', 'n']
f=[[1, 2, 3],['a', 'b', 'c']]
zero=f[0]
print(zero)
ad=a[2]+x[0]
print(ad)
# Out:
# [1, 2, 3]
# ca
