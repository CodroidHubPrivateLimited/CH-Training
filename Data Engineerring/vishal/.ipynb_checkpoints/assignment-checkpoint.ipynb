# %%
print("vishal")
print("age is ",20)
print("favorite subject:","math")
# Out:
# vishal
# age is  20
# favorite subject: math

# %%
welcome=("wecome in my blog")
welcome
# Out:
# 'wecome in my blog'

# %%
name=input("enter your collage name")
print("your collage name is",name)
# Out:
# enter your collage name chitkara
# your collage name is chitkara

# %%
city_name=input("enter the your city name")
print("your city name is :",city_name)
# Out:
# enter the your city name ambala
# your city name is : ambala

# %%
num=input("enter the number of the student:")
num2=input("enter the number of the subject:")
num3=input ("enter your admistion date is :")
print(num)
print(num2)
print(num3)
# Out:
# enter the number of the student: 23
# enter the number of the subject: 5
# enter your admistion date is : 2012
# 23
# 5
# 2012

# %%
product_price=float(input("produc price "))
tempearture=float(input("temperature is :"))
percentage =float(input("percenatage is:"))
print(product_price,tempearture,percentage)
# Out:
# produc price  56.5
# temperature is : 14.5
# percenatage is: 63.9
# 56.5 14.5 63.9

# %%
first_name=input("enter your first name is :")
last_name=input("enter your last name is :")
course_name=input("enter your course name is :")
print(first_name,last_name,course_name)
# Out:
# enter your first name is : vishal
# enter your last name is : sachdeva
# enter your course name is : aiml
# vishal sachdeva aiml

# %%
frute=["mango","apple","banana","date","graps"]
print(frute)
# Out:
# ['mango', 'apple', 'banana', 'date', 'graps']

# %%
date=("08","09","2005")
date
# Out:
# ('08', '09', '2005')

# %%
set={23,23,34,45,45,67}
set
# Out:
# {23, 34, 45, 67}

# %%
name={ "name":"vishal",
      "age":45,
      "course":"AIML",
     }
name
# Out:
# {'name': 'vishal', 'age': 45, 'course': 'AIML'}

# %%
num1=[]
print(type(num1))
# Out:
# <class 'list'>

# %%
num2={}
print(type(num2))
# Out:
# <class 'dict'>

# %%
name="vishal"
print("name is:",name)
age=20
print("age is:",age)
city="ambala"
print("city is :",city)
# Out:
# name is: vishal
# age is: 20
# city is : ambala

# %%
#declare two variable
#variable is work like containers
#and also print them
weight=45
gender="male"
print("your weight is :",weight)
print("your gender is:",gender)
# Out:
# your weight is : 45
# your gender is: male

# %%
''' my name is vishal
from ambala
i do coding'''
print("welcome")
# Out:
# welcome
