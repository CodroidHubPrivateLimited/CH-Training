# %%
import pandas as pd

# %%
pd.DataFrame({
    "A":[1,2,3],
    "B":[4,5,6],
})
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
url="https://www.flipkart.com/tyy/4io/~cs-yyz0z07a06/pr?sid=tyy%2C4io&collection-tab-name=samsung+S24+5G+SD&pageCriteria=default&param=3838&hpid=H3kVFvfATcBjl0FYDg15tqp7_Hsxr70nj65vMAAFKlc%3D&ctx=...%3D%3D"

# %%
headers={
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36"
}

# %%
response=requests.get(url,headers=headers)

# %%
response.status_code==200
# Out:
# True

# %%
print(response)
# Out:
# <Response [200]>

# %%
#change 
soup=BeautifulSoup(response.content,'html.parser')
print(soup)
# Out:
# <!DOCTYPE html>
# ...

# %%
parent_class="lvJbLV col-12-12"
print(parent_class)
print(len(parent_class))
# Out:
# lvJbLV col-12-12
# 16

# %%
products=soup.findAll("div",class_="lvJbLV col-12-12")
print(products)
print(len(products))
# Out:
# [<div class="lvJbLV col-12-12"><div class="v360g_"><section class="JPBFuF vRd1kF"><div class="AF1m2F"><div class="UHMz4K"><span>Filters</span></div></div></section><div class="_f7dpA"><section class="EbGpCV"><div class="ejUPwC"><span>CATEGORIES</span></div><div><div class="pBPis1"><span><svg class="QASjE5" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="zMV6HH" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="HJtI4S ECYCDD" href="/mobiles-accessories/pr?sid=tyy&amp;otracker=categorytree" title="Mobiles &amp; Accessories">Mobiles &amp; Accessories</a></div></div><div><div class="pBPis1"><span><svg class="QASjE5" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="GD4sye ECYCDD" href="/mobiles/pr?sid=tyy,4io&amp;otracker=categorytree
# ...

# %%
df = pd.DataFrame()
name_list = []
price_list = []

# %%
for product in products:
    name=product.find("div",class_="RG5Slk")
    price=product.find("div",class_="hZ3P6w DeU9vF")
    if name!=None:
        name=name.get_text()
    if price!=None:
        price=price.get_text()

    if (price!=None) and (name!=None):
        price_list.append(price)
        name_list.append(name)
df["Name"]=name_list
df["Price"]=price_list
df
# Out:
#                                                 Name    Price
# 0  Samsung Galaxy S24 5G Snapdragon (Onyx Black, ...  ₹47,999
# 1  Samsung Galaxy S24 5G Snapdragon (Onyx Black, ...  ₹42,999
# 2  Samsung Galaxy S24 5G Snapdragon (Marble Gray,...  ₹47,999
# 3  Samsung Galaxy S24 5G Snapdragon (Amber Yellow...  ₹42,999
# 4  Samsung Galaxy S24 5G Snapdragon (Amber Yellow...  ₹47,999
# 5  Samsung Galaxy S24 5G Snapdragon (Cobalt Viole...  ₹42,999
# 6  Samsung Galaxy S24 5G Snapdragon (Cobalt Viole...  ₹47,999

# %%
url2="https://books.toscrape.com/"

# %%
header2 = { 
    "User-Agent":
"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36"
}

# %%
responsed=requests.get(url2,headers=header2)

# %%
responsed.status_code==200
# Out:
# True

# %%
print(responsed)
# Out:
# <Response [200]>

# %%
soup2=BeautifulSoup(responsed.content,'html.parser')
print(soup2)
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-us"> <!--<![endif]-->
# <head>
# <title>
#     All products | Books to Scrape - Sandbox
# </title>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="24th Jun 2016 09:29" name="created"/>
# <meta content="" name="description"/>
# <meta content="width=device-width" name="viewport"/>
# <meta content="NOARCHIVE,NOCACHE" name="robots"/>
# <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
# <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
# <link href="static/oscar/favicon.ico" rel="shortcut icon"/>
# ...

# %%
parent_class2="col-xs-6 col-sm-4 col-md-3 col-lg-3"
print(parent_class2)
print(len(parent_class2))
# Out:
# col-xs-6 col-sm-4 col-md-3 col-lg-3
# 35

# %%
products2=soup2.find_all("li",class_="col-xs-6 col-sm-4 col-md-3 col-lg-3")
print(products2)
print(len(products2))
# Out:
# [<li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
# <article class="product_pod">
# <div class="image_container">
# <a href="catalogue/a-light-in-the-attic_1000/index.html"><img alt="A Light in the Attic" class="thumbnail" src="media/cache/2c/da/2cdad67c44b002e7ead0cc35693c0e8b.jpg"/></a>
# </div>
# <p class="star-rating Three">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>
# <h3><a href="catalogue/a-light-in-the-attic_1000/index.html" title="A Light in the Attic">A Light in the ...</a></h3>
# <div class="product_price">
# <p class="price_color">£51.77</p>
# <p class="instock availability">
# <i class="icon-ok"></i>
#
#         In stock
#
# </p>
# <form>
# <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
# </form>
# </div>
# </article>
# </li>, <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
# <article class="product_pod">
# ...

# %%
df2 = pd.DataFrame()
name_list2 = []
price_list2 = []

# %%
for product in products2:
    name=product.find("h3").find("a")
    price=product.find("p",class_="price_color")
    if name!=None:
        name=name.get_text()
    if price!=None:
        price=price.get_text()

    if (price!=None) and (name!=None):
        price_list2.append(price)
        name_list2.append(name)
df2["Name"]=name_list2
df2["Price"]=price_list2
df2
# Out:
#                                      Name   Price
# 0                      A Light in the ...  £51.77
# 1                      Tipping the Velvet  £53.74
# 2                              Soumission  £50.10
# 3                           Sharp Objects  £47.82
# 4            Sapiens: A Brief History ...  £54.23
# 5                         The Requiem Red  £22.65
# 6            The Dirty Little Secrets ...  £33.34
# 7                 The Coming Woman: A ...  £17.93
# 8                     The Boys in the ...  £22.60
# 9                         The Black Maria  £52.15
# 10  Starving Hearts (Triangular Trade ...  £13.99
# 11                  Shakespeare's Sonnets  £20.66
# 12                            Set Me Free  £17.46
# 13    Scott Pilgrim's Precious Little ...  £52.29
# 14                      Rip it Up and ...  £35.02
# 15                  Our Band Could Be ...  £57.25
# 16                                   Olio  £23.88
# 17        Mesaerion: The Best Science ...  £37.59
# ...

# %%
url3="https://www.zomato.com/chandigarh/restaurants"

# %%
header3={
    "user-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36"
}

# %%
rresponse3=requests.get(url2,headers=header3)
print(rresponse3)
rresponse3.status_code==200
# Out:
# <Response [200]>
# True

# %%
products3=soup.find_all("div",class_="sc-evWYkj cRThYq")
print(products3)
print(len(products3))
# Out:
# []
# 0

# %%
soup3=BeautifulSoup(rresponse3.content,'html.parser')
print(soup3)
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-us"> <!--<![endif]-->
# <head>
# <title>
#     All products | Books to Scrape - Sandbox
# </title>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="24th Jun 2016 09:29" name="created"/>
# <meta content="" name="description"/>
# <meta content="width=device-width" name="viewport"/>
# <meta content="NOARCHIVE,NOCACHE" name="robots"/>
# <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
# <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
# <link href="static/oscar/favicon.ico" rel="shortcut icon"/>
# ...

# %%
df3 = pd.DataFrame()
name_list3 = []
price_list3= []

# %%
for product in products3:
    name=product.find("h4",class_="sc-1hp8d8a-0 sc-Ehqfj bxOQva")
    price=product.find("p",class_="sc-1hez2tp-0 sc-gggouf KXcjT")
    if name!=None:
        name=name.get_text()
    if price!=None:
        price=price.get_text()

    if (price!=None) and (name!=None):
        price_list3.append(price)
        name_list3.append(name)
df3["Name"]=name_list3
df3["Price"]=price_list3
df3
# Out:
# Empty DataFrame
# Columns: [Name, Price]
# Index: []

# %%
url4="https://www.swiggy.com/collections/80382?collection_id=80382&tags=layout_CCS_CholeBhature&type=rcv2"
header4={
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36"
}
response4=requests.get(url4,headers=header4)
print(response4)
response4.status_code==200
print(response4)
soup4=BeautifulSoup(response4.content,'html.parser')
print(soup4)
parent_class4="sc-beIvYv gpUGEh"
print(parent_class4)
print(len(parent_class4))
products4=soup4.find_all("div",class_="sc-beIvYv gpUGEh")
print(products4)
print(len(products4))
df4 = pd.DataFrame()
name_list4 = []
price_list4 = []

for product in products4:
    name=product.find("div",class_="sc-aXZVg brETgz")
    price=product.find("div",class_="sc-aXZVg OyTrl")
    if name!=None:
        name=name.get_text()
    if price!=None:
        price=price.get_text()

    if (price!=None) and (name!=None):
        price_list4.append(price)
        name_list4.append(name)
df4["Name"]=name_list4
df4["Price"]=price_list4
df4
# Out:
# <Response [200]>
# <Response [200]>
# <!DOCTYPE html>
# ...

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
url5="https://www.makemytrip.com/hotels/hotel-listing/?checkin=03012026&city=CTBLR&checkout=03032026&roomStayQualifier=1e0e&locusId=CTBLR&country=IN&locusType=city&searchText=Bengaluru&regionNearByExp=3&rsc=1e1e0e"
header5={
    "user-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36"
}
response5=requests.get(url5,headers=header5)
print(response5)
response5.status_code==200
print(response5)
soup5=BeautifulSoup(response5.content,'html.parser')
print(soup5)
parent_class5="listingRow listingRowPerNew bdrPerNew"
print(parent_class5)
print(len(parent_class5))
products5=soup5.find_all("div",class_="listingRow listingRowPerNew bdrPerNew")
print(products5)
print(len(products5))
df5 = pd.DataFrame()
name_list5 = []
price_list5 = []

for product in products5:
    name=product.find("p",class_="latoBlack blackText font20")
    price=product.find("p",class_="priceText latoBlack font22 blackText appendBottom5")
    if name!=None:
        name=name.get_text()
    if price!=None:
        price=price.get_text()

    if (price!=None) and (name!=None):
        price_list5.append(price)
        name_list5.append(name)
df5["Name"]=name_list5
df5["Price"]=price_list5
df5

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
url6="https://www.flipkart.com/all/~cs-7847646c0fa813bb0b1d71a25db94e79/pr?sid=0pm,fcn,821,a7x,2si&marketplace=FLIPKART&restrictLocale=true"
header6={
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36"
}
response6=requests.get(url6,headers=header6)
# print(response6)
response6.status_code==200
# print(response6)
soup6=BeautifulSoup(response6.content,'html.parser')
# print(soup6)
parent_class6="RGLWAk"
print(parent_class6)
# print(len(parent_class6))
products6=soup6.find_all("div",class_="RGLWAk")
# print(products6)
print(len(products6))
df6 = pd.DataFrame()
name_list6 = []
price_list6 = []

for product in products6:
    name=product.find("a",class_="pIpigb")
    price=product.find("div",class_="hZ3P6w")
    if name!=None:
        name=name.get_text()
    if price!=None:
        price=price.get_text()

    if (price!=None) and (name!=None):
        price_list6.append(price)
        name_list6.append(name)
df6["Name"]=name_list6
df6["Price"]=price_list6
df6
# Out:
# RGLWAk
# 40
#                                                  Name   Price
# 0   boAt Airdopes 161, Adv 4Mic ENx, 50H Battery,F...    ₹799
# 1   TRIGGR Kraken X4 with 13mm Drivers, 40ms Laten...    ₹799
# 2   boAt Airdopes 71,40 H Battery, ENx Tech, Low L...    ₹799
# 3             BULLSTORM BS ultrapood Bluetooth Gaming    ₹298
# 4   TECHIO Black Earbuds | True Wireless Stereo | ...    ₹247
# 5   GOBOULT Z40 with ENC Mic, 60Hr Battery, Metal ...    ₹999
# 6   myxes New Edition TWS M19 Gaming Earbuds Bluet...    ₹373
# 7   Sagaft X589 Advanced TWS Earbuds with Hi-Fi So...    ₹693
# 8   Caidea TW500 Tube Upto 50H Playtime*, ENC, Fas...    ₹399
# 9   OnePlus Nord Buds 3r TWS Earbud, 10min charge ...  ₹1,799
# 10  boAt Airdopes 161/163,ASAP Charge,40 H Battery...    ₹799
# 11  boAt Airdopes 212,Translucent Lid, 50H Battery...    ₹799
# 12  NS WORLD Thunder Pods | High Bass | Large Batt...    ₹298
# 13  GWALBROS New White Bluetooth Earbuds, True Wir...    ₹251
# ...

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
url7="https://pharmeasy.in/health-care/sports-nutrition-12931"
header7={
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36"
}
response7=requests.get(url7,headers=header6)
# print(response6)
response7.status_code==200
# print(response6)
soup7=BeautifulSoup(response7.content,'html.parser')
# print(soup6)
parent_class7="ProductCard_productCard__ftHIX"
print(parent_class6)
# print(len(parent_class6))
products7=soup7.find_all("div",class_="ProductCard_productCard__ftHIX")
# print(products6)
print(len(products7))
df7 = pd.DataFrame()
name_list7 = []
price_list7 = []

for product in products7:
    name=product.find("div",class_="ProductCard_productName__nWQ3x")
    price=product.find("div",class_="ProductCard_priceContainer__99QdN ProductCard_otcListingPriceContainer__PXAT_")
    if name!=None:
        name=name.get_text()
    if price!=None:
        price=price.get_text()

    if (price!=None) and (name!=None):
        price_list7.append(price)
        name_list7.append(name)
df7["Name"]=name_list7
df7["Price"]=price_list7
df7
# Out:
# RGLWAk
# 20
#                                            Name                  Price
# 0   Optimum Nutrition (On) Gold Standard 100...   ₹3611.65MRP ₹4249.00
# 1   Pharmeasy Daily Protein For Strong Bones...     ₹311.98MRP ₹799.96
# 2   Muscleblaze Beginner'S Whey Protein | Fa...   ₹1465.46MRP ₹1559.00
# 3   Nutrabay Gold 100% Whey Protein Isolate ...  ₹5609.49MRP ₹10999.00
# 4   Isopure Zero Carb Protein - 2.20 Lbs | 1...   ₹5651.55MRP ₹5949.00
# 5   Pharmeasy Diabetic Protein Powder French...    ₹743.66MRP ₹1957.00
# 6   Pharmeasy Diabetic Protein Powder French...     ₹355.60MRP ₹889.00
# 7   Oziva Protein & Herbs For Women Vanilla ...   ₹1531.63MRP ₹1579.00
# 8   Pharmeasy Diabetic Protein Powder Chocol...     ₹364.49MRP ₹889.00
# 9   Nutrabay Gold Tri-Blend Whey Protein Str...   ₹2225.47MRP ₹4199.00
# 10  Optimum Nutrition (On) Gold Standard 100...   ₹1931.16MRP ₹2299.00
# 11             On Creatine Monohydrate 100g Ind     ₹489.30MRP ₹699.00
# ...

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
url7="https://pharmeasy.in/health-care/sports-nutrition-12931"
header7={
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36"
}
response7=requests.get(url7,headers=header6)
# print(response6)
response7.status_code==200
# print(response6)
soup7=BeautifulSoup(response7.content,'html.parser')
# print(soup6)
parent_class7="ProductCard_productCard__ftHIX"
print(parent_class6)
# print(len(parent_class6))
products7=soup7.find_all("div",class_="ProductCard_productCard__ftHIX")
# print(products6)
print(len(products7))
df7 = pd.DataFrame()
name_list7 = []
price_list7 = []

for product in products7:
    name=product.find("div",class_="ProductCard_productName__nWQ3x")
    price=product.find("div",class_="ProductCard_priceContainer__99QdN ProductCard_otcListingPriceContainer__PXAT_")
    if name!=None:
        name=name.get_text()
    if price!=None:
        price=price.get_text()

    if (price!=None) and (name!=None):
        price_list7.append(price)
        name_list7.append(name)
df7["Name"]=name_list7
df7["Price"]=price_list7
df7
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 8
#       4 url7="https://pharmeasy.in/health-care/sports-nutrition-12931"
#       5 header7={
#       6     "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36"
#       7 }
# ----> 8 response7=requests.get(url7,headers=header6)
#       9 # print(response6)
#      10 response7.status_code==200
#
# NameError: name 'header6' is not defined

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
url7="https://puirf.codroidhub.com/api/api/v1/instruments/user/getHomeFacilities"
header7={
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36"
}

response7 = requests.get(url7,headers=header7)
print(response7)
df7 = pd.DataFrame()
name_list7 = []
price_list7 = []

for product in products7:
    name=product.find("div",class_="ProductCard_productName__nWQ3x")
    price=product.find("div",class_="ProductCard_priceContainer__99QdN ProductCard_otcListingPriceContainer__PXAT_")
    if name!=None:
        name=name.get_text()
    if price!=None:
        price=price.get_text()

    if (price!=None) and (name!=None):
        price_list7.append(price)
        name_list7.append(name)
df7["Name"]=name_list7
df7["Price"]=price_list7
df7
# Out:
# <Response [200]>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 15
#      12 name_list7 = []
#      13 price_list7 = []
# ---> 15 for product in products7:
#      16     name=product.find("div",class_="ProductCard_productName__nWQ3x")
#      17     price=product.find("div",class_="ProductCard_priceContainer__99QdN ProductCard_otcListingPriceContainer__PXAT_")
#
# NameError: name 'products7' is not defined
