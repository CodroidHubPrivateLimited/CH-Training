# %% [markdown]
# <center><h1>vishal sachdeva<h1></center>
# <center><h2>Use The Api<h2></center>

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
url = "https://codroidhub.com/api/testimonials"
headers = {
    "User-Agent": "Mozilla/5.0"
}
response = requests.get(url, headers=headers)
print(type(response.content))
data = response.json()
main_data = data["testimonials"]
print(type(main_data))
id_list1 = []
name_list1 = []
role_list1 = []
company_list1 = []
for item in main_data:
    id_list1.append(item.get("id"))
    name_list1.append(item.get("name"))
    role_list1.append(item.get("role"))
    company_list1.append(item.get("company"))
df = pd.DataFrame({
    "id": id_list1,
    "name": name_list1,
    "role": role_list1,
    "company": company_list1
})
print(df)
df.to_csv("CodroidHub_data.csv", index=False)
# Out:
# <class 'bytes'>
# <class 'list'>
#       id              name                                               role  \
# 0   None            Sakshi                        Trainee | Digital Marketing
# 1   None     Drishti Gupta                   Trainee | MERN Stack Development
# 2   None            Ishika                      Trainee |Human Resources (HR)
# 3   None            Trisha  Trainee | Data Analytics & Visualization with ...
# 4   None         Isha Rani  Trainee | Data Analytics & Visualization with ...
# 5   None       Tarun Kumar  Trainee | Large Language Models (LLMs) with Hu...
# 6   None      Tannu Sharma               Trainee | \tCorporate Communications
# 7   None       Sumit Singh        Trainee | AI & Machine Learning with Python
# 8   None  Rishabh Dev Jain  Trainee | Data Analytics & Visualization with ...
# 9   None      Mahima Gupta        Trainee | AI & Machine Learning with Python
# 10  None   Rasanpreet kaur  Trainee | Finance & Accounts with IT Applications
# 11  None              Neha  Trainee | Large Language Models (LLMs) with Hu...
# 12  None      Sanjana Devi  Trainee | Data Engineering with Python & Cloud...
# 13  None           Anshita  Trainee | Data Analytics & Visualization with ...
#
#                              company
# 0   CodroidHub Professional Training
# 1   CodroidHub Professional Training
# 2   CodroidHub Professional Training
# 3   CodroidHub Professional Training
# 4   CodroidHub Professional Training
# 5   CodroidHub Professional Training
# 6   CodroidHub Professional Training
# 7   CodroidHub Professional Training
# 8   CodroidHub Professional Training
# 9   CodroidHub Professional Training
# 10  CodroidHub Professional Training
# 11  CodroidHub Professional Training
# 12  CodroidHub Professional Training
# 13  CodroidHub Professional Training
