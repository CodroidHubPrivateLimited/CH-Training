# %% [markdown]
# <center><h1>vishal sachdeva<h1></center>
# <center><h2>dynamic website is<h2></center>

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
driver.get("https://m.dominos.co.in/jfl-discovery-ui/en/web/menu-v2/6585R?&showSearchModal=false&scrollTo=205")
time.sleep(2)
quotes2 = driver.find_elements(By.TAG_NAME, "span")
quote_list = []
for index, quote in enumerate(quotes2):
    print(f"Index: {index}, Quote: {quote.text}")
    quote_list.append(quote.text)
    if index==10:
        break
driver.quit()

# df.to_csv("dynamic_data.csv", index=False)
# Out:
# Index: 0, Quote: Domino's Pizza
# Index: 1, Quote: Tacos & Parcels
# Index: 2, Quote:
# Index: 3, Quote: Pizza Mania
# Index: 4, Quote:
# Index: 5, Quote: Desserts
# Index: 6, Quote:
# Index: 7, Quote: No Onion No Garlic
# Index: 8, Quote:
# Index: 9, Quote: Veg Pizza
# Index: 10, Quote:

# %%
print(quote_list)
# Out:
# ["Domino's Pizza", 'Tacos & Parcels', '', 'Pizza Mania', '', 'Desserts', '', 'No Onion No Garlic', '', 'Veg Pizza', '']

# %%
import pandas as pd
df = pd.DataFrame({"Quotes"
                   : quote_list})
print(df)
# Out:
#                 Quotes
# 0       Domino's Pizza
# 1      Tacos & Parcels
# 2
# 3          Pizza Mania
# 4
# 5             Desserts
# 6
# 7   No Onion No Garlic
# 8
# 9            Veg Pizza
# 10

# %%
df.to_csv("dynamic_data.csv", index=False)

# %% [markdown]
# <center><h1>thanku<h1></center>
