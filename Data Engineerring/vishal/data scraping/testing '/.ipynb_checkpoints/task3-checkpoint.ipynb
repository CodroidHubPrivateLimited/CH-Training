# %% [markdown]
# <center><h1>vishal sachdeva<h1></center>
# <center><h2>dynamic website is<h2></center>

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
driver.get("https://m.dominos.co.in/jfl-discovery-ui/en/web/menu-v2/6585R?&showSearchModal=false&scrollTo=205")
time.sleep(2)
quotes2 = driver.find_elements(By.TAG_NAME, "div")
for quote in quotes2:
    print(quote.text)
driver.quit()
# Out:
# Domino's Pizza
# Veg Only
# Non Veg Only
# Sort by
# Tacos & Parcels
# Pizza Mania
# Desserts
# No Onion No Garlic
# Veg Pizza
# Crazy Deals
# Cheese Burst Pizza
# Cheese Lava
# Sourdough @299
# Chicken Feast
# Love Loaded@299
# Cheese Volcano
# Garlic Breads & Dips
# Non-Veg Pizza
# Beverages
# Chicken Burst
# Meals Under 99
# Menu@99
# Love Loaded@299
# Loaded Veggie Paradise
# Valentine’s Special: Thin Crust Cheese Burst pizza loaded with Golden Corn, Black Olives, Capsicum & Red Paprika.
# Rs.299
# RegularThin-Crust Cheese Burst
# Add +
# Loaded Pepper BBQ Chicken
# Valentine’s Special: Thin Crust Cheese Burst pizza with Pepper BBQ Chicken for that extra zing.
# Rs.299
# RegularThin-Crust Cheese Burst
# Add +
# Loaded Chicken Dominator
# Valentine’s Special: Thin Crust Cheese Burst pizza loaded with loads of Chicken.
# Rs.299
# RegularThin-Crust Cheese Burst
# Add +
# Loaded Farmhouse
# ...

# %% [markdown]
# <center><h1>thanku<h1></center>
