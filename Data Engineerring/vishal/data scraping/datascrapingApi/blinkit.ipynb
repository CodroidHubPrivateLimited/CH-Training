# %% [markdown]
# <div style="text-align: center; padding: 20px:colour='red'">
#     <h1 style="color: rgb(249, 249, 246);">Vishal Sachdeva</h1>
#     <h2 style="color: rgb(251, 255, 9);">Blinkit Dynamic</h2>
#     <p style="font-size: 16px; max-width: 700px; margin: auto;">
#         faching the data from the blinkit website
#     </p>
#     <hr style="width: 60%;">
# </div>

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
# Start browser
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
# Open website
driver.get("https://blinkit.com/cn/chips-crisps/cid/1237/940")
time.sleep(2)
# Find elements
quotes = driver.find_elements(By.CSS_SELECTOR, "div[role='button']")
for quote in quotes:
    print(quote.text)
driver.quit()
# Out:
# Chips & Crisps
# Rusks & Wafers
# Energy Bars
# Nachos
# Bhujia & Mixtures
# Popcorn
# Namkeen Snacks
# Makhana & More
# Papad & Fryums
# Imported Snacks
# Granola
# Munchies Gift Packs
# 8 MINS
# Sweet Karam Coffee Andhra Spicy Murukku
# 95 g
# ₹90
# ₹92
# ADD
# 3 options
# ADD
# 3 options
# 8 MINS
# Kettle Studio Rock Sea Salt & English Vinegar Potato Chips
# 113 g
# ₹99
# ADD
# ADD
# 8 MINS
# Protein Chef Baked Coated Peanuts (Masala Roasted Healthy Snacks)
# 50 g
# ₹69
# ₹70
# ADD
# 2 options
# ADD
# 2 options
# 8 MINS
# Kurkure Masala Munch Crisps
# 75 g
# ₹20
# ADD
# 2 options
# ADD
# 2 options
# 38% OFF
# 8 MINS
# Crax Fritts Peri Peri Corn & Potato Sticks Snacks
# 84 g
# ₹37
# ₹60
# ADD
# 2 options
# ADD
# 2 options
# 10% OFF
# 8 MINS
# Kettle Studio Sharp Jalapenos & Cream Cheese Potato Chips
# 60 g
# ₹44
# ₹49
# ADD
#
# ADD
# 8 MINS
# Kettle Studio Potato Chips - Himalyan Pink Salt
# 113 g
# ₹99
# ADD
# ADD
# 8 MINS
# Kettle Studio Sweet Chilli With Lime & Basil Potato Chips
# 60 g
# ₹49
# ADD
# 2 options
# ADD
# 2 options
# 8 MINS
# Kettle Studio Crushed Peprika with Exotic Spices Potato Chips
# 113 g
# ₹99
# ADD
# ADD
# 8 MINS
# Lay's West Indies Hot n Sweet Chilli Flavour Potato Chips
# 52.9 g
# ₹20
# ADD
# ADD
# 8 MINS
# Kab's Jackpot Fiery and Crunchy Crisps
# 80 g
# ₹65
# ADD
# ADD
# 8% OFF
# 8 MINS
# Britannia 5050 Potazos Masti Masala Potato Biscuit
# 71.5 g
# ₹23
# ₹25
# ADD
# 2 options
# ADD
# 2 options
# 8 MINS
# Lo! Foods Gluten Free Millet Chips
# 75 g
# ₹99
# ADD
# ADD
# 8 MINS
# Lay's Chile Limon Flavour Potato Chips
# 52.9 g
# ₹20
# ADD
# ADD
# 8 MINS
# Lay's American Style Cream & Onion Potato Chips
# 73.7 g
# ₹30
# ADD
# 2 options
# ADD
# 2 options
# 8 MINS
# Lay's Classic Salted Potato Chips
# 51 g
# ₹20
# ADD
# 2 options
# ADD
# 2 options
# 8 MINS
# Lay's Crispz Herb & Onion Potato Chips
# 50.8 g
# ₹20
# ADD
# ADD
# 10% OFF
# 8 MINS
# Kettle Studio Himalayan Pink Salt Potato Chips
# 56 g
# ₹44
# ₹49
# ADD
# ADD
# 8 MINS
# Kurkure Puffcorn Yummy Cheese Puffs
# 58 g
# ₹20
# ADD
# 2 options
# ADD
# 2 options
# 8 MINS
# Nongshim Shrimp Flavoured Hot & Spicy Crackers Chips
# 75 g
# ₹139
# ADD
# ADD
# 8 MINS
# Kettle Studio Mature Cheddar & Red Onions Potato Chips
# 113 g
# ₹99
# ADD
# 2 options
# ADD
# 2 options
# 23% OFF
# 8 MINS
# Let's Try Rock Salt Potato Chips / Wafers
# 58 g
# ₹46
# ₹60
# ADD
# ADD
# 8 MINS
# Uncle Chipps Plain Salted Potato Chips
# 53 g
# ₹20
# ADD
# 2 options
# ADD
# 2 options
# 8 MINS
# Kurkure Chilli Chatka Crisps
# 68 g
# ₹20
# ADD
# 2 options
# ADD
# 2 options
# 8 MINS
# Kettle Studio Lime & Chilli Wafers
# 140 g
# ₹80
# ADD
# ADD
# 8 MINS
# Dobra Thin & Crispy Tapioca Chips
# 60 g
# ₹65
# ADD
# ADD
# 8 MINS
# Farmley Makha Shaka Makhana Masala Stix Crisps
# 33 g
# ₹29
# ₹30
# ADD
# 2 options
# ADD
# 2 options
# 26% OFF
# 8 MINS
# Chheda's Yellow Rock Salt Banana Chips
# 170 g
# ₹69
# ₹94
# ADD
# ADD
# 7% OFF
# 8 MINS
# Sweet Karam Coffee Tuticorin Rock Salt Potato Chips - Homestyle Wafers
# 60 g
# ₹51
# ₹55
# ADD
#
# ADD
# 16% OFF
# 8 MINS
# Sweet Karam Coffee Andhra Spicy Murukku + Nendran Banana Chips Combo
# 95 g + 65 g
# ₹130
# ₹156
# ADD
# ADD

# %% [markdown]
# <marquee><h2 style="color: yellow;">Thanku</h2></marquee>>
