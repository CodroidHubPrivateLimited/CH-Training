# %%
a=int(input("enter the your first number value is :"))
b=int(input("enter your second number value is:"))
c=int(input("enter your third number value is :"))
average=(a+b+c)/3
print(average)
# Out:
# enter the your first number value is : 20
# enter your second number value is: 50
# enter your third number value is : 60
# 43.333333333333336

# %%
#using the function
#function definations
def avg():
    a=int(input("enter the your first number value is :"))
    b=int(input("enter your second number value is:"))
    c=int(input("enter your third number value is :"))
    average=(a+b+c)/3
    print(average)
avg()#function calls
avg()
# Out:
# enter the your first number value is : 10
# enter your second number value is: 20
# enter your third number value is : 30
# 20.0
# enter the your first number value is : 50
# enter your second number value is: 04
# enter your third number value is : 45
# 33.0
