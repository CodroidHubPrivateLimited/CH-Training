# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
headers={
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/143.0.0.0 Safari/537.36'
}
url='https://www.flipkart.com/search?q=laptop&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off'
response=requests.get(url, headers=headers)
response
soup= BeautifulSoup(response.content,'html.parser')

soup
if soup.body:
    soup=soup.body
for tag in soup(['script','style','meta','noscript','link','head']):
        tag.decompose()
#print(soup.prettify())
product=soup.find_all('div',class_='jIjQ8S')
#print(len(product))
product
Laptop=[]
for i in product:
    title=i.find('div',class_='RG5Slk')
    price=i.find('div',class_='hZ3P6w DeU9vF')
    Laptop.append({
         'Name': title.get_text(strip=True) if title else None,
         'Price': price.get_text(strip=True) if price else None,
    })
Laptop
df=pd.DataFrame(Laptop)
df
# Out:
#                                                  Name      Price
# 0   Samsung Galaxy Book4 Metal Intel Core i5 13th ...    ₹53,500
# 1   Samsung Galaxy Book4 Edge Series Copilot AI-PC...    ₹64,990
# 2   DELL 15 AMD Ryzen 3 Quad Core 7320U - (8 GB/51...    ₹29,999
# 3   Acer Aspire 3 Intel Celeron Dual Core - (8 GB/...    ₹21,499
# 4   Acer Aspire 3 Intel Celeron Dual Core N4500 - ...    ₹23,990
# 5   Samsung Galaxy Book4 Metal Intel Core i3 13th ...    ₹38,990
# 6   Lenovo 100e Chromebook Gen 4 MediaTek Kompanio...     ₹9,999
# 7   Thomson Intel Celeron Dual Core N4020 - (4 GB/...    ₹14,799
# 8   Lenovo Chromebook MediaTek Kompanio 520 - (4 G...    ₹13,999
# 9   Acer Aspire 3 Backlit AMD Ryzen 7 Octa Core 77...    ₹38,990
# 10  DELL 15 AMD Ryzen 5 Hexa Core 7530U - (16 GB/5...    ₹42,990
# 11  Samsung Galaxy Book4 Pro Evo AI PC Intel Core ...  ₹1,41,505
# 12  HP 15 Intel Core i5 13th Gen 1335U - (16 GB/51...    ₹53,980
# ...

# %%
n=int(input("Enter thre number"))
if(n%2==0):
    print("No. Is even")
else:
    print("no. is odd")
# Out:
# No. Is even

# %%
list1=[2,3,4]
list1
# Out:
# [2, 3, 4]

# %%
import math as m
n=2/3
m.ceil(n)
# Out:
# 1

# %%
5%2
# Out:
# 1

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
2//3
# Out:
# 0

# %%
pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
2//3
# Out:
# 0
