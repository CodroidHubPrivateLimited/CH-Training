# %%
import requests

# %%
url="https://dog.ceo/api/breeds/image/random"

# %%
response=requests.get(url)

# %%
response.status_code
# Out:
# 200

# %%
if response.status_code == 200:
    data = response.json()
    dog_image_url = data['message']
    print("Random Dog Image URL:", dog_image_url)
    print(dog_image_url)
else:
    print("Failed to retrieve data. Status code:")
# Out:
# Random Dog Image URL: https://images.dog.ceo/breeds/bulldog-french/n02108915_656.jpg
# https://images.dog.ceo/breeds/bulldog-french/n02108915_656.jpg
