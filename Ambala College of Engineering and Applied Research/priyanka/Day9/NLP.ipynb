# %%
import re

# %%
pip install pyspellchecker
# Out:
# Collecting pyspellchecker
#   Downloading pyspellchecker-0.8.4-py3-none-any.whl.metadata (9.4 kB)
# Downloading pyspellchecker-0.8.4-py3-none-any.whl (7.2 MB)
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.2 MB 325.1 kB/s eta 0:00:23
#     --------------------------------------- 0.1/7.2 MB 655.4 kB/s eta 0:00:11
#    - -------------------------------------- 0.3/7.2 MB 1.3 MB/s eta 0:00:06
#    -- ------------------------------------- 0.4/7.2 MB 1.8 MB/s eta 0:00:04
#    ---- ----------------------------------- 0.7/7.2 MB 2.7 MB/s eta 0:00:03
#    ------ --------------------------------- 1.1/7.2 MB 3.7 MB/s eta 0:00:02
#    -------- ------------------------------- 1.5/7.2 MB 4.4 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.0/7.2 MB 5.0 MB/s eta 0:00:02
#    -------------- ------------------------- 2.5/7.2 MB 6.0 MB/s eta 0:00:01
#    ---------------- ----------------------- 3.0/7.2 MB 6.4 MB/s eta 0:00:01
#    ------------------- -------------------- 3.6/7.2 MB 7.0 MB/s eta 0:00:01
#    ---------------------- ----------------- 4.1/7.2 MB 7.4 MB/s eta 0:00:01
#    ------------------------ --------------- 4.5/7.2 MB 7.6 MB/s eta 0:00:01
#    --------------------------- ------------ 5.0/7.2 MB 7.8 MB/s eta 0:00:01
#    ------------------------------ --------- 5.5/7.2 MB 8.1 MB/s eta 0:00:01
#    --------------------------------- ------ 6.1/7.2 MB 8.3 MB/s eta 0:00:01
#    ------------------------------------ --- 6.6/7.2 MB 8.6 MB/s eta 0:00:01
#    ---------------------------------------  7.2/7.2 MB 8.7 MB/s eta 0:00:01
#    ---------------------------------------- 7.2/7.2 MB 8.3 MB/s eta 0:00:00
# Installing collected packages: pyspellchecker
# Successfully installed pyspellchecker-0.8.4
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install nltk
# Out:
# Collecting nltk
#   Downloading nltk-3.9.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting click (from nltk)
#   Downloading click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting joblib (from nltk)
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting regex>=2021.8.3 (from nltk)
#   Downloading regex-2025.11.3-cp312-cp312-win_amd64.whl.metadata (41 kB)
#      ---------------------------------------- 0.0/41.5 kB ? eta -:--:--
#      ---------------------------------------- 0.0/41.5 kB ? eta -:--:--
#      --------- ------------------------------ 10.2/41.5 kB ? eta -:--:--
#      ---------------------------- --------- 30.7/41.5 kB 325.1 kB/s eta 0:00:01
#      -------------------------------------- 41.5/41.5 kB 332.8 kB/s eta 0:00:00
# Collecting tqdm (from nltk)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
#      ---------------------------------------- 0.0/57.7 kB ? eta -:--:--
#      --------------------- ------------------ 30.7/57.7 kB ? eta -:--:--
#      ---------------------------------------- 57.7/57.7 kB 1.0 MB/s eta 0:00:00
# Requirement already satisfied: colorama in c:\users\r\appdata\roaming\python\python312\site-packages (from click->nltk) (0.4.6)
# Downloading nltk-3.9.2-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---- ----------------------------------- 0.2/1.5 MB 5.0 MB/s eta 0:00:01
#    ------------ --------------------------- 0.5/1.5 MB 5.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 0.9/1.5 MB 7.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 1.3/1.5 MB 7.7 MB/s eta 0:00:01
#    ---------------------------------------  1.5/1.5 MB 7.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 6.9 MB/s eta 0:00:00
# Downloading regex-2025.11.3-cp312-cp312-win_amd64.whl (277 kB)
#    ---------------------------------------- 0.0/277.1 kB ? eta -:--:--
#    ---------------------------------------  276.5/277.1 kB 8.6 MB/s eta 0:00:01
#    ---------------------------------------- 277.1/277.1 kB 5.8 MB/s eta 0:00:00
# Downloading click-8.3.1-py3-none-any.whl (108 kB)
#    ---------------------------------------- 0.0/108.3 kB ? eta -:--:--
#    ---------------------------------------- 108.3/108.3 kB 3.1 MB/s eta 0:00:00
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
#    ---------------------------------------- 0.0/78.5 kB ? eta -:--:--
#    ---------------------------------------- 78.5/78.5 kB 2.1 MB/s eta 0:00:00
# Installing collected packages: tqdm, regex, joblib, click, nltk
# Successfully installed click-8.3.1 joblib-1.5.3 nltk-3.9.2 regex-2025.11.3 tqdm-4.67.1
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script tqdm.exe is installed in 'c:\Users\r\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script nltk.exe is installed in 'c:\Users\r\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import re #regular expressions Python build in Regular Expression module(used for special scharacter removing , pattern matching , text cleaning)
from spellchecker import SpellChecker
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
text = "OMG!! 😱 I cant believed u getting the job!!! thats gr8! 🎉 I'm so happi for u! 😊 btw, I still remembr when we last met, u were so nervous abt the interview..lol 😂. Hope u come soon so we can hang out! 😎 Don't forget to call me 2moro!! 📞"

# %%
tokens =word_tokenize(text)# to create tokens from text
print(tokens)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 tokens =word_tokenize(text)
#       2 print(tokens)
#
# File c:\Users\r\AppData\Local\Programs\Python\Python312\Lib\site-packages\nltk\tokenize\__init__.py:142, in word_tokenize(text, language, preserve_line)
#     127 def word_tokenize(text, language="english", preserve_line=False):
#     128     """
#     129     Return a tokenized copy of *text*,
#     130     using NLTK's recommended word tokenizer
#    (...)    140     :type preserve_line: bool
#     141     """
# --> 142     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     143     return [
#     144         token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#     145     ]
#
# File c:\Users\r\AppData\Local\Programs\Python\Python312\Lib\site-packages\nltk\tokenize\__init__.py:119, in sent_tokenize(text, language)
#     109 def sent_tokenize(text, language="english"):
#     110     """
#     111     Return a sentence-tokenized copy of *text*,
#     112     using NLTK's recommended sentence tokenizer
#    (...)    117     :param language: the model name in the Punkt corpus
#     118     """
# --> 119     tokenizer = _get_punkt_tokenizer(language)
#     120     return tokenizer.tokenize(text)
#
# File c:\Users\r\AppData\Local\Programs\Python\Python312\Lib\site-packages\nltk\tokenize\__init__.py:105, in _get_punkt_tokenizer(language)
#      96 @functools.lru_cache
#      97 def _get_punkt_tokenizer(language="english"):
#      98     """
#      99     A constructor for the PunktTokenizer that utilizes
#     100     a lru cache for performance.
#    (...)    103     :type language: str
#     104     """
# --> 105     return PunktTokenizer(language)
#
# File c:\Users\r\AppData\Local\Programs\Python\Python312\Lib\site-packages\nltk\tokenize\punkt.py:1744, in PunktTokenizer.__init__(self, lang)
#    1742 def __init__(self, lang="english"):
#    1743     PunktSentenceTokenizer.__init__(self)
# -> 1744     self.load_lang(lang)
#
# File c:\Users\r\AppData\Local\Programs\Python\Python312\Lib\site-packages\nltk\tokenize\punkt.py:1749, in PunktTokenizer.load_lang(self, lang)
#    1746 def load_lang(self, lang="english"):
#    1747     from nltk.data import find
# -> 1749     lang_dir = find(f"tokenizers/punkt_tab/{lang}/")
#    1750     self._params = load_punkt_params(lang_dir)
#    1751     self._lang = lang
#
# File c:\Users\r\AppData\Local\Programs\Python\Python312\Lib\site-packages\nltk\data.py:579, in find(resource_name, paths)
#     577 sep = "*" * 70
#     578 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 579 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - 'C:\\Users\\r/nltk_data'
#     - 'c:\\Users\\r\\AppData\\Local\\Programs\\Python\\Python312\\nltk_data'
#     - 'c:\\Users\\r\\AppData\\Local\\Programs\\Python\\Python312\\share\\nltk_data'
#     - 'c:\\Users\\r\\AppData\\Local\\Programs\\Python\\Python312\\lib\\nltk_data'
#     - 'C:\\Users\\r\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************

# %%
nltk.download('punkt')# download punkt package for tokenization
nltk.download('stopwords')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\r\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\r\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\r\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
tokens =word_tokenize(text)
print(tokens)
# Out:
# ['OMG', '!', '!', '😱', 'I', 'cant', 'believed', 'u', 'getting', 'the', 'job', '!', '!', '!', 'thats', 'gr8', '!', '🎉', 'I', "'m", 'so', 'happi', 'for', 'u', '!', '😊', 'btw', ',', 'I', 'still', 'remembr', 'when', 'we', 'last', 'met', ',', 'u', 'were', 'so', 'nervous', 'abt', 'the', 'interview', '..', 'lol', '😂', '.', 'Hope', 'u', 'come', 'soon', 'so', 'we', 'can', 'hang', 'out', '!', '😎', 'Do', "n't", 'forget', 'to', 'call', 'me', '2moro', '!', '!', '📞']

# %%
stop_words = set(stopwords.words('english'))
filtered_tokens = [word for word in tokens if word.lower() not in stop_words]
print("Filtered Tokens:", filtered_tokens)
# Out:
# Filtered Tokens: ['OMG', '!', '!', '😱', 'cant', 'believed', 'u', 'getting', 'job', '!', '!', '!', 'thats', 'gr8', '!', '🎉', "'m", 'happi', 'u', '!', '😊', 'btw', ',', 'still', 'remembr', 'last', 'met', ',', 'u', 'nervous', 'abt', 'interview', '..', 'lol', '😂', '.', 'Hope', 'u', 'come', 'soon', 'hang', '!', '😎', "n't", 'forget', 'call', '2moro', '!', '!', '📞']

# %%
#remove a specific word
word_to_remove = "OMG" #WORD TO REMOVE
FILTERED_tokens = [word for word in filtered_tokens if word != word_to_remove]
print (FILTERED_tokens)
# Out:
# ['!', '!', '😱', 'cant', 'believed', 'u', 'getting', 'job', '!', '!', '!', 'thats', 'gr8', '!', '🎉', "'m", 'happi', 'u', '!', '😊', 'btw', ',', 'still', 'remembr', 'last', 'met', ',', 'u', 'nervous', 'abt', 'interview', '..', 'lol', '😂', '.', 'Hope', 'u', 'come', 'soon', 'hang', '!', '😎', "n't", 'forget', 'call', '2moro', '!', '!', '📞']

# %%
from nltk.stem import PorterStemmer
#intialize the porter stemmer
stemmer = PorterStemmer()
#stem each word

# %%
stammered_words = [stemmer.stem(word) for word in tokens]

# %%
print("Orignal Text:", text)
print("Stemmed Words:", stammed_words)
# Out:
# Orignal Text: OMG!! 😱 I cant believed u getting the job!!! thats gr8! 🎉 I'm so happi for u! 😊 btw, I still remembr when we last met, u were so nervous abt the interview..lol 😂. Hope u come soon so we can hang out! 😎 Don't forget to call me 2moro!! 📞
# Stemmed Words: ['omg', '!', '!', '😱', 'i', 'cant', 'believ', 'u', 'get', 'the', 'job', '!', '!', '!', 'that', 'gr8', '!', '🎉', 'i', "'m", 'so', 'happi', 'for', 'u', '!', '😊', 'btw', ',', 'i', 'still', 'remembr', 'when', 'we', 'last', 'met', ',', 'u', 'were', 'so', 'nervou', 'abt', 'the', 'interview', '..', 'lol', '😂', '.', 'hope', 'u', 'come', 'soon', 'so', 'we', 'can', 'hang', 'out', '!', '😎', 'do', "n't", 'forget', 'to', 'call', 'me', '2moro', '!', '!', '📞']

# %%
def stammedtext(text):
    tokens=word_tokenize(text)
    from nltk.stem import PorterStemmer
    stemmer = PorterStemmer()
    return [stemmer.stem(word) for word in tokens]

# %%
text2=  "The  children were running quickly,they will be playing untill evening."
stammedwords = stammedtext(text2)
print(stammedwords)
# Out:
# ['the', 'children', 'were', 'run', 'quickli', ',', 'they', 'will', 'be', 'play', 'until', 'even', '.']
