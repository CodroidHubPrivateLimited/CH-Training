# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
headers = {
"User-Agent": "Mozilla/5.0"
}

# %%
url = "https://finance.yahoo.com/markets/crypto/gainers/"
response = requests.get(url, headers=headers)

# %%
soup = BeautifulSoup(response.text, "html.parser")

# %%
table = soup.find("table")
if table is None:
  print("Table not found. The data may be loaded dynamically")
else:
  rows = table.find("tbody").find_all("tr")

# %%
data = []

# %%
for row in rows:
  cols = row.find_all("td")
  data.append([col.get_text(strip=True) for col in cols])
data
# Out:
# [['SSEAGULL-USD',
#   'SEAGULL SAM USD',
#   '',
#   '0.30+0.30(+634,591.60%)',
#   '+0.30',
#   '+634,591.60%',
#   '0',
#   '43,141',
#   '43,141',
#   '43,141',
#   '0',
#   '-99.55%',
#   '0.000.03'],
#  ['BBPX10720-USD',
#   'Black Phoenix USD',
#   '',
#   '2.82+2.81(+42,024.55%)',
#   '+2.81',
#   '+42,024.55%',
#   '0',
#   '7.141M',
#   '7.141M',
#   '7.141M',
#   '0',
#   '-99.49%',
#   '0.003.38'],
#  ['HHOOD37295-USD',
#   'Robinhood USD',
#   '',
#   '0.00+0.00(+6,303.14%)',
#   '+0.00',
#   '+6,303.14%',
#   '0',
#   '24,357',
#   '24,357',
#   '24,357',
#   '0',
#   '-97.52%',
#   '0.0014.20'],
#  ['FFELIS-USD',
#   'Felis USD',
#   '',
#   '0.00+0.00(+3,008.02%)',
#   '+0.00',
#   '+3,008.02%',
#   '0',
#   '65,287',
#   '65,287',
#   '65,287',
#   '0',
#   '-66.67%',
#   '0.000.00'],
#  ['DDOGO29570-USD',
#   'DOGO USD',
#   '',
#   '0.00+0.00(+2,739.62%)',
#   '+0.00',
#   '+2,739.62%',
#   '0',
#   '130,901',
#   '130,901',
#   '130,901',
#   '0',
#   '-40.00%',
#   '0.000.00'],
#  ['BBEER36413-USD',
#   'Beers USD',
#   '',
#   '0.08+0.07(+923.32%)',
#   '+0.07',
#   '+923.32%',
#   '0',
#   '970,175',
#   '970,175',
#   '970,175',
#   '0',
#   '+19.97%',
#   '0.000.54'],
#  ['ZZKP-USD',
#   'Panther Protocol USD',
#   '',
#   '0.10+0.09(+907.63%)',
#   '+0.09',
#   '+907.63%',
#   '0',
#   '330,237',
#   '330,237',
#   '330,237',
#   '0',
#   '-55.48%',
#   '0.000.03'],
#  ['RRATS34039-USD',
#   'rats (Ethereum) USD',
#   '',
#   '1,417,551,232.00+1,233,705,344.00(+671.05%)',
#   '+1,233,705,344.00',
#   '+671.05%',
#   '0',
#   '108,894',
#   '108,894',
#   '108,894',
#   '0',
#   '+83,279,504,998,400.00%',
#   '0.0054,855,844,000.00'],
#  ['BBOME33369-USD',
#   'Book of Meme 3.0 USD',
#   '',
#   '0.00+0.00(+643.31%)',
#   '+0.00',
#   '+643.31%',
#   '0',
#   '215,767',
#   '215,767',
#   '215,767',
#   '0',
#   '--',
#   '0.000.00'],
#  ['JJAI35584-USD',
#   'Japanese Akita Inu USD',
#   '',
#   '0.00+0.00(+607.96%)',
#   '+0.00',
#   '+607.96%',
#   '0',
#   '72,612',
#   '72,612',
#   '72,612',
#   '0',
#   '-30.00%',
#   '0.000.00'],
#  ['GGME32488-USD',
#   'GameStop Coin USD',
#   '',
#   '0.00+0.00(+563.11%)',
#   '+0.00',
#   '+563.11%',
#   '0',
#   '342,278',
#   '342,278',
#   '342,278',
#   '0',
#   '+37.46%',
#   '0.000.44'],
#  ['FFARTCOIN36328-USD',
#   'FARTCOIN (fartcoin.one) USD',
#   '',
#   '0.00+0.00(+525.93%)',
#   '+0.00',
#   '+525.93%',
#   '0',
#   '851,166',
#   '851,166',
#   '851,166',
#   '0',
#   '+523.19%',
#   '0.000.01'],
#  ['SSQUID34407-USD',
#   'Squid Game (squidgame.top) USD',
#   '',
#   '0.00+0.00(+499.67%)',
#   '+0.00',
#   '+499.67%',
#   '0',
#   '92,529',
#   '92,529',
#   '92,529',
#   '0',
#   '+15,550.00%',
#   '0.00676,828,220.00'],
#  ['TTURBO33724-USD',
#   'Turbo Trump USD',
#   '',
#   '0.23+0.19(+446.59%)',
#   '+0.19',
#   '+446.59%',
#   '0',
#   '95,442',
#   '95,442',
#   '95,442',
#   '0',
#   '+2,152,900.00%',
#   '0.007,500,205.50'],
#  ['TTRUMP31874-USD',
#   'PEPE USD',
#   '',
#   '0.00+0.00(+445.43%)',
#   '+0.00',
#   '+445.43%',
#   '0',
#   '263,194',
#   '263,194',
#   '263,194',
#   '0',
#   '-97.48%',
#   '0.000.00'],
#  ['PPEOPLE32079-USD',
#   'MAGA USD',
#   '',
#   '0.00+0.00(+432.26%)',
#   '+0.00',
#   '+432.26%',
#   '0',
#   '135,103',
#   '135,103',
#   '135,103',
#   '0',
#   '-96.60%',
#   '0.000.12'],
#  ['TTRUMP32865-USD',
#   'TRUMP AI USD',
#   '',
#   '0.00+0.00(+419.23%)',
#   '+0.00',
#   '+419.23%',
#   '0',
#   '349,072',
#   '349,072',
#   '349,072',
#   '0',
#   '+132,400.00%',
#   '0.000.37'],
#  ['CCOIN36756-USD',
#   '[Fake]COINBASE USD',
#   '',
#   '55.02+44.04(+401.37%)',
#   '+44.04',
#   '+401.37%',
#   '0',
#   '480,758',
#   '480,758',
#   '480,758',
#   '0',
#   '+4.33%',
#   '2.16423.75'],
#  ['MMOODENG33647-USD',
#   'Moo Deng (moodeng.sbs) USD',
#   '',
#   '0.00+0.00(+370.84%)',
#   '+0.00',
#   '+370.84%',
#   '0',
#   '74,147',
#   '74,147',
#   '74,147',
#   '0',
#   '-66.67%',
#   '0.000.00'],
#  ['PPEPE36287-USD',
#   'PEPE AI (pepeai.one) USD',
#   '',
#   '0.00+0.00(+337.14%)',
#   '+0.00',
#   '+337.14%',
#   '0',
#   '299,205',
#   '299,205',
#   '299,205',
#   '0',
#   '+53.33%',
#   '0.000.00'],
#  ['AAI16Z-USD',
#   'ai16z USD',
#   '',
#   '0.00+0.00(+327.95%)',
#   '+0.00',
#   '+327.95%',
#   '0',
#   '3.722M',
#   '3.722M',
#   '3.722M',
#   '0',
#   '-99.90%',
#   '0.002.48'],
#  ['MMSTR34245-USD',
#   'MSTR USD',
#   '',
#   '3.40+2.56(+307.59%)',
#   '+2.56',
#   '+307.59%',
#   '0',
#   '298,434',
#   '298,434',
#   '298,434',
#   '0',
#   '-75.14%',
#   '0.0018.17'],
#  ['BBROCCOLI35787-USD',
#   'Broccoli(broccolicoin.me) USD',
#   '',
#   '0.00+0.00(+301.26%)',
#   '+0.00',
#   '+301.26%',
#   '0',
#   '38,326',
#   '38,326',
#   '38,326',
#   '0',
#   '-94.56%',
#   '0.000.00'],
#  ['TTSLA37443-USD',
#   'Tesla (buytesla.net) USD',
#   '',
#   '182.18+136.71(+300.67%)',
#   '+136.71',
#   '+300.67%',
#   '0',
#   '382,070',
#   '382,070',
#   '382,070',
#   '0',
#   '-44.45%',
#   '2.81435.58'],
#  ['CCATS33323-USD',
#   'Cats (catshouse.live) USD',
#   '',
#   '0.00+0.00(+296.16%)',
#   '+0.00',
#   '+296.16%',
#   '0',
#   '316,775',
#   '316,775',
#   '316,775',
#   '0',
#   '-96.88%',
#   '0.000.00']]

# %%
print(data[0])
print(len(data[0]))
# Out:
# ['SSEAGULL-USD', 'SEAGULL SAM USD', '', '0.30+0.30(+634,591.60%)', '+0.30', '+634,591.60%', '0', '43,141', '43,141', '43,141', '0', '-99.55%', '0.000.03']
# 13

# %%
columns=[
"Symbol",
"Name",
" ",
"Price",
"Change",
"% Change",
"Market Cap",
"Volume ",
"Volume in currency( 24 hr)",
"Volume in all currencies(in 24 hr)",
"Circulating Supply",
"52 Weeks Change%",
" "
]

# %%
df = pd.DataFrame(data, columns=columns)
df
# Out:
#                 Symbol                            Name    \
# 0         SSEAGULL-USD                 SEAGULL SAM USD
# 1        BBPX10720-USD               Black Phoenix USD
# 2       HHOOD37295-USD                   Robinhood USD
# 3           FFELIS-USD                       Felis USD
# 4       DDOGO29570-USD                        DOGO USD
# 5       BBEER36413-USD                       Beers USD
# 6             ZZKP-USD            Panther Protocol USD
# 7       RRATS34039-USD             rats (Ethereum) USD
# 8       BBOME33369-USD            Book of Meme 3.0 USD
# 9        JJAI35584-USD          Japanese Akita Inu USD
# 10       GGME32488-USD               GameStop Coin USD
# 11  FFARTCOIN36328-USD     FARTCOIN (fartcoin.one) USD
# 12     SSQUID34407-USD  Squid Game (squidgame.top) USD
# 13     TTURBO33724-USD                 Turbo Trump USD
# 14     TTRUMP31874-USD                        PEPE USD
# 15    PPEOPLE32079-USD                        MAGA USD
# 16     TTRUMP32865-USD                    TRUMP AI USD
# 17      CCOIN36756-USD              [Fake]COINBASE USD
# 18   MMOODENG33647-USD      Moo Deng (moodeng.sbs) USD
# 19      PPEPE36287-USD        PEPE AI (pepeai.one) USD
# 20          AAI16Z-USD                       ai16z USD
# 21      MMSTR34245-USD                        MSTR USD
# 22  BBROCCOLI35787-USD   Broccoli(broccolicoin.me) USD
# 23      TTSLA37443-USD        Tesla (buytesla.net) USD
# 24      CCATS33323-USD       Cats (catshouse.live) USD
#
#                                           Price             Change  \
# 0                       0.30+0.30(+634,591.60%)              +0.30
# 1                        2.82+2.81(+42,024.55%)              +2.81
# 2                         0.00+0.00(+6,303.14%)              +0.00
# 3                         0.00+0.00(+3,008.02%)              +0.00
# 4                         0.00+0.00(+2,739.62%)              +0.00
# 5                           0.08+0.07(+923.32%)              +0.07
# 6                           0.10+0.09(+907.63%)              +0.09
# 7   1,417,551,232.00+1,233,705,344.00(+671.05%)  +1,233,705,344.00
# 8                           0.00+0.00(+643.31%)              +0.00
# 9                           0.00+0.00(+607.96%)              +0.00
# 10                          0.00+0.00(+563.11%)              +0.00
# 11                          0.00+0.00(+525.93%)              +0.00
# 12                          0.00+0.00(+499.67%)              +0.00
# 13                          0.23+0.19(+446.59%)              +0.19
# 14                          0.00+0.00(+445.43%)              +0.00
# 15                          0.00+0.00(+432.26%)              +0.00
# 16                          0.00+0.00(+419.23%)              +0.00
# 17                        55.02+44.04(+401.37%)             +44.04
# 18                          0.00+0.00(+370.84%)              +0.00
# 19                          0.00+0.00(+337.14%)              +0.00
# 20                          0.00+0.00(+327.95%)              +0.00
# 21                          3.40+2.56(+307.59%)              +2.56
# 22                          0.00+0.00(+301.26%)              +0.00
# 23                      182.18+136.71(+300.67%)            +136.71
# 24                          0.00+0.00(+296.16%)              +0.00
#
#         % Change Market Cap  Volume  Volume in currency( 24 hr)  \
# 0   +634,591.60%          0   43,141                     43,141
# 1    +42,024.55%          0   7.141M                     7.141M
# 2     +6,303.14%          0   24,357                     24,357
# 3     +3,008.02%          0   65,287                     65,287
# 4     +2,739.62%          0  130,901                    130,901
# 5       +923.32%          0  970,175                    970,175
# 6       +907.63%          0  330,237                    330,237
# 7       +671.05%          0  108,894                    108,894
# 8       +643.31%          0  215,767                    215,767
# 9       +607.96%          0   72,612                     72,612
# 10      +563.11%          0  342,278                    342,278
# 11      +525.93%          0  851,166                    851,166
# 12      +499.67%          0   92,529                     92,529
# 13      +446.59%          0   95,442                     95,442
# 14      +445.43%          0  263,194                    263,194
# 15      +432.26%          0  135,103                    135,103
# 16      +419.23%          0  349,072                    349,072
# 17      +401.37%          0  480,758                    480,758
# 18      +370.84%          0   74,147                     74,147
# 19      +337.14%          0  299,205                    299,205
# 20      +327.95%          0   3.722M                     3.722M
# 21      +307.59%          0  298,434                    298,434
# 22      +301.26%          0   38,326                     38,326
# 23      +300.67%          0  382,070                    382,070
# 24      +296.16%          0  316,775                    316,775
#
#    Volume in all currencies(in 24 hr) Circulating Supply  \
# 0                              43,141                  0
# 1                              7.141M                  0
# 2                              24,357                  0
# 3                              65,287                  0
# 4                             130,901                  0
# 5                             970,175                  0
# 6                             330,237                  0
# 7                             108,894                  0
# 8                             215,767                  0
# 9                              72,612                  0
# 10                            342,278                  0
# 11                            851,166                  0
# 12                             92,529                  0
# 13                             95,442                  0
# 14                            263,194                  0
# 15                            135,103                  0
# 16                            349,072                  0
# 17                            480,758                  0
# 18                             74,147                  0
# 19                            299,205                  0
# 20                             3.722M                  0
# 21                            298,434                  0
# 22                             38,326                  0
# 23                            382,070                  0
# 24                            316,775                  0
#
#            52 Weeks Change%
# 0                   -99.55%               0.000.03
# 1                   -99.49%               0.003.38
# 2                   -97.52%              0.0014.20
# 3                   -66.67%               0.000.00
# 4                   -40.00%               0.000.00
# 5                   +19.97%               0.000.54
# 6                   -55.48%               0.000.03
# 7   +83,279,504,998,400.00%  0.0054,855,844,000.00
# 8                        --               0.000.00
# 9                   -30.00%               0.000.00
# 10                  +37.46%               0.000.44
# 11                 +523.19%               0.000.01
# 12              +15,550.00%     0.00676,828,220.00
# 13           +2,152,900.00%       0.007,500,205.50
# 14                  -97.48%               0.000.00
# 15                  -96.60%               0.000.12
# 16             +132,400.00%               0.000.37
# 17                   +4.33%             2.16423.75
# 18                  -66.67%               0.000.00
# 19                  +53.33%               0.000.00
# 20                  -99.90%               0.002.48
# 21                  -75.14%              0.0018.17
# 22                  -94.56%               0.000.00
# 23                  -44.45%             2.81435.58
# 24                  -96.88%               0.000.00

# %%
df.to_csv("Top Gainer Crypto currency.csv")

# %%
df.shape
# Out:
# (25, 13)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                 Symbol                            Name    \
# 0         SSEAGULL-USD                 SEAGULL SAM USD
# 1        BBPX10720-USD               Black Phoenix USD
# 2       HHOOD37295-USD                   Robinhood USD
# 3           FFELIS-USD                       Felis USD
# 4       DDOGO29570-USD                        DOGO USD
# 5       BBEER36413-USD                       Beers USD
# 6             ZZKP-USD            Panther Protocol USD
# 7       RRATS34039-USD             rats (Ethereum) USD
# 8       BBOME33369-USD            Book of Meme 3.0 USD
# 9        JJAI35584-USD          Japanese Akita Inu USD
# 10       GGME32488-USD               GameStop Coin USD
# 11  FFARTCOIN36328-USD     FARTCOIN (fartcoin.one) USD
# 12     SSQUID34407-USD  Squid Game (squidgame.top) USD
# 13     TTURBO33724-USD                 Turbo Trump USD
# 14     TTRUMP31874-USD                        PEPE USD
# 15    PPEOPLE32079-USD                        MAGA USD
# 16     TTRUMP32865-USD                    TRUMP AI USD
# 17      CCOIN36756-USD              [Fake]COINBASE USD
# 18   MMOODENG33647-USD      Moo Deng (moodeng.sbs) USD
# 19      PPEPE36287-USD        PEPE AI (pepeai.one) USD
# 20          AAI16Z-USD                       ai16z USD
# 21      MMSTR34245-USD                        MSTR USD
# 22  BBROCCOLI35787-USD   Broccoli(broccolicoin.me) USD
# 23      TTSLA37443-USD        Tesla (buytesla.net) USD
# 24      CCATS33323-USD       Cats (catshouse.live) USD
#
#                                           Price             Change  \
# 0                       0.30+0.30(+634,591.60%)              +0.30
# 1                        2.82+2.81(+42,024.55%)              +2.81
# 2                         0.00+0.00(+6,303.14%)              +0.00
# 3                         0.00+0.00(+3,008.02%)              +0.00
# 4                         0.00+0.00(+2,739.62%)              +0.00
# 5                           0.08+0.07(+923.32%)              +0.07
# 6                           0.10+0.09(+907.63%)              +0.09
# 7   1,417,551,232.00+1,233,705,344.00(+671.05%)  +1,233,705,344.00
# 8                           0.00+0.00(+643.31%)              +0.00
# 9                           0.00+0.00(+607.96%)              +0.00
# 10                          0.00+0.00(+563.11%)              +0.00
# 11                          0.00+0.00(+525.93%)              +0.00
# 12                          0.00+0.00(+499.67%)              +0.00
# 13                          0.23+0.19(+446.59%)              +0.19
# 14                          0.00+0.00(+445.43%)              +0.00
# 15                          0.00+0.00(+432.26%)              +0.00
# 16                          0.00+0.00(+419.23%)              +0.00
# 17                        55.02+44.04(+401.37%)             +44.04
# 18                          0.00+0.00(+370.84%)              +0.00
# 19                          0.00+0.00(+337.14%)              +0.00
# 20                          0.00+0.00(+327.95%)              +0.00
# 21                          3.40+2.56(+307.59%)              +2.56
# 22                          0.00+0.00(+301.26%)              +0.00
# 23                      182.18+136.71(+300.67%)            +136.71
# 24                          0.00+0.00(+296.16%)              +0.00
#
#         % Change Market Cap  Volume  Volume in currency( 24 hr)  \
# 0   +634,591.60%          0   43,141                     43,141
# 1    +42,024.55%          0   7.141M                     7.141M
# 2     +6,303.14%          0   24,357                     24,357
# 3     +3,008.02%          0   65,287                     65,287
# 4     +2,739.62%          0  130,901                    130,901
# 5       +923.32%          0  970,175                    970,175
# 6       +907.63%          0  330,237                    330,237
# 7       +671.05%          0  108,894                    108,894
# 8       +643.31%          0  215,767                    215,767
# 9       +607.96%          0   72,612                     72,612
# 10      +563.11%          0  342,278                    342,278
# 11      +525.93%          0  851,166                    851,166
# 12      +499.67%          0   92,529                     92,529
# 13      +446.59%          0   95,442                     95,442
# 14      +445.43%          0  263,194                    263,194
# 15      +432.26%          0  135,103                    135,103
# 16      +419.23%          0  349,072                    349,072
# 17      +401.37%          0  480,758                    480,758
# 18      +370.84%          0   74,147                     74,147
# 19      +337.14%          0  299,205                    299,205
# 20      +327.95%          0   3.722M                     3.722M
# 21      +307.59%          0  298,434                    298,434
# 22      +301.26%          0   38,326                     38,326
# 23      +300.67%          0  382,070                    382,070
# 24      +296.16%          0  316,775                    316,775
#
#    Volume in all currencies(in 24 hr) Circulating Supply  \
# 0                              43,141                  0
# 1                              7.141M                  0
# 2                              24,357                  0
# 3                              65,287                  0
# 4                             130,901                  0
# 5                             970,175                  0
# 6                             330,237                  0
# 7                             108,894                  0
# 8                             215,767                  0
# 9                              72,612                  0
# 10                            342,278                  0
# 11                            851,166                  0
# 12                             92,529                  0
# 13                             95,442                  0
# 14                            263,194                  0
# 15                            135,103                  0
# 16                            349,072                  0
# 17                            480,758                  0
# 18                             74,147                  0
# 19                            299,205                  0
# 20                             3.722M                  0
# 21                            298,434                  0
# 22                             38,326                  0
# 23                            382,070                  0
# 24                            316,775                  0
#
#            52 Weeks Change%
# 0                   -99.55%               0.000.03
# 1                   -99.49%               0.003.38
# 2                   -97.52%              0.0014.20
# 3                   -66.67%               0.000.00
# 4                   -40.00%               0.000.00
# 5                   +19.97%               0.000.54
# 6                   -55.48%               0.000.03
# 7   +83,279,504,998,400.00%  0.0054,855,844,000.00
# 8                        --               0.000.00
# 9                   -30.00%               0.000.00
# 10                  +37.46%               0.000.44
# 11                 +523.19%               0.000.01
# 12              +15,550.00%     0.00676,828,220.00
# 13           +2,152,900.00%       0.007,500,205.50
# 14                  -97.48%               0.000.00
# 15                  -96.60%               0.000.12
# 16             +132,400.00%               0.000.37
# 17                   +4.33%             2.16423.75
# 18                  -66.67%               0.000.00
# 19                  +53.33%               0.000.00
# 20                  -99.90%               0.002.48
# 21                  -75.14%              0.0018.17
# 22                  -94.56%               0.000.00
# 23                  -44.45%             2.81435.58
# 24                  -96.88%               0.000.00  >

# %%
()
