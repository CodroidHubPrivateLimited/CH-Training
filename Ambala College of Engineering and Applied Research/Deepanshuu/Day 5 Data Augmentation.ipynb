# %% [markdown]
# ## DATA AUGMENTATION
#
# The process of artificially increasing the size and diversity of a dataset by creating new data points from exisiting data without changing their underlying meaning or lable.
#
#
#
#  ### Why
#         Reduce overfitting
#         Overcome limited dataset size
#         Handles class imbancle
#         Improves model generalization
#
# ### Augmentaion of Image Data
#         Rotation
#         Flipping
#         Cropping
#         Adding Noise
#
# ### Augmentaion of Text Data
#         Synonym replacement
#         Para pharasing
#         used in NLP
#
# ### Augmentaion of Synthetic Data
#         SMOTE
#         Bootstrapping
#         Noise Injection(Genrating Noise)

# %%
import numpy as np
import pandas as pd

np.random.seed(42)

n=500

df = pd.DataFrame({
    "Age": np.random.randint(20,26,n),
    "CGPA": np.round(np.random.uniform(6.0,9.5,n),2),
    "Internship_Counts": np.random.randint(0,4,n),
    "Technical_Score": np.random.randint(50,100,n),
    "Attendance_Percentage": np.random.randint(60,100,n)
})


# Target variable imbalanced

df['Placed'] = np.where(
    (df['CGPA']>7.5) & (df['Technical_Score']>70) , 'Yes', 'No')

# %%
df
# Out:
#      Age  CGPA  Internship_Counts  Technical_Score  Attendance_Percentage  \
# 0     23  6.61                  2               94                     74
# 1     24  7.52                  0               95                     65
# 2     22  7.39                  3               59                     79
# 3     24  8.16                  0               92                     73
# 4     24  8.22                  0               83                     61
# ..   ...   ...                ...              ...                    ...
# 495   23  7.27                  3               98                     83
# 496   21  8.03                  3               98                     78
# 497   21  8.21                  0               93                     64
# 498   24  6.05                  2               77                     91
# 499   23  8.32                  1               96                     60
#
#     Placed
# 0       No
# 1      Yes
# 2       No
# 3      Yes
# 4      Yes
# ..     ...
# 495     No
# 496    Yes
# 497    Yes
# 498     No
# 499    Yes
#
# [500 rows x 6 columns]

# %%
df.shape
# Out:
# (500, 6)

# %%
# Bootstrapping to augment data/ Resampling (+200 samples)
bootstrap=df.sample(n=200, replace=True, random_state=42)
df_aug = pd.concat([df, bootstrap], ignore_index=True)

# %%
df_aug
# Out:
#      Age  CGPA  Internship_Counts  Technical_Score  Attendance_Percentage  \
# 0     23  6.61                  2               94                     74
# 1     24  7.52                  0               95                     65
# 2     22  7.39                  3               59                     79
# 3     24  8.16                  0               92                     73
# 4     24  8.22                  0               83                     61
# ..   ...   ...                ...              ...                    ...
# 695   23  8.88                  3               94                     74
# 696   21  6.57                  2               77                     72
# 697   24  6.05                  1               52                     72
# 698   20  7.21                  1               92                     99
# 699   20  9.17                  1               73                     70
#
#     Placed
# 0       No
# 1      Yes
# 2       No
# 3      Yes
# 4      Yes
# ..     ...
# 695    Yes
# 696     No
# 697     No
# 698     No
# 699    Yes
#
# [700 rows x 6 columns]

# %%
noise=df.sample(n=150, random_state=42).copy()

noise['CGPA'] = noise['CGPA'] + np.random.normal(0,0.1,150)
noise['Technical_Score'] += np.random.randint(-3,4,150) 
noise['Attendance_Percentage'] += np.random.randint(0,2,150)

# Logical constraints
noise['CGPA'] = noise['CGPA'].clip(6.0,9.5)
noise['Technical_Score'] = noise['Technical_Score'].clip(50,100)
noise['Attendance_Percentage'] = noise['Attendance_Percentage'].clip(60,100)

df_aug = pd.concat([df_aug, noise], ignore_index=True)

# %%
df_aug
# Out:
#      Age      CGPA  Internship_Counts  Technical_Score  Attendance_Percentage  \
# 0     23  6.610000                  2               94                     74
# 1     24  7.520000                  0               95                     65
# 2     22  7.390000                  3               59                     79
# 3     24  8.160000                  0               92                     73
# 4     24  8.220000                  0               83                     61
# ..   ...       ...                ...              ...                    ...
# 845   20  7.779730                  3               70                     62
# 846   21  7.308858                  1               69                     99
# 847   20  7.282875                  0               50                     85
# 848   21  6.240868                  3               72                     62
# 849   21  6.977639                  3               71                     97
#
#     Placed
# 0       No
# 1      Yes
# 2       No
# 3      Yes
# 4      Yes
# ..     ...
# 845    Yes
# 846     No
# 847     No
# 848     No
# 849     No
#
# [850 rows x 6 columns]

# %%
# %pip install --upgrade scikit-learn imbalanced-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in c:\users\deepanshu saini\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (1.8.0)
# Requirement already satisfied: imbalanced-learn in c:\users\deepanshu saini\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (0.14.0)
# Requirement already satisfied: numpy>=1.24.1 in c:\users\deepanshu saini\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-learn) (2.3.5)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\deepanshu saini\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\deepanshu saini\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\deepanshu saini\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: C:\Users\Deepanshu Saini\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import sklearn
import imblearn

print("sklearn:", sklearn.__version__)
print("imblearn:", imblearn.__version__)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[9], line 2
#       1 import sklearn
# ----> 2 import imblearn
#       4 print("sklearn:", sklearn.__version__)
#       5 print("imblearn:", imblearn.__version__)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\imblearn\__init__.py:54
#      50     sys.stderr.write("Partial import of imblearn during the build process.\n")
#      51     # We are not importing the rest of scikit-learn during the build
#      52     # process, as it may not be compiled yet
#      53 else:
# ---> 54     from . import (
#      55         combine,
#      56         ensemble,
#      57         exceptions,
#      58         metrics,
#      59         model_selection,
#      60         over_sampling,
#      61         pipeline,
#      62         tensorflow,
#      63         under_sampling,
#      64         utils,
#      65     )
#      66     from ._version import __version__
#      67     from .base import FunctionSampler
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\imblearn\combine\__init__.py:5
#       1 """The :mod:`imblearn.combine` provides methods which combine
#       2 over-sampling and under-sampling.
#       3 """
# ----> 5 from ._smote_enn import SMOTEENN
#       6 from ._smote_tomek import SMOTETomek
#       8 __all__ = ["SMOTEENN", "SMOTETomek"]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\imblearn\combine\_smote_enn.py:12
#       9 from sklearn.base import clone
#      10 from sklearn.utils import check_X_y
# ---> 12 from ..base import BaseSampler
#      13 from ..over_sampling import SMOTE
#      14 from ..over_sampling.base import BaseOverSampler
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\imblearn\base.py:15
#      12 from sklearn.utils._metadata_requests import METHODS
#      13 from sklearn.utils.multiclass import check_classification_targets
# ---> 15 from .utils import check_sampling_strategy, check_target_type
#      16 from .utils._sklearn_compat import _fit_context, get_tags, validate_data
#      17 from .utils._validation import ArraysTransformer
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\imblearn\utils\__init__.py:6
#       1 """
#       2 The :mod:`imblearn.utils` module includes various utilities.
#       3 """
#       5 from ._docstring import Substitution
# ----> 6 from ._validation import (
#       7     check_neighbors_object,
#       8     check_sampling_strategy,
#       9     check_target_type,
#      10 )
#      12 __all__ = [
#      13     "check_neighbors_object",
#      14     "check_sampling_strategy",
#      15     "check_target_type",
#      16     "Substitution",
#      17 ]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\imblearn\utils\_validation.py:20
#      17 from sklearn.utils.multiclass import type_of_target
#      18 from sklearn.utils.validation import _num_samples
# ---> 20 from ..utils._sklearn_compat import _is_pandas_df, check_array
#      22 SAMPLING_KIND = (
#      23     "over-sampling",
#      24     "under-sampling",
#    (...)     27     "bypass",
#      28 )
#      29 TARGET_KIND = ("binary", "multiclass", "multilabel-indicator")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\imblearn\utils\_sklearn_compat.py:256
#     251 else:
#     252     from sklearn.utils.metadata_routing import (
#     253         _raise_for_params,  # noqa: F401
#     254         process_routing,  # noqa: F401
#     255     )
# --> 256     from sklearn.utils.validation import (
#     257         _is_fitted,  # noqa: F401
#     258         _is_pandas_df,  # noqa: F401
#     259     )
#     262 ########################################################################################
#     263 # Upgrading for scikit-learn 1.5
#     264 ########################################################################################
#     267 if sklearn_version < parse_version("1.5"):
#     268     # chunking
#     269     # extmath
#     270     # fixes
#
# ImportError: cannot import name '_is_pandas_df' from 'sklearn.utils.validation' (C:\Users\Deepanshu Saini\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\utils\validation.py)
