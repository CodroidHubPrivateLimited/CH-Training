# %% [markdown]
# # synthetic data creation

# %%
import pandas as pd
import numpy as np

# %%
data = {"Student_ID":[101,102,103,104,105],
        "Name":["Amit","Suman","Ravi","Anjali","Priya"],
        "Age":[23,22,24,23,22],
       "Marks":[85,90,78,92,88],
        "Department":["CSE","ECE","ME","CSE","ECE"]
        }

# %%
df = pd.DataFrame(data)
df
# Out:
#    Student_ID    Name  Age  Marks Department
# 0         101    Amit   23     85        CSE
# 1         102   Suman   22     90        ECE
# 2         103    Ravi   24     78         ME
# 3         104  Anjali   23     92        CSE
# 4         105   Priya   22     88        ECE

# %%
data = {"Student_ID":[101,102,103,104,None,],
        "Name":["Amit","Suman","Ravi",None,"Priya"],
        "Age":[23,22,24,23,24],
       "Marks":[85,90,78,92,"Pass"],
        "Department":["CSE","ECE","ME",None,"ECE"]
        }
df = pd.DataFrame(data)
df
# Out:
#    Student_ID   Name  Age Marks Department
# 0       101.0   Amit   23    85        CSE
# 1       102.0  Suman   22    90        ECE
# 2       103.0   Ravi   24    78         ME
# 3       104.0   None   23    92       None
# 4         NaN  Priya   24  Pass        ECE

# %%
import numpy as np
np.random.seed(42)
#n = 10
print(np.random.randint(1, 100, 10))
# Out:
# [52 93 15 72 61 21 83 87 75 75]

# %%
np.random.seed(41)
n = 1000
data = {"Student_ID": np.arange(101,101+n), "Age": np.random.randint(18,24,size=n), "Marks": np.random.randint(40,100,size=n), "Department": np.random.choice(["CSE","ECE","ME","ECE"], size=n)}
df = pd.DataFrame(data)
print(len(df))
# Out:
# 1000

# %%
df.head()
# Out:
#    Student_ID  Age  Marks Department
# 0         101   18     92        ECE
# 1         102   21     56        CSE
# 2         103   22     65         ME
# 3         104   20     46         ME
# 4         105   18     80        CSE

# %%
for col in ["Age","Marks","Department"]:
    df.loc[df.sample(frac=0.05).index, col] = np.nan

# add a small sample of duplicate rows
df = pd.concat([df, df.sample(20)], ignore_index=True)

# set some Age values to null
df.loc[df.sample(10).index, "Age"] = np.nan

df.head()
# Out:
#    Student_ID   Age  Marks Department
# 0         101  18.0   92.0        ECE
# 1         102  21.0   56.0        CSE
# 2         103  22.0   65.0         ME
# 3         104   NaN   46.0         ME
# 4         105  18.0   80.0        CSE

# %%
df.loc[df.sample(10).index, "Marks"] = np.nan

df.head()
# Out:
#    Student_ID   Age  Marks Department
# 0         101  18.0   92.0        ECE
# 1         102  21.0   56.0        CSE
# 2         103  22.0   65.0         ME
# 3         104   NaN   46.0         ME
# 4         105  18.0   80.0        CSE

# %%
df["Department"] = df["Department"].astype(str)
df.loc[df.sample(frac=0.1).index, "Department"] = df["Department"].str.lower()
df.head()
# Out:
#    Student_ID   Age  Marks Department
# 0         101  18.0   92.0        ECE
# 1         102  21.0   56.0        CSE
# 2         103  22.0   65.0         ME
# 3         104   NaN   46.0         ME
# 4         105  18.0   80.0        cse

# %%
df.tail()
# Out:
#       Student_ID   Age  Marks Department
# 1015         995   NaN   63.0        ECE
# 1016         152  22.0   90.0        CSE
# 1017         919  21.0   91.0        ece
# 1018         630   NaN   91.0        ECE
# 1019         783  21.0   97.0        ECE

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Student_ID  1020 non-null   int64
#  1   Age         957 non-null    float64
#  2   Marks       961 non-null    float64
#  3   Department  1020 non-null   object
# dtypes: float64(2), int64(1), object(1)
# memory usage: 32.0+ KB

# %%
df.isnull().sum()
# Out:
# Student_ID     0
# Age           63
# Marks         59
# Department     0
# dtype: int64

# %%
df.describe()
# Out:
#         Student_ID         Age       Marks
# count  1020.000000  957.000000  961.000000
# mean    599.191176   20.473354   69.703434
# std     288.302316    1.704219   17.432085
# min     101.000000   18.000000   40.000000
# 25%     350.750000   19.000000   54.000000
# 50%     598.500000   20.000000   70.000000
# 75%     847.250000   22.000000   85.000000
# max    1100.000000   23.000000   99.000000

# %%
pd.reset_option('display.max_rows')
df
# Out:
#       Student_ID   Age  Marks Department
# 0            101  18.0   92.0        ECE
# 1            102  21.0   56.0        CSE
# 2            103  22.0   65.0         ME
# 3            104   NaN   46.0         ME
# 4            105  18.0   80.0        cse
# ...          ...   ...    ...        ...
# 1015         995   NaN   63.0        ECE
# 1016         152  22.0   90.0        CSE
# 1017         919  21.0   91.0        ece
# 1018         630   NaN   91.0        ECE
# 1019         783  21.0   97.0        ECE
#
# [1020 rows x 4 columns]

# %%
df.iloc[500:600].to_string( )
# Out:
# '     Student_ID   Age  Marks Department\n500         601  21.0    NaN        ECE\n501         602  19.0   72.0         ME\n502         603  20.0   90.0         ME\n503         604  20.0   64.0        ECE\n504         605  21.0   67.0         ME\n505         606  22.0   90.0         ME\n506         607  21.0   49.0        ECE\n507         608  18.0   86.0        CSE\n508         609  22.0   66.0        ECE\n509         610  19.0   73.0        ECE\n510         611  22.0   72.0        CSE\n511         612  21.0   77.0        CSE\n512         613  21.0   59.0         ME\n513         614  21.0   71.0         ME\n514         615  23.0   77.0         ME\n515         616   NaN   71.0        ECE\n516         617  20.0   57.0        CSE\n517         618   NaN   97.0        ECE\n518         619  22.0    NaN        nan\n519         620  20.0   60.0        ECE\n520         621  20.0   45.0        ECE\n521         622  18.0   61.0         ME\n522         623  21.0   83.0        ECE\n523         624  18.0   56.0        ECE\n524         625  23.0   64.0        CSE\n525         626  18.0   45.0        nan\n526         627  22.0   90.0        ECE\n527         628  20.0   41.0         ME\n528         629  18.0   43.0        ECE\n529         630   NaN   91.0        ECE\n530         631  23.0   91.0        CSE\n531         632  18.0   54.0         me\n532         633   NaN   51.0        ECE\n533         634  19.0   66.0        CSE\n534         635  23.0   60.0        ECE\n535         636  23.0   61.0         ME\n536         637  23.0   69.0         ME\n537         638  23.0   70.0        ece\n538         639  19.0   61.0        CSE\n539         640   NaN   84.0        ECE\n540         641  19.0   93.0        ECE\n541         642  19.0   63.0        ECE\n542         643  19.0   72.0        ECE\n543         644  20.0   82.0        CSE\n544         645  18.0   61.0         ME\n545         646  23.0   64.0        ECE\n546         647  18.0   84.0        ECE\n547         648  21.0   65.0         ME\n548         649  21.0   60.0        ECE\n549         650  23.0   72.0         me\n550         651  21.0   82.0        nan\n551         652  19.0    NaN        ece\n552         653  21.0   78.0        ECE\n553         654  21.0   66.0        ECE\n554         655  19.0   51.0        ECE\n555         656  21.0   64.0        CSE\n556         657  20.0   62.0        ECE\n557         658  23.0   54.0        ECE\n558         659  19.0   71.0        ece\n559         660  20.0   64.0        ECE\n560         661  18.0   42.0        ECE\n561         662  20.0   88.0        ECE\n562         663  22.0   66.0        ECE\n563         664  18.0   89.0        ECE\n564         665  23.0   90.0        ECE\n565         666  18.0   66.0        ECE\n566         667  23.0    NaN        nan\n567         668  22.0   60.0        ECE\n568         669  23.0   75.0        CSE\n569         670  21.0   58.0        CSE\n570         671  18.0   73.0        nan\n571         672  22.0   76.0         ME\n572         673  18.0   90.0        CSE\n573         674  21.0   91.0        ECE\n574         675  19.0   81.0        ECE\n575         676   NaN   90.0        cse\n576         677  18.0   97.0        ECE\n577         678  22.0    NaN        ece\n578         679  23.0   43.0        CSE\n579         680  20.0   65.0        ece\n580         681  19.0    NaN        CSE\n581         682  23.0   52.0         ME\n582         683  18.0   97.0        CSE\n583         684  21.0   47.0        CSE\n584         685  21.0   59.0         ME\n585         686  21.0   89.0        ECE\n586         687  22.0   49.0        ece\n587         688  20.0   61.0        CSE\n588         689  18.0   86.0         ME\n589         690  21.0   61.0        ECE\n590         691  19.0   85.0         me\n591         692  22.0   52.0        ECE\n592         693  23.0   52.0        nan\n593         694  22.0   91.0         ME\n594         695  20.0   87.0         ME\n595         696  19.0   61.0        ECE\n596         697  23.0  ...

# %%
df.to_csv()
# Out:
# ',Student_ID,Age,Marks,Department\r\n0,101,18.0,92.0,ECE\r\n1,102,21.0,56.0,CSE\r\n2,103,22.0,65.0,ME\r\n3,104,,46.0,ME\r\n4,105,18.0,80.0,cse\r\n5,106,19.0,72.0,CSE\r\n6,107,21.0,,ECE\r\n7,108,19.0,88.0,ECE\r\n8,109,23.0,51.0,ECE\r\n9,110,20.0,41.0,ECE\r\n10,111,23.0,70.0,CSE\r\n11,112,22.0,77.0,ECE\r\n12,113,,73.0,ME\r\n13,114,21.0,50.0,ECE\r\n14,115,21.0,70.0,ME\r\n15,116,20.0,49.0,CSE\r\n16,117,18.0,57.0,CSE\r\n17,118,22.0,68.0,ECE\r\n18,119,23.0,52.0,ECE\r\n19,120,19.0,96.0,ECE\r\n20,121,21.0,77.0,ME\r\n21,122,22.0,82.0,ME\r\n22,123,18.0,46.0,CSE\r\n23,124,21.0,98.0,ECE\r\n24,125,22.0,81.0,CSE\r\n25,126,22.0,83.0,ece\r\n26,127,19.0,69.0,ME\r\n27,128,23.0,65.0,me\r\n28,129,20.0,,ME\r\n29,130,20.0,76.0,ECE\r\n30,131,19.0,48.0,cse\r\n31,132,22.0,40.0,ME\r\n32,133,23.0,95.0,ece\r\n33,134,21.0,80.0,CSE\r\n34,135,23.0,,ECE\r\n35,136,23.0,65.0,ME\r\n36,137,20.0,49.0,ECE\r\n37,138,20.0,48.0,ME\r\n38,139,20.0,71.0,nan\r\n39,140,22.0,97.0,ME\r\n40,141,21.0,85.0,ECE\r\n41,142,19.0,99.0,nan\r\n42,143,22.0,66.0,ECE\r\n43,144,22.0,72.0,ECE\r\n44,145,20.0,45.0,ECE\r\n45,146,21.0,66.0,nan\r\n46,147,22.0,60.0,ME\r\n47,148,23.0,78.0,ECE\r\n48,149,22.0,72.0,ECE\r\n49,150,23.0,43.0,CSE\r\n50,151,23.0,40.0,CSE\r\n51,152,22.0,90.0,CSE\r\n52,153,20.0,82.0,CSE\r\n53,154,23.0,83.0,ME\r\n54,155,22.0,86.0,ME\r\n55,156,,,ME\r\n56,157,23.0,81.0,me\r\n57,158,23.0,52.0,ECE\r\n58,159,18.0,57.0,CSE\r\n59,160,,92.0,ME\r\n60,161,,57.0,ME\r\n61,162,20.0,71.0,ME\r\n62,163,19.0,87.0,ECE\r\n63,164,22.0,46.0,CSE\r\n64,165,19.0,49.0,ECE\r\n65,166,19.0,45.0,ECE\r\n66,167,23.0,41.0,ME\r\n67,168,23.0,77.0,ECE\r\n68,169,20.0,48.0,CSE\r\n69,170,22.0,61.0,CSE\r\n70,171,22.0,,me\r\n71,172,23.0,42.0,ECE\r\n72,173,22.0,73.0,ME\r\n73,174,21.0,53.0,ECE\r\n74,175,18.0,92.0,ece\r\n75,176,21.0,52.0,ece\r\n76,177,23.0,93.0,cse\r\n77,178,23.0,61.0,nan\r\n78,179,20.0,54.0,CSE\r\n79,180,23.0,78.0,CSE\r\n80,181,23.0,50.0,CSE\r\n81,182,20.0,96.0,ECE\r\n82,183,23.0,48.0,ECE\r\n83,184,18.0,99.0,ME\r\n84,185,20.0,52.0,ECE\r\n85,186,23.0,95.0,ECE\r\n86,187,,67.0,ECE\r\n87,188,20.0,57.0,ME\r\n88,189,20.0,79.0,nan\r\n89,190,18.0,51.0,ECE\r\n90,191,19.0,52.0,CSE\r\n91,192,20.0,60.0,nan\r\n92,193,20.0,82.0,ECE\r\n93,194,18.0,76.0,ECE\r\n94,195,20.0,56.0,ME\r\n95,196,23.0,52.0,ME\r\n96,197,20.0,74.0,ME\r\n97,198,18.0,79.0,ECE\r\n98,199,18.0,50.0,me\r\n99,200,20.0,95.0,ECE\r\n100,201,19.0,89.0,ME\r\n101,202,22.0,50.0,ECE\r\n102,203,23.0,,CSE\r\n103,204,18.0,94.0,ECE\r\n104,205,22.0,58.0,ECE\r\n105,206,19.0,61.0,ME\r\n106,207,23.0,94.0,CSE\r\n107,208,19.0,70.0,ECE\r\n108,209,19.0,71.0,ECE\r\n109,210,20.0,74.0,CSE\r\n110,211,20.0,82.0,ECE\r\n111,212,19.0,75.0,ME\r\n112,213,19.0,52.0,ECE\r\n113,214,20.0,90.0,CSE\r\n114,215,19.0,,CSE\r\n115,216,18.0,47.0,ECE\r\n116,217,19.0,92.0,ECE\r\n117,218,,,CSE\r\n118,219,21.0,46.0,ece\r\n119,220,21.0,45.0,ECE\r\n120,221,20.0,52.0,ECE\r\n121,222,20.0,94.0,CSE\r\n122,223,19.0,42.0,ece\r\n123,224,21.0,59.0,ME\r\n124,225,18.0,58.0,CSE\r\n125,226,19.0,57.0,CSE\r\n126,227,19.0,94.0,ECE\r\n127,228,23.0,54.0,CSE\r\n128,229,,61.0,nan\r\n129,230,18.0,78.0,ME\r\n130,231,20.0,50.0,nan\r\n131,232,20.0,49.0,CSE\r\n132,233,22.0,77.0,CSE\r\n133,234,22.0,,ECE\r\n134,235,18.0,77.0,cse\r\n135,236,22.0,88.0,ECE\r\n136,237,19.0,70.0,ECE\r\n137,238,,66.0,ECE\r\n138,239,22.0,91.0,ME\r\n139,240,23.0,63.0,ECE\r\n140,241,21.0,61.0,CSE\r\n141,242,21.0,77.0,ECE\r\n142,243,18.0,67.0,ECE\r\n143,244,23.0,93.0,ME\r\n144,245,20.0,41.0,ECE\r\n145,246,21.0,51.0,ME\r\n146,247,,49.0,ECE\r\n147,248,,72.0,CSE\r\n148,249,20.0,84.0,ECE\r\n149,250,21.0,88.0,ECE\r\n150,251,19.0,51.0,ME\r\n151,252,20.0,91.0,CSE\r\n152,253,18.0,88.0,ECE\r\n153,254,20.0,92.0,CSE\r\n154,255,20.0,92.0,CSE\r\n155,256,19.0,58.0,ME\r\n156,257,19.0,54.0,ECE\r\n157,258,19.0,84.0,me\r\n158,259,22.0,89.0,nan\r\n159,260,22.0,90.0,ME\r\n160,261,22.0,95.0,ECE\r\n161,262,20.0,41.0,ME\r\n162,263,,56.0,ECE\r\n163,264,18.0,45.0,ECE\r\n164,265,18.0,92.0,ECE\r\n165,266,,45.0,ECE\r\n166,267,23.0,65.0,ECE\r\n167,268,20.0,78.0,ECE\r\n168, ...

# %%
df.to_csv('student.csv',index=False)
df
# Out:
#       Student_ID   Age  Marks Department
# 0            101  18.0   92.0        ECE
# 1            102  21.0   56.0        CSE
# 2            103  22.0   65.0         ME
# 3            104   NaN   46.0         ME
# 4            105  18.0   80.0        cse
# ...          ...   ...    ...        ...
# 1015         995   NaN   63.0        ECE
# 1016         152  22.0   90.0        CSE
# 1017         919  21.0   91.0        ece
# 1018         630   NaN   91.0        ECE
# 1019         783  21.0   97.0        ECE
#
# [1020 rows x 4 columns]

# %%
# %pip install openpyxl

df.to_excel("synthetic_data.xlsx", index=False)


df.head()
# Out:
# Collecting openpyxl
#   Obtaining dependency information for openpyxl from https://files.pythonhosted.org/packages/c0/da/977ded879c29cbd04de313843e76868e6e13408a94ed6b987245dc7c8506/openpyxl-3.1.5-py2.py3-none-any.whl.metadata
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Obtaining dependency information for et-xmlfile from https://files.pythonhosted.org/packages/c1/8b/5fe2cc11fee489817272089c4203e679c63b570a5aaeb18d852ae3cbba6a/et_xmlfile-2.0.0-py3-none-any.whl.metadata
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
#    ---------------------------------------- 0.0/250.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/250.9 kB ? eta -:--:--
#    ---- ---------------------------------- 30.7/250.9 kB 435.7 kB/s eta 0:00:01
#    ----------------- ---------------------- 112.6/250.9 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------------  245.8/250.9 kB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 250.9/250.9 kB 1.5 MB/s eta 0:00:00
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
#    Student_ID   Age  Marks Department
# 0         101  18.0   92.0        ECE
# 1         102  21.0   56.0        CSE
# 2         103  22.0   65.0         ME
# 3         104   NaN   46.0         ME
# 4         105  18.0   80.0        cse
