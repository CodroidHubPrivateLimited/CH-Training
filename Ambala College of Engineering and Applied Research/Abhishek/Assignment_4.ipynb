# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
headers = {
"User-Agent": "Mozilla/5.0"
}

# %%
url = "https://finance.yahoo.com/markets/mutualfunds/top/?start=0&count=25"

# %%
response = requests.get(url, headers=headers)

# %%
soup = BeautifulSoup(response.text, "html.parser")

# %%
table = soup.find("table")
if table is None:
	print("Table not found. The data may be loaded dynamically")
else:
	tbody = table.find("tbody")
	if tbody is None:
		print("No tbody found in the table.")
		rows = []
	else:
		rows = tbody.find_all("tr")

# %%
data = []

# %%
for row in rows:
	cols = row.find_all("td")
	data.append([col.get_text(strip=True) for col in cols])

# %%
data
# Out:
# [['FIKAX',
#   'Fidelity Advisor Energy Z',
#   '51.67+0.83(+1.63%)',
#   '+0.83',
#   '+1.63%',
#   '50.50',
#   '47.80',
#   '+8.58%',
#   '+11.19%',
#   '+10.55%',
#   '39.7752.55'],
#  ['FANIX',
#   'Fidelity Advisor Energy I',
#   '51.78+0.83(+1.63%)',
#   '+0.83',
#   '+1.63%',
#   '50.51',
#   '47.82',
#   '+8.55%',
#   '+11.06%',
#   '+10.64%',
#   '39.8152.56'],
#  ['FAOIX',
#   'Fidelity Advisor Overseas-I',
#   '34.27+0.52(+1.54%)',
#   '+0.52',
#   '+1.54%',
#   '36.34',
#   '37.02',
#   '-3.20%',
#   '+15.37%',
#   '+6.30%',
#   '30.8839.43'],
#  ['FAOSX',
#   'Fidelity Advisor Overseas-Z',
#   '34.16+0.51(+1.52%)',
#   '+0.51',
#   '+1.52%',
#   '36.25',
#   '36.94',
#   '-3.16%',
#   '+15.50%',
#   '+6.22%',
#   '30.8139.37'],
#  ['BIVSX',
#   'Invenomic Super Institutional',
#   '17.76+0.25(+1.43%)',
#   '+0.25',
#   '+1.43%',
#   '17.25',
#   '17.48',
#   '-0.35%',
#   '-12.01%',
#   '+2.42%',
#   '16.2418.87'],
#  ['INIIX',
#   'VanEck International Investors Gold I',
#   '39.79+0.50(+1.27%)',
#   '+0.50',
#   '+1.27%',
#   '34.84',
#   '27.10',
#   '+28.60%',
#   '+181.71%',
#   '+171.98%',
#   '14.6339.79'],
#  ['INIYX',
#   'VanEck International Investors Gold Y',
#   '28.66+0.36(+1.27%)',
#   '+0.36',
#   '+1.27%',
#   '25.45',
#   '19.82',
#   '+28.61%',
#   '+181.66%',
#   '+167.35%',
#   '10.7228.66'],
#  ['INIVX',
#   'VanEck International Investors Gold A',
#   '27.53+0.34(+1.25%)',
#   '+0.34',
#   '+1.25%',
#   '24.47',
#   '19.07',
#   '+28.50%',
#   '+180.86%',
#   '+166.51%',
#   '10.3327.53'],
#  ['MSEIX',
#   'AMG Veritas Asia Pacific I',
#   '93.38+1.08(+1.17%)',
#   '+1.08',
#   '+1.17%',
#   '92.50',
#   '80.92',
#   '+3.34%',
#   '+40.00%',
#   '+40.48%',
#   '58.9497.91'],
#  ['FGADX',
#   'Franklin Gold and Precious Metals Adv',
#   '53.59+0.58(+1.09%)',
#   '+0.58',
#   '+1.09%',
#   '48.08',
#   '36.89',
#   '+33.63%',
#   '+206.56%',
#   '+184.15%',
#   '18.8655.28'],
#  ['FGPMX',
#   'Franklin Gold and Precious Metals R6',
#   '54.58+0.59(+1.09%)',
#   '+0.59',
#   '+1.09%',
#   '48.91',
#   '37.52',
#   '+33.66%',
#   '+206.66%',
#   '+184.72%',
#   '19.1756.23'],
#  ['FRGOX',
#   'Franklin Gold and Precious Metals C',
#   '40.81+0.44(+1.09%)',
#   '+0.44',
#   '+1.09%',
#   '37.37',
#   '28.79',
#   '+33.28%',
#   '+203.43%',
#   '+175.37%',
#   '14.8243.02'],
#  ['FKRCX',
#   'Franklin Gold and Precious Metals A',
#   '48.31+0.52(+1.09%)',
#   '+0.52',
#   '+1.09%',
#   '43.68',
#   '33.56',
#   '+33.55%',
#   '+205.78%',
#   '+181.04%',
#   '17.1950.25'],
#  ['SEMTX',
#   'Hartford Schroders Emerging Mkts Eq SDR',
#   '23.34+0.24(+1.04%)',
#   '+0.24',
#   '+1.04%',
#   '22.74',
#   '20.00',
#   '+7.36%',
#   '+40.26%',
#   '+39.84%',
#   '15.2323.34'],
#  ['MICFX',
#   'Matthews China Instl',
#   '17.53+0.18(+1.04%)',
#   '+0.18',
#   '+1.04%',
#   '17.71',
#   '16.15',
#   '-2.39%',
#   '+31.22%',
#   '+30.14%',
#   '12.4518.71'],
#  ['SEMNX',
#   'Hartford Schroders Emerging Mkts Eq I',
#   '23.27+0.23(+1.00%)',
#   '+0.23',
#   '+1.00%',
#   '22.68',
#   '19.95',
#   '+7.28%',
#   '+40.10%',
#   '+39.68%',
#   '15.2023.27'],
#  ['SEMVX',
#   'Hartford Schroders Emerging Mkts Eq A',
#   '23.27+0.23(+1.00%)',
#   '+0.23',
#   '+1.00%',
#   '22.69',
#   '19.98',
#   '+7.19%',
#   '+39.59%',
#   '+39.17%',
#   '15.2423.27'],
#  ['MCHFX',
#   'Matthews China Fund',
#   '17.55+0.17(+0.98%)',
#   '+0.17',
#   '+0.98%',
#   '17.72',
#   '16.16',
#   '-1.00%',
#   '+32.37%',
#   '+30.10%',
#   '12.4618.71'],
#  ['FIDLX',
#   'Fidelity Advisor Large Cap Z',
#   '58.01+0.53(+0.92%)',
#   '+0.53',
#   '+0.92%',
#   '60.23',
#   '57.03',
#   '+3.58%',
#   '+19.84%',
#   '+12.93%',
#   '44.3064.04'],
#  ['FLCCX',
#   'Fidelity Advisor Large Cap C',
#   '45.07+0.41(+0.92%)',
#   '+0.41',
#   '+0.92%',
#   '47.00',
#   '44.79',
#   '+3.28%',
#   '+18.64%',
#   '+10.85%',
#   '34.9650.22'],
#  ['FALIX',
#   'Fidelity Advisor Large Cap I',
#   '58.05+0.52(+0.90%)',
#   '+0.52',
#   '+0.90%',
#   '60.27',
#   '57.09',
#   '+3.55%',
#   '+19.71%',
#   '+12.81%',
#   '44.3664.09'],
#  ['FALGX',
#   'Fidelity Advisor Large Cap M',
#   '53.61+0.48(+0.90%)',
#   '+0.48',
#   '+0.90%',
#   '55.65',
#   '52.76',
#   '+3.43%',
#   '+19.15%',
#   '+12.41%',
#   '41.0559.15'],
#  ['FZAEX',
#   'Fidelity Advisor Focused Em Mkts Z',
#   '42.45+0.38(+0.90%)',
#   '+0.38',
#   '+0.90%',
#   '41.75',
#   '37.31',
#   '+5.19%',
#   '+39.17%',
#   '+37.96%',
#   '28.4242.51'],
#  ['FALAX',
#   'Fidelity Advisor Large Cap A',
#   '53.66+0.48(+0.90%)',
#   '+0.48',
#   '+0.90%',
#   '55.76',
#   '52.89',
#   '+3.50%',
#   '+19.42%',
#   '+12.38%',
#   '41.1459.35'],
#  ['FIMKX',
#   'Fidelity Advisor Focused Em Mkts I',
#   '42.55+0.38(+0.90%)',
#   '+0.38',
#   '+0.90%',
#   '41.83',
#   '37.38',
#   '+5.15%',
#   '+38.98%',
#   '+37.93%',
#   '28.4942.58']]

# %%
print(data[0])
print(len(data[0]))
# Out:
# ['FIKAX', 'Fidelity Advisor Energy Z', '51.67+0.83(+1.63%)', '+0.83', '+1.63%', '50.50', '47.80', '+8.58%', '+11.19%', '+10.55%', '39.7752.55']
# 11

# %%
columns = [
"Symbol",
"Name",
"Last Price",
"Change",
"% Change",
"50 Days Average",
"200 Days Average ",
"3 Months Average",
"YTD return",
"52 Weeks Change%",
""
]

# %%
df = pd.DataFrame(data, columns=columns)
df
# Out:
#    Symbol                                     Name          Last Price Change  \
# 0   FIKAX                Fidelity Advisor Energy Z  51.67+0.83(+1.63%)  +0.83
# 1   FANIX                Fidelity Advisor Energy I  51.78+0.83(+1.63%)  +0.83
# 2   FAOIX              Fidelity Advisor Overseas-I  34.27+0.52(+1.54%)  +0.52
# 3   FAOSX              Fidelity Advisor Overseas-Z  34.16+0.51(+1.52%)  +0.51
# 4   BIVSX            Invenomic Super Institutional  17.76+0.25(+1.43%)  +0.25
# 5   INIIX    VanEck International Investors Gold I  39.79+0.50(+1.27%)  +0.50
# 6   INIYX    VanEck International Investors Gold Y  28.66+0.36(+1.27%)  +0.36
# 7   INIVX    VanEck International Investors Gold A  27.53+0.34(+1.25%)  +0.34
# 8   MSEIX               AMG Veritas Asia Pacific I  93.38+1.08(+1.17%)  +1.08
# 9   FGADX    Franklin Gold and Precious Metals Adv  53.59+0.58(+1.09%)  +0.58
# 10  FGPMX     Franklin Gold and Precious Metals R6  54.58+0.59(+1.09%)  +0.59
# 11  FRGOX      Franklin Gold and Precious Metals C  40.81+0.44(+1.09%)  +0.44
# 12  FKRCX      Franklin Gold and Precious Metals A  48.31+0.52(+1.09%)  +0.52
# 13  SEMTX  Hartford Schroders Emerging Mkts Eq SDR  23.34+0.24(+1.04%)  +0.24
# 14  MICFX                     Matthews China Instl  17.53+0.18(+1.04%)  +0.18
# 15  SEMNX    Hartford Schroders Emerging Mkts Eq I  23.27+0.23(+1.00%)  +0.23
# 16  SEMVX    Hartford Schroders Emerging Mkts Eq A  23.27+0.23(+1.00%)  +0.23
# 17  MCHFX                      Matthews China Fund  17.55+0.17(+0.98%)  +0.17
# 18  FIDLX             Fidelity Advisor Large Cap Z  58.01+0.53(+0.92%)  +0.53
# 19  FLCCX             Fidelity Advisor Large Cap C  45.07+0.41(+0.92%)  +0.41
# 20  FALIX             Fidelity Advisor Large Cap I  58.05+0.52(+0.90%)  +0.52
# 21  FALGX             Fidelity Advisor Large Cap M  53.61+0.48(+0.90%)  +0.48
# 22  FZAEX       Fidelity Advisor Focused Em Mkts Z  42.45+0.38(+0.90%)  +0.38
# 23  FALAX             Fidelity Advisor Large Cap A  53.66+0.48(+0.90%)  +0.48
# 24  FIMKX       Fidelity Advisor Focused Em Mkts I  42.55+0.38(+0.90%)  +0.38
#
#    % Change 50 Days Average 200 Days Average  3 Months Average YTD return  \
# 0    +1.63%           50.50             47.80           +8.58%    +11.19%
# 1    +1.63%           50.51             47.82           +8.55%    +11.06%
# 2    +1.54%           36.34             37.02           -3.20%    +15.37%
# 3    +1.52%           36.25             36.94           -3.16%    +15.50%
# 4    +1.43%           17.25             17.48           -0.35%    -12.01%
# 5    +1.27%           34.84             27.10          +28.60%   +181.71%
# 6    +1.27%           25.45             19.82          +28.61%   +181.66%
# 7    +1.25%           24.47             19.07          +28.50%   +180.86%
# 8    +1.17%           92.50             80.92           +3.34%    +40.00%
# 9    +1.09%           48.08             36.89          +33.63%   +206.56%
# 10   +1.09%           48.91             37.52          +33.66%   +206.66%
# 11   +1.09%           37.37             28.79          +33.28%   +203.43%
# 12   +1.09%           43.68             33.56          +33.55%   +205.78%
# 13   +1.04%           22.74             20.00           +7.36%    +40.26%
# 14   +1.04%           17.71             16.15           -2.39%    +31.22%
# 15   +1.00%           22.68             19.95           +7.28%    +40.10%
# 16   +1.00%           22.69             19.98           +7.19%    +39.59%
# 17   +0.98%           17.72             16.16           -1.00%    +32.37%
# 18   +0.92%           60.23             57.03           +3.58%    +19.84%
# 19   +0.92%           47.00             44.79           +3.28%    +18.64%
# 20   +0.90%           60.27             57.09           +3.55%    +19.71%
# 21   +0.90%           55.65             52.76           +3.43%    +19.15%
# 22   +0.90%           41.75             37.31           +5.19%    +39.17%
# 23   +0.90%           55.76             52.89           +3.50%    +19.42%
# 24   +0.90%           41.83             37.38           +5.15%    +38.98%
#
#    52 Weeks Change%
# 0           +10.55%  39.7752.55
# 1           +10.64%  39.8152.56
# 2            +6.30%  30.8839.43
# 3            +6.22%  30.8139.37
# 4            +2.42%  16.2418.87
# 5          +171.98%  14.6339.79
# 6          +167.35%  10.7228.66
# 7          +166.51%  10.3327.53
# 8           +40.48%  58.9497.91
# 9          +184.15%  18.8655.28
# 10         +184.72%  19.1756.23
# 11         +175.37%  14.8243.02
# 12         +181.04%  17.1950.25
# 13          +39.84%  15.2323.34
# 14          +30.14%  12.4518.71
# 15          +39.68%  15.2023.27
# 16          +39.17%  15.2423.27
# 17          +30.10%  12.4618.71
# 18          +12.93%  44.3064.04
# 19          +10.85%  34.9650.22
# 20          +12.81%  44.3664.09
# 21          +12.41%  41.0559.15
# 22          +37.96%  28.4242.51
# 23          +12.38%  41.1459.35
# 24          +37.93%  28.4942.58

# %%
df.to_csv("Top 25 Mutual Funds.csv")

# %%
df.shape
# Out:
# (25, 11)

# %%
df.describe()
# Out:
#        Symbol                       Name          Last Price Change % Change  \
# count      25                         25                  25     25       25
# unique     25                         25                  24     19       13
# top     FIKAX  Fidelity Advisor Energy Z  23.27+0.23(+1.00%)  +0.52   +0.90%
# freq        1                          1                   2      3        5
#
#        50 Days Average 200 Days Average  3 Months Average YTD return  \
# count               25                25               25         25
# unique              25                25               25         25
# top              50.50             47.80           +8.58%    +11.19%
# freq                 1                 1                1          1
#
#        52 Weeks Change%
# count                25          25
# unique               25          25
# top             +10.55%  39.7752.55
# freq                  1           1

# %%
df.sample(10)
# Out:
#    Symbol                                   Name          Last Price Change  \
# 0   FIKAX              Fidelity Advisor Energy Z  51.67+0.83(+1.63%)  +0.83
# 21  FALGX           Fidelity Advisor Large Cap M  53.61+0.48(+0.90%)  +0.48
# 22  FZAEX     Fidelity Advisor Focused Em Mkts Z  42.45+0.38(+0.90%)  +0.38
# 17  MCHFX                    Matthews China Fund  17.55+0.17(+0.98%)  +0.17
# 1   FANIX              Fidelity Advisor Energy I  51.78+0.83(+1.63%)  +0.83
# 11  FRGOX    Franklin Gold and Precious Metals C  40.81+0.44(+1.09%)  +0.44
# 3   FAOSX            Fidelity Advisor Overseas-Z  34.16+0.51(+1.52%)  +0.51
# 24  FIMKX     Fidelity Advisor Focused Em Mkts I  42.55+0.38(+0.90%)  +0.38
# 10  FGPMX   Franklin Gold and Precious Metals R6  54.58+0.59(+1.09%)  +0.59
# 5   INIIX  VanEck International Investors Gold I  39.79+0.50(+1.27%)  +0.50
#
#    % Change 50 Days Average 200 Days Average  3 Months Average YTD return  \
# 0    +1.63%           50.50             47.80           +8.58%    +11.19%
# 21   +0.90%           55.65             52.76           +3.43%    +19.15%
# 22   +0.90%           41.75             37.31           +5.19%    +39.17%
# 17   +0.98%           17.72             16.16           -1.00%    +32.37%
# 1    +1.63%           50.51             47.82           +8.55%    +11.06%
# 11   +1.09%           37.37             28.79          +33.28%   +203.43%
# 3    +1.52%           36.25             36.94           -3.16%    +15.50%
# 24   +0.90%           41.83             37.38           +5.15%    +38.98%
# 10   +1.09%           48.91             37.52          +33.66%   +206.66%
# 5    +1.27%           34.84             27.10          +28.60%   +181.71%
#
#    52 Weeks Change%
# 0           +10.55%  39.7752.55
# 21          +12.41%  41.0559.15
# 22          +37.96%  28.4242.51
# 17          +30.10%  12.4618.71
# 1           +10.64%  39.8152.56
# 11         +175.37%  14.8243.02
# 3            +6.22%  30.8139.37
# 24          +37.93%  28.4942.58
# 10         +184.72%  19.1756.23
# 5          +171.98%  14.6339.79

# %%
df.head()
# Out:
#   Symbol                           Name          Last Price Change % Change  \
# 0  FIKAX      Fidelity Advisor Energy Z  51.67+0.83(+1.63%)  +0.83   +1.63%
# 1  FANIX      Fidelity Advisor Energy I  51.78+0.83(+1.63%)  +0.83   +1.63%
# 2  FAOIX    Fidelity Advisor Overseas-I  34.27+0.52(+1.54%)  +0.52   +1.54%
# 3  FAOSX    Fidelity Advisor Overseas-Z  34.16+0.51(+1.52%)  +0.51   +1.52%
# 4  BIVSX  Invenomic Super Institutional  17.76+0.25(+1.43%)  +0.25   +1.43%
#
#   50 Days Average 200 Days Average  3 Months Average YTD return  \
# 0           50.50             47.80           +8.58%    +11.19%
# 1           50.51             47.82           +8.55%    +11.06%
# 2           36.34             37.02           -3.20%    +15.37%
# 3           36.25             36.94           -3.16%    +15.50%
# 4           17.25             17.48           -0.35%    -12.01%
#
#   52 Weeks Change%
# 0          +10.55%  39.7752.55
# 1          +10.64%  39.8152.56
# 2           +6.30%  30.8839.43
# 3           +6.22%  30.8139.37
# 4           +2.42%  16.2418.87

# %%
df.isnull().sum()
# Out:
# Symbol               0
# Name                 0
# Last Price           0
# Change               0
# % Change             0
# 50 Days Average      0
# 200 Days Average     0
# 3 Months Average     0
# YTD return           0
# 52 Weeks Change%     0
#                      0
# dtype: int64
