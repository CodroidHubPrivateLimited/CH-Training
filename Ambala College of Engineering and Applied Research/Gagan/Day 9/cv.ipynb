# %%
import cv2

# %%
import numpy as np

# %%
import sys

# %%
print("you have successfully installed openCV version "+cv2.__version__)
print("Your version of python is" +sys.version)
# Out:
# you have successfully installed openCV version 4.12.0
# Your version of python is3.12.7 | packaged by Anaconda, Inc. | (main, Oct  4 2024, 13:17:27) [MSC v.1929 64 bit (AMD64)]

# %%
img=cv2.imread("Image.jpeg")
if img is None:
	print("Error: Could not load image. Please check the file path.")
else:
	cv2.imshow("Image", img)
	cv2.waitKey(0)
	cv2.destroyAllWindows()

# %%
print(img[:,:,2].shape)
# Out:
# (600, 800)

# %%
import matplotlib.pyplot as plt

# %%
img_1 =cv2.imread("Image.jpeg")
img_1 =cv2.cvtColor(img_1,cv2.COLOR_BGR2RGB)
plt.imshow(img_1)
plt.title('image001')
plt.axis('off')
plt.show()

# %%
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Cannot open camera")
else:
    while True:
        ret, frame = cap.read()
        if not ret:
            print("Can't receive frame (stream end?). Exiting ...")
            break
        cv2.imshow('Webcam', frame)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
        if cv2.getWindowProperty('Webcam', cv2.WND_PROP_VISIBLE) < 1:
            break
    cap.release()
    cv2.destroyAllWindows()

# %%
print(img.shape)
# Out:
# (600, 800, 3)

# %%
print(img[0,400])
# Out:
# [255 255 255]

# %%
print(img[300,400])
# Out:
# [  0   0 254]

# %%
img_1 =cv2.imread("Image.jpeg")
grey =cv2.cvtColor(img_1,cv2.COLOR_BGR2GRAY)
cv2.imshow("Grey", grey)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img_1 =cv2.imread("Image.jpeg")
img_1 =cv2.cvtColor(img_1,cv2.COLOR_BGR2GRAY)
plt.imshow(img_1, camp="grey", interpolation="bicubic")
plt.title('image001')
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 3
#       1 img_1 =cv2.imread("Image.jpeg")
#       2 img_1 =cv2.cvtColor(img_1,cv2.COLOR_BGR2GRAY)
# ----> 3 plt.imshow(img_1, camp="grey", interpolation="bicubic")
#       4 plt.title('image001')
#       5 plt.axis('off')
#
# File c:\Users\BOPARAI\anaconda3\Lib\site-packages\matplotlib\pyplot.py:3562, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    3541 @_copy_docstring_and_deprecators(Axes.imshow)
#    3542 def imshow(
#    3543     X: ArrayLike | PIL.Image.Image,
#    (...)
#    3560     **kwargs,
#    3561 ) -> AxesImage:
# -> 3562     __ret = gca().imshow(
#    3563         X,
#    3564         cmap=cmap,
#    3565         norm=norm,
#    3566         aspect=aspect,
# ...
