# %%
import numpy as np
import pandas as pd

# %%
np.random.seed(0)
n = 500
df = pd.DataFrame({
    "Age": np.random.randint(18, 60, size=n),
    "CGPA": np.random.randint(0, 120, size=n),
    "Internships_Count": np.random.randint(0, 10, size=n),
    "Technical_Score": np.random.randint(0, 120, size=n),
    "Attendance_Percentage": np.random.randint(50, 101, size=n),
})
df
# Out:
#      Age  CGPA  Internships_Count  Technical_Score  Attendance_Percentage
# 0     18    90                  6               26                     86
# 1     21    51                  1               84                     78
# 2     21   102                  7                5                     50
# 3     57    46                  7               88                     60
# 4     27    80                  0               17                     63
# ..   ...   ...                ...              ...                    ...
# 495   44    43                  3                9                     80
# 496   40   110                  9               85                     62
# 497   30    69                  5               66                     84
# 498   33   118                  4                9                     53
# 499   52    19                  0              110                     90
#
# [500 rows x 5 columns]

# %%
np.random.seed(42)
n = 230
data={
    'student_ID': np.arange(100,150,n),
    'age': np.random.randint(18, 30,n),
    'marks': np.random.randint(40, 100, n),
    'grade': np.random.choice(['A', 'B', 'C'],n),
    'department': np.random.choice(["Physics", "Chemistry", "Mathematics"],n)

}

# %%
df
# Out:
#      Age  CGPA  Internships_Count  Technical_Score  Attendance_Percentage
# 0     18    90                  6               26                     86
# 1     21    51                  1               84                     78
# 2     21   102                  7                5                     50
# 3     57    46                  7               88                     60
# 4     27    80                  0               17                     63
# ..   ...   ...                ...              ...                    ...
# 495   44    43                  3                9                     80
# 496   40   110                  9               85                     62
# 497   30    69                  5               66                     84
# 498   33   118                  4                9                     53
# 499   52    19                  0              110                     90
#
# [500 rows x 5 columns]

# %%
df =  pd.DataFrame(data)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_50076/2835739962.py in <module>
# ----> 1 df =  pd.DataFrame(data)
#       2 df
#
# c:\Users\DELL\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615         elif isinstance(data, ma.MaskedArray):
#     616             import numpy.ma.mrecords as mrecords
#
# c:\Users\DELL\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     462         # TODO: can we get rid of the dt64tz special case above?
#     463
# --> 464     return arrays_to_mgr(
# ...
