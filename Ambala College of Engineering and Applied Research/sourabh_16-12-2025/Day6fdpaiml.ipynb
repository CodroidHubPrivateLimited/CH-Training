# %% [markdown]
# ##PYTHON BASICS

# %% [markdown]
# ##what is python?
# high level
# programming language
# interpreted
# Dynamically typed
# object_oriented
#
# what is high level language whichis understood by user.
#
#
# syntax framing
#
# semantic means meaning or  logically correct
#
#
# programming paradigm
#
# pogramming is wrting programs
#
# the diff ways you can write programs is called programming paradigm
#
# structure
# function
# procedural
#
# oops- class-properities, functionalities
#
# generic represnetaion of object is called class
#
#
# python support multi programming paradigm

# %%
num1=10
type(num1)
# Out:
# int

# %%
print(num1.__class__)
# Out:
# <class 'int'>

# %%
print("hello world")
# Out:
# hello world

# %%
"hello world"
# Out:
# 'hello world'

# %%
print(20+30)  #print()
# Out:
# 50

# %%
20+30
# Out:
# 50

# %%
#whether this is possoible in C PROGRAMMING LANGUAGE

# %%
pr=print("hello world")
print(pr)
# Out:
# hello world
# None

# %%
type(pr)
# Out:
# NoneType

# %%
sum=print(10+20)
# Out:
# 30

# %%
type(sum)
# Out:
# NoneType

# %%
10-20
# Out:
# -10

# %%
10+20
# Out:
# 30

# %%
_+20
# Out:
# 50

# %%
_+20
# Out:
# 70

# %%
_-20
# Out:
# 50

# %%
_*2
# Out:
# 100

# %%
#print other assignmenet oprators and above

# %%
print("A","B",sep="!",end="!\n")
# Out:
# A!B!

# %%
print("A","B",sep=",",end="!\n")
# Out:
# A,B!

# %%
num3=40
num4=50
print("num3:",num3, "num4",num4)
# Out:
# num3: 40 num4 50

# %%
print(num3,num4)
# Out:
# 40 50

# %%
#print + string formatting

price=200
tax=18
print("the total amount is:",price+tax)
# Out:
# the total amount is: 218

# %%
#print + string formatting

price=200
tax=18
print(f"the total amount is {price+tax}")
# Out:
# the total amount is 218

# %%
pi=3.1415
print(f"{pi:2f}")
# Out:
# 3.141500

# %%
pi=3.1415
print(f"{pi:.03f}")
# Out:
# 3.142

# %%
pi=3
print(f"{pi:03d}")
# Out:
# 003

# %%
name="Devashish"
print(f"{name:>20}")
# Out:
#            Devashish

# %%
name="Devashish"
print(f"{name:>10}")
# Out:
#  Devashish

# %%
name="Devashish"
print(f"{name:<10}")
# Out:
# Devashish

# %%
name="Devashish"
print(f"{name:^20}")
# Out:
#      Devashish

# %%
class student:
    def __init__(self,name,marks):
        self.name=name
        self.marks=marks

    def display(self):
        print(f"Name:{self.name},marks:{self.marks}")

# %%
stud1=student(43,90)

stud1.display()
# Out:
# Name:43,marks:90

# %%
class Student:
    def __init__(self,name: str,marks:int):
        self.name=name
        self.marks=marks

    def display(self)->str:
        #print(f"Name:{self.name},marks:{self.marks}")
        return f"Name:{self.name},Marks:{self.marks}"

# %%
stud2=student(45,95)
print(stud2.display())
# Out:
# Name:45,marks:95
# None

# %%
type(stud2)
# Out:
# __main__.student

# %%
class Student:
    def __init__(self,name: str,marks:int):
        if not isinstance(name,str):
            raise TypeError("name must be string")
        if not isinstance(marks,int):
            raise TypeError("makrs should be integer")
        self.name=name
        self.marks=marks

    def display(self)->str:
        #print(f"Name:{self.name},marks:{self.marks}")
        return f"Name:{self.name},Marks:{self.marks}"

# %%
stud2 =Student("SOURABH",98)
print(stud2.display())
# Out:
# Name:SOURABH,Marks:98

# %%
num5=10
type(num5)
# Out:
# int

# %%
num5=str(num1)
type(num5)
# Out:
# str

# %%
class student:
    def __init__(self,name,marks):
        self.name=str(name)
        self.marks=int(marks)

    def display(self):
        print(f"Name:{self.name},marks:{self.marks}")

# %%
student1=student("name",45)
student.display()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[68], line 2
#       1 student1=student("name",45)
# ----> 2 student.display()
#
# TypeError: display() missing 1 required positional argument: 'self'

# %%
student1=student("name",45)
student1.display()
# Out:
# Name:name,marks:45

# %%
#Assert keyword in python = Debugging Perspective

#sntax assert condition ! assert conditon , "error message"

# %%
marks1=-60
assert marks1>0
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[71], line 2
#       1 marks1=-60
# ----> 2 assert marks1>0
#
# AssertionError:

# %%
marks1=-60
assert marks1>0, "marks is less than 0"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[72], line 2
#       1 marks1=-60
# ----> 2 assert marks1>0, "marks is less than 0"
#
# AssertionError: marks is less than 0
