# %%
10+20
# Out:
# 30

# %%
_+20
# Out:
# 50

# %%
_-10
# Out:
# 40

# %%
_/2
# Out:
# 20.0

# %%
_*3
# Out:
# 60.0

# %%
print("A","B", sep="!" , end="!\n")
# Out:
# A!B!

# %%
num3 = 15
num4 = 4
print("num3:", num3, "num4:", num4 )
# Out:
# num3: 15 num4: 4

# %%
price = 200
tax = 18
print("total price:", price + tax )
# Out:
# total price: 218

# %%
pi = 3.141567
print(f"{pi:.4f}")
# Out:
# 3.1416

# %%
pi=3
print(f"{pi:03d}")
# Out:
# 003

# %%
name = "Abhishek"
print(f"{name:^80}")
# Out:
#                                     Abhishek

# %%
class student:
    def __init__(self, name, marks):
        self.name = name
        self.marks = marks
    def display(self):
        print(f"Name: {self.name}, Marks: {self.marks}")

# %%
stud1 = student("Abhishek", 95)
stud1.display()
# Out:
# Name: Abhishek, Marks: 95

# %%
class Student:
    def __init__(self, name: str, marks: int):
        self.name = name
        self.marks = marks
    def display(self)->str:
        
        return f"Name: {self.name}, Marks: {self.marks}"

# %%
print(stud1.display())
# Out:
# Name: Abhishek, Marks: 95
# None

# %%
stud2 = Student(43, 98)
print(stud2.display())
# Out:
# Name: 43, Marks: 98

# %%
class Student:
    def __init__(self, name: str, marks: int):
        if not isinstance(name, str):
            raise TypeError("Name must be a string")
        if not isinstance(marks, int):
            raise TypeError("Marks must be an integer")
        self.name = name
        self.marks = marks
    def display(self)->str:
        
        return f"Name: {self.name}, Marks: {self.marks}"

# %%
stud2 = Student("def", "98")
print(stud2.display())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 stud2 = Student("def", "98")
#       2 print(stud2.display())
#
# Cell In[30], line 6, in Student.__init__(self, name, marks)
#       4     raise TypeError("Name must be a string")
#       5 if not isinstance(marks, int):
# ----> 6     raise TypeError("Marks must be an integer")
#       7 self.name = name
#       8 self.marks = marks
#
# TypeError: Marks must be an integer

# %%
marks1=60
assert marks1 > 0

# %%
marks1 = -10
assert marks1 > 0, "less than zero error"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[37], line 2
#       1 marks1 = -10
# ----> 2 assert marks1 > 0, "less than zero error"
#
# AssertionError: less than zero error

# %%
class Student:
    def __init__(self, name: str, marks: int):
        assert isinstance(name, str), "Name must be a string"
        self.name = name
        self.marks = marks
        assert isinstance(marks, int), "Marks must be an integer"   
    def display(self)->str:
        
        return f"Name: {self.name}, Marks: {self.marks}"

# %%
s1 = Student(56, 90)
s1.display()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 s1 = Student(56, 90)
#       2 s1.display()
#
# Cell In[38], line 3, in Student.__init__(self, name, marks)
#       2 def __init__(self, name: str, marks: int):
# ----> 3     assert isinstance(name, str), "Name must be a string"
#       4     assert isinstance(marks, int), "Marks must be an integer"
#
# AssertionError: Name must be a string
