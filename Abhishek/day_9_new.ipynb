# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\abhishek\appdata\local\programs\python\python311\lib\site-packages (3.9.2)
# Requirement already satisfied: click in c:\users\abhishek\appdata\local\programs\python\python311\lib\site-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in c:\users\abhishek\appdata\roaming\python\python311\site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\abhishek\appdata\local\programs\python\python311\lib\site-packages (from nltk) (2025.11.3)
# Requirement already satisfied: tqdm in c:\users\abhishek\appdata\local\programs\python\python311\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\abhishek\appdata\roaming\python\python311\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyspellchecker
# Out:
# Requirement already satisfied: pyspellchecker in c:\users\abhishek\appdata\local\programs\python\python311\lib\site-packages (0.8.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import re

from spellchecker import SpellChecker
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 4
#       1 import re
#       3 from spellchecker import SpellChecker
# ----> 4 import nltk
#       5 from nltk.tokenize import word_tokenize
#       6 from nltk.corpus import stopwords
#
# File c:\Users\Abhishek\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\__init__.py:147
#     141 from nltk.jsontags import *
#     143 ###########################################################
#     144 # PACKAGES
#     145 ###########################################################
# --> 147 from nltk.chunk import *
#     148 from nltk.classify import *
#     149 from nltk.inference import *
#
# File c:\Users\Abhishek\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\chunk\__init__.py:155
#       1 # Natural Language Toolkit: Chunkers
#       2 #
#       3 # Copyright (C) 2001-2025 NLTK Project
#    (...)      7 # For license information, see LICENSE.TXT
#       8 #
#      10 """
#      11 Classes and interfaces for identifying non-overlapping linguistic
#      12 groups (such as base noun phrases) in unrestricted text.  This task is
#    (...)    152      pattern is valid.
#     153 """
# --> 155 from nltk.chunk.api import ChunkParserI
#     156 from nltk.chunk.named_entity import Maxent_NE_Chunker
#     157 from nltk.chunk.regexp import RegexpChunkParser, RegexpParser
#
# File c:\Users\Abhishek\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\chunk\api.py:13
#       1 # Natural Language Toolkit: Chunk parsing API
#       2 #
#       3 # Copyright (C) 2001-2025 NLTK Project
#    (...)     10 ##  Chunk Parser Interface
#      11 ##//////////////////////////////////////////////////////
# ---> 13 from nltk.chunk.util import ChunkScore
#      14 from nltk.internals import deprecated
#      15 from nltk.parse import ParserI
#
# File c:\Users\Abhishek\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\chunk\util.py:12
#       9 import re
#      11 from nltk.metrics import accuracy as _accuracy
# ---> 12 from nltk.tag.mapping import map_tag
#      13 from nltk.tag.util import str2tuple
#      14 from nltk.tree import Tree
#
# File c:\Users\Abhishek\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\tag\__init__.py:72
#      70 from nltk.tag.api import TaggerI
#      71 from nltk.tag.util import str2tuple, tuple2str, untag
# ---> 72 from nltk.tag.sequential import (
#      73     SequentialBackoffTagger,
#      74     ContextTagger,
#      75     DefaultTagger,
#      76     NgramTagger,
#      77     UnigramTagger,
#      78     BigramTagger,
#      79     TrigramTagger,
#      80     AffixTagger,
#      81     RegexpTagger,
#      82     ClassifierBasedTagger,
#      83     ClassifierBasedPOSTagger,
#      84 )
#      85 from nltk.tag.brill import BrillTagger
#      86 from nltk.tag.brill_trainer import BrillTaggerTrainer
#
# File c:\Users\Abhishek\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\tag\sequential.py:26
#      23 from typing import List, Optional, Tuple
#      25 from nltk import jsontags
# ---> 26 from nltk.classify import NaiveBayesClassifier
#      27 from nltk.probability import ConditionalFreqDist
#      28 from nltk.tag.api import FeaturesetTaggerI, TaggerI
#
# File c:\Users\Abhishek\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\classify\__init__.py:97
#      95 from nltk.classify.positivenaivebayes import PositiveNaiveBayesClassifier
#      96 from nltk.classify.rte_classify import RTEFeatureExtractor, rte_classifier, rte_features
# ---> 97 from nltk.classify.scikitlearn import SklearnClassifier
#      98 from nltk.classify.senna import Senna
#      99 from nltk.classify.textcat import TextCat
#
# File c:\Users\Abhishek\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\classify\scikitlearn.py:38
#      35 from nltk.probability import DictionaryProbDist
#      37 try:
# ---> 38     from sklearn.feature_extraction import DictVectorizer
#      39     from sklearn.preprocessing import LabelEncoder
#      40 except ImportError:
#
# File c:\Users\Abhishek\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\__init__.py:82
#      80 from . import _distributor_init  # noqa: F401
#      81 from . import __check_build  # noqa: F401
# ---> 82 from .base import clone
#      83 from .utils._show_versions import show_versions
#      85 __all__ = [
#      86     "calibration",
#      87     "cluster",
#    (...)    128     "show_versions",
#     129 ]
#
# File c:\Users\Abhishek\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:17
#      15 from . import __version__
#      16 from ._config import get_config
# ---> 17 from .utils import _IS_32BIT
#      18 from .utils._set_output import _SetOutputMixin
#      19 from .utils._tags import (
#      20     _DEFAULT_TAGS,
#      21 )
#
# File c:\Users\Abhishek\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\__init__.py:19
#      16 import numpy as np
#      17 from scipy.sparse import issparse
# ---> 19 from .murmurhash import murmurhash3_32
#      20 from .class_weight import compute_class_weight, compute_sample_weight
#      21 from . import _joblib
#
# File sklearn\utils\murmurhash.pyx:1, in init sklearn.utils.murmurhash()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\abhishek\appdata\local\programs\python\python311\lib\site-packages (3.9.2)
# Requirement already satisfied: click in c:\users\abhishek\appdata\local\programs\python\python311\lib\site-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in c:\users\abhishek\appdata\roaming\python\python311\site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\abhishek\appdata\local\programs\python\python311\lib\site-packages (from nltk) (2025.11.3)
# Requirement already satisfied: tqdm in c:\users\abhishek\appdata\local\programs\python\python311\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\abhishek\appdata\roaming\python\python311\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
 pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\abhishek\appdata\local\programs\python\python311\lib\site-packages (23.2.1)
# Collecting pip
#   Obtaining dependency information for pip from https://files.pythonhosted.org/packages/44/3c/d717024885424591d5376220b5e836c2d5293ce2011523c9de23ff7bf068/pip-25.3-py3-none-any.whl.metadata
#   Downloading pip-25.3-py3-none-any.whl.metadata (4.7 kB)
# Downloading pip-25.3-py3-none-any.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#     --------------------------------------- 0.0/1.8 MB 326.8 kB/s eta 0:00:06
#    - -------------------------------------- 0.1/1.8 MB 491.5 kB/s eta 0:00:04
#    --- ------------------------------------ 0.2/1.8 MB 876.1 kB/s eta 0:00:02
#    ---------- ----------------------------- 0.5/1.8 MB 2.0 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.8/1.8 MB 2.8 MB/s eta 0:00:01
#    ------------------------------- -------- 1.4/1.8 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------  1.8/1.8 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 4.4 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 23.2.1
#     Uninstalling pip-23.2.1:
#       Successfully uninstalled pip-23.2.1
# Successfully installed pip-25.3
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts pip.exe, pip3.11.exe and pip3.exe are installed in 'c:\Users\Abhishek\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import re
from spellchecker import SpellChecker
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

nltk.download('punkt')
nltk.download('stopwords')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 3
#       1 import re
#       2 from spellchecker import SpellChecker
# ----> 3 import nltk
#       4 from nltk.tokenize import word_tokenize
#       5 from nltk.corpus import stopwords
#
# File c:\Users\Abhishek\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\__init__.py:147
#     141 from nltk.jsontags import *
#     143 ###########################################################
#     144 # PACKAGES
#     145 ###########################################################
# --> 147 from nltk.chunk import *
#     148 from nltk.classify import *
#     149 from nltk.inference import *
#
# File c:\Users\Abhishek\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\chunk\__init__.py:155
#       1 # Natural Language Toolkit: Chunkers
#       2 #
#       3 # Copyright (C) 2001-2025 NLTK Project
#    (...)      7 # For license information, see LICENSE.TXT
#       8 #
#      10 """
#      11 Classes and interfaces for identifying non-overlapping linguistic
#      12 groups (such as base noun phrases) in unrestricted text.  This task is
#    (...)    152      pattern is valid.
#     153 """
# --> 155 from nltk.chunk.api import ChunkParserI
#     156 from nltk.chunk.named_entity import Maxent_NE_Chunker
#     157 from nltk.chunk.regexp import RegexpChunkParser, RegexpParser
#
# File c:\Users\Abhishek\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\chunk\api.py:13
#       1 # Natural Language Toolkit: Chunk parsing API
#       2 #
#       3 # Copyright (C) 2001-2025 NLTK Project
#    (...)     10 ##  Chunk Parser Interface
#      11 ##//////////////////////////////////////////////////////
# ---> 13 from nltk.chunk.util import ChunkScore
#      14 from nltk.internals import deprecated
#      15 from nltk.parse import ParserI
#
# File c:\Users\Abhishek\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\chunk\util.py:12
#       9 import re
#      11 from nltk.metrics import accuracy as _accuracy
# ---> 12 from nltk.tag.mapping import map_tag
#      13 from nltk.tag.util import str2tuple
#      14 from nltk.tree import Tree
#
# File c:\Users\Abhishek\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\tag\__init__.py:72
#      70 from nltk.tag.api import TaggerI
#      71 from nltk.tag.util import str2tuple, tuple2str, untag
# ---> 72 from nltk.tag.sequential import (
#      73     SequentialBackoffTagger,
#      74     ContextTagger,
#      75     DefaultTagger,
#      76     NgramTagger,
#      77     UnigramTagger,
#      78     BigramTagger,
#      79     TrigramTagger,
#      80     AffixTagger,
#      81     RegexpTagger,
#      82     ClassifierBasedTagger,
#      83     ClassifierBasedPOSTagger,
#      84 )
#      85 from nltk.tag.brill import BrillTagger
#      86 from nltk.tag.brill_trainer import BrillTaggerTrainer
#
# File c:\Users\Abhishek\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\tag\sequential.py:26
#      23 from typing import List, Optional, Tuple
#      25 from nltk import jsontags
# ---> 26 from nltk.classify import NaiveBayesClassifier
#      27 from nltk.probability import ConditionalFreqDist
#      28 from nltk.tag.api import FeaturesetTaggerI, TaggerI
#
# File c:\Users\Abhishek\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\classify\__init__.py:97
#      95 from nltk.classify.positivenaivebayes import PositiveNaiveBayesClassifier
#      96 from nltk.classify.rte_classify import RTEFeatureExtractor, rte_classifier, rte_features
# ---> 97 from nltk.classify.scikitlearn import SklearnClassifier
#      98 from nltk.classify.senna import Senna
#      99 from nltk.classify.textcat import TextCat
#
# File c:\Users\Abhishek\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\classify\scikitlearn.py:38
#      35 from nltk.probability import DictionaryProbDist
#      37 try:
# ---> 38     from sklearn.feature_extraction import DictVectorizer
#      39     from sklearn.preprocessing import LabelEncoder
#      40 except ImportError:
#
# File c:\Users\Abhishek\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\__init__.py:82
#      80 from . import _distributor_init  # noqa: F401
#      81 from . import __check_build  # noqa: F401
# ---> 82 from .base import clone
#      83 from .utils._show_versions import show_versions
#      85 __all__ = [
#      86     "calibration",
#      87     "cluster",
#    (...)    128     "show_versions",
#     129 ]
#
# File c:\Users\Abhishek\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:17
#      15 from . import __version__
#      16 from ._config import get_config
# ---> 17 from .utils import _IS_32BIT
#      18 from .utils._set_output import _SetOutputMixin
#      19 from .utils._tags import (
#      20     _DEFAULT_TAGS,
#      21 )
#
# File c:\Users\Abhishek\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\__init__.py:19
#      16 import numpy as np
#      17 from scipy.sparse import issparse
# ---> 19 from .murmurhash import murmurhash3_32
#      20 from .class_weight import compute_class_weight, compute_sample_weight
#      21 from . import _joblib
#
# File sklearn\utils\murmurhash.pyx:1, in init sklearn.utils.murmurhash()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject

# %%
import nltk
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import nltk
#
# File c:\Users\Abhishek\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\__init__.py:147
#     141 from nltk.jsontags import *
#     143 ###########################################################
#     144 # PACKAGES
#     145 ###########################################################
# --> 147 from nltk.chunk import *
#     148 from nltk.classify import *
#     149 from nltk.inference import *
#
# File c:\Users\Abhishek\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\chunk\__init__.py:155
#       1 # Natural Language Toolkit: Chunkers
#       2 #
#       3 # Copyright (C) 2001-2025 NLTK Project
#    (...)      7 # For license information, see LICENSE.TXT
#       8 #
#      10 """
#      11 Classes and interfaces for identifying non-overlapping linguistic
#      12 groups (such as base noun phrases) in unrestricted text.  This task is
#    (...)    152      pattern is valid.
#     153 """
# --> 155 from nltk.chunk.api import ChunkParserI
#     156 from nltk.chunk.named_entity import Maxent_NE_Chunker
#     157 from nltk.chunk.regexp import RegexpChunkParser, RegexpParser
#
# File c:\Users\Abhishek\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\chunk\api.py:13
#       1 # Natural Language Toolkit: Chunk parsing API
#       2 #
#       3 # Copyright (C) 2001-2025 NLTK Project
#    (...)     10 ##  Chunk Parser Interface
#      11 ##//////////////////////////////////////////////////////
# ---> 13 from nltk.chunk.util import ChunkScore
#      14 from nltk.internals import deprecated
#      15 from nltk.parse import ParserI
#
# File c:\Users\Abhishek\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\chunk\util.py:12
#       9 import re
#      11 from nltk.metrics import accuracy as _accuracy
# ---> 12 from nltk.tag.mapping import map_tag
#      13 from nltk.tag.util import str2tuple
#      14 from nltk.tree import Tree
#
# File c:\Users\Abhishek\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\tag\__init__.py:72
#      70 from nltk.tag.api import TaggerI
#      71 from nltk.tag.util import str2tuple, tuple2str, untag
# ---> 72 from nltk.tag.sequential import (
#      73     SequentialBackoffTagger,
#      74     ContextTagger,
#      75     DefaultTagger,
#      76     NgramTagger,
#      77     UnigramTagger,
#      78     BigramTagger,
#      79     TrigramTagger,
#      80     AffixTagger,
#      81     RegexpTagger,
#      82     ClassifierBasedTagger,
#      83     ClassifierBasedPOSTagger,
#      84 )
#      85 from nltk.tag.brill import BrillTagger
#      86 from nltk.tag.brill_trainer import BrillTaggerTrainer
#
# File c:\Users\Abhishek\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\tag\sequential.py:26
#      23 from typing import List, Optional, Tuple
#      25 from nltk import jsontags
# ---> 26 from nltk.classify import NaiveBayesClassifier
#      27 from nltk.probability import ConditionalFreqDist
#      28 from nltk.tag.api import FeaturesetTaggerI, TaggerI
#
# File c:\Users\Abhishek\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\classify\__init__.py:97
#      95 from nltk.classify.positivenaivebayes import PositiveNaiveBayesClassifier
#      96 from nltk.classify.rte_classify import RTEFeatureExtractor, rte_classifier, rte_features
# ---> 97 from nltk.classify.scikitlearn import SklearnClassifier
#      98 from nltk.classify.senna import Senna
#      99 from nltk.classify.textcat import TextCat
#
# File c:\Users\Abhishek\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\classify\scikitlearn.py:38
#      35 from nltk.probability import DictionaryProbDist
#      37 try:
# ---> 38     from sklearn.feature_extraction import DictVectorizer
#      39     from sklearn.preprocessing import LabelEncoder
#      40 except ImportError:
#
# File c:\Users\Abhishek\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\__init__.py:82
#      80 from . import _distributor_init  # noqa: F401
#      81 from . import __check_build  # noqa: F401
# ---> 82 from .base import clone
#      83 from .utils._show_versions import show_versions
#      85 __all__ = [
#      86     "calibration",
#      87     "cluster",
#    (...)    128     "show_versions",
#     129 ]
#
# File c:\Users\Abhishek\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:17
#      15 from . import __version__
#      16 from ._config import get_config
# ---> 17 from .utils import _IS_32BIT
#      18 from .utils._set_output import _SetOutputMixin
#      19 from .utils._tags import (
#      20     _DEFAULT_TAGS,
#      21 )
#
# File c:\Users\Abhishek\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\__init__.py:19
#      16 import numpy as np
#      17 from scipy.sparse import issparse
# ---> 19 from .murmurhash import murmurhash3_32
#      20 from .class_weight import compute_class_weight, compute_sample_weight
#      21 from . import _joblib
#
# File sklearn\utils\murmurhash.pyx:1, in init sklearn.utils.murmurhash()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject

# %%
pip uninstall -y numpy
# Out:
# Found existing installation: numpy 2.2.6
# Uninstalling numpy-2.2.6:
#   Successfully uninstalled numpy-2.2.6
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Failed to remove contents in a temporary directory 'C:\Users\Abhishek\AppData\Local\Programs\Python\Python311\Lib\site-packages\~umpy.libs'.
# You can safely remove it manually.
# WARNING: Failed to remove contents in a temporary directory 'C:\Users\Abhishek\AppData\Local\Programs\Python\Python311\Lib\site-packages\~umpy'.
# You can safely remove it manually.

# %%
pip install --no-cache-dir numpy
# Out:
# Collecting numpy
#   Downloading numpy-2.4.0-cp311-cp311-win_amd64.whl.metadata (6.6 kB)
# Downloading numpy-2.4.0-cp311-cp311-win_amd64.whl (12.6 MB)
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ----- ---------------------------------- 1.8/12.6 MB 10.0 MB/s eta 0:00:02
#    ------------ --------------------------- 3.9/12.6 MB 9.8 MB/s eta 0:00:01
#    ------------------- -------------------- 6.0/12.6 MB 10.0 MB/s eta 0:00:01
#    ------------------------- -------------- 8.1/12.6 MB 10.1 MB/s eta 0:00:01
#    -------------------------------- ------- 10.2/12.6 MB 10.0 MB/s eta 0:00:01
#    ---------------------------------------  12.3/12.6 MB 9.9 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 10.0 MB/s  0:00:01
# Installing collected packages: numpy
# Successfully installed numpy-2.4.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts f2py.exe and numpy-config.exe are installed in 'c:\Users\Abhishek\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.4.0 which is incompatible.

# %%
pip install --force-reinstall --no-cache-dir pandas scipy scikit-learn
# Out:
# Collecting pandas
#   Downloading pandas-2.3.3-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Collecting scipy
#   Downloading scipy-1.16.3-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Collecting scikit-learn
#   Downloading scikit_learn-1.8.0-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Collecting numpy>=1.23.2 (from pandas)
#   Downloading numpy-2.4.0-cp311-cp311-win_amd64.whl.metadata (6.6 kB)
# Collecting python-dateutil>=2.8.2 (from pandas)
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting joblib>=1.3.0 (from scikit-learn)
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting six>=1.5 (from python-dateutil>=2.8.2->pandas)
#   Downloading six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Downloading pandas-2.3.3-cp311-cp311-win_amd64.whl (11.3 MB)
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    ---- ----------------------------------- 1.3/11.3 MB 8.4 MB/s eta 0:00:02
#    ------------ --------------------------- 3.4/11.3 MB 9.2 MB/s eta 0:00:01
#    -------------------- ------------------- 5.8/11.3 MB 9.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 8.1/11.3 MB 10.3 MB/s eta 0:00:01
#    ------------------------------------ --- 10.5/11.3 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------- 11.3/11.3 MB 10.6 MB/s  0:00:01
# Downloading scipy-1.16.3-cp311-cp311-win_amd64.whl (38.7 MB)
#    ---------------------------------------- 0.0/38.7 MB ? eta -:--:--
#    -- ------------------------------------- 2.4/38.7 MB 11.2 MB/s eta 0:00:04
#    ----- ---------------------------------- 5.0/38.7 MB 11.6 MB/s eta 0:00:03
#    ------- -------------------------------- 7.1/38.7 MB 10.9 MB/s eta 0:00:03
#    --------- ------------------------------ 8.9/38.7 MB 10.7 MB/s eta 0:00:03
#    ----------- ---------------------------- 11.5/38.7 MB 10.8 MB/s eta 0:00:03
#    -------------- ------------------------- 13.6/38.7 MB 10.7 MB/s eta 0:00:03
#    ---------------- ----------------------- 16.0/38.7 MB 10.7 MB/s eta 0:00:03
#    ------------------ --------------------- 18.4/38.7 MB 10.8 MB/s eta 0:00:02
#    --------------------- ------------------ 20.7/38.7 MB 10.9 MB/s eta 0:00:02
#    ----------------------- ---------------- 23.1/38.7 MB 11.0 MB/s eta 0:00:02
#    -------------------------- ------------- 25.7/38.7 MB 11.0 MB/s eta 0:00:02
#    ---------------------------- ----------- 28.0/38.7 MB 11.0 MB/s eta 0:00:01
#    ------------------------------- -------- 30.4/38.7 MB 11.0 MB/s eta 0:00:01
#    --------------------------------- ------ 32.8/38.7 MB 11.1 MB/s eta 0:00:01
#    ------------------------------------ --- 35.4/38.7 MB 11.1 MB/s eta 0:00:01
#    -------------------------------------- - 37.7/38.7 MB 11.1 MB/s eta 0:00:01
#    ---------------------------------------- 38.7/38.7 MB 11.1 MB/s  0:00:03
# Downloading numpy-2.4.0-cp311-cp311-win_amd64.whl (12.6 MB)
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ------- -------------------------------- 2.4/12.6 MB 12.2 MB/s eta 0:00:01
#    --------------- ------------------------ 5.0/12.6 MB 11.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 7.3/12.6 MB 11.3 MB/s eta 0:00:01
#    ------------------------------ --------- 9.7/12.6 MB 11.4 MB/s eta 0:00:01
#    ---------------------------------------  12.3/12.6 MB 11.3 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 11.1 MB/s  0:00:01
# Downloading scikit_learn-1.8.0-cp311-cp311-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    --------- ------------------------------ 1.8/8.1 MB 8.4 MB/s eta 0:00:01
#    ---------------------- ----------------- 4.5/8.1 MB 11.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.1/8.1 MB 11.5 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 11.4 MB/s  0:00:00
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading six-1.17.0-py2.py3-none-any.whl (11 kB)
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Downloading tzdata-2025.3-py2.py3-none-any.whl (348 kB)
# Installing collected packages: pytz, tzdata, threadpoolctl, six, numpy, joblib, scipy, python-dateutil, scikit-learn, pandas
#
#   Attempting uninstall: pytz
#
#     Found existing installation: pytz 2025.2
#
#    ----------------------------------------  0/10 [pytz]
#     Uninstalling pytz-2025.2:
#    ----------------------------------------  0/10 [pytz]
#       Successfully uninstalled pytz-2025.2
#    ----------------------------------------  0/10 [pytz]
#    ----------------------------------------  0/10 [pytz]
#    ----------------------------------------  0/10 [pytz]
#    ----------------------------------------  0/10 [pytz]
#    ----------------------------------------  0/10 [pytz]
#    ----------------------------------------  0/10 [pytz]
#   Attempting uninstall: tzdata
#    ----------------------------------------  0/10 [pytz]
#     Found existing installation: tzdata 2025.3
#    ----------------------------------------  0/10 [pytz]
#    ---- -----------------------------------  1/10 [tzdata]
#     Uninstalling tzdata-2025.3:
#    ---- -----------------------------------  1/10 [tzdata]
#       Successfully uninstalled tzdata-2025.3
#    ---- -----------------------------------  1/10 [tzdata]
#    ---- -----------------------------------  1/10 [tzdata]
#    ---- -----------------------------------  1/10 [tzdata]
#    ---- -----------------------------------  1/10 [tzdata]
#    ---- -----------------------------------  1/10 [tzdata]
#   Attempting uninstall: threadpoolctl
#    ---- -----------------------------------  1/10 [tzdata]
#     Found existing installation: threadpoolctl 3.6.0
#    ---- -----------------------------------  1/10 [tzdata]
#     Uninstalling threadpoolctl-3.6.0:
#    ---- -----------------------------------  1/10 [tzdata]
#    -------- -------------------------------  2/10 [threadpoolctl]
#    -------- -------------------------------  2/10 [threadpoolctl]
#    -------- -------------------------------  2/10 [threadpoolctl]
#    -------- -------------------------------  2/10 [threadpoolctl]
#    -------- -------------------------------  2/10 [threadpoolctl]
#    -------- -------------------------------  2/10 [threadpoolctl]
#    -------- -------------------------------  2/10 [threadpoolctl]
#    -------- -------------------------------  2/10 [threadpoolctl]
#       Successfully uninstalled threadpoolctl-3.6.0
#    -------- -------------------------------  2/10 [threadpoolctl]
#    -------- -------------------------------  2/10 [threadpoolctl]
#   Attempting uninstall: six
#    -------- -------------------------------  2/10 [threadpoolctl]
#     Found existing installation: six 1.17.0
#    -------- -------------------------------  2/10 [threadpoolctl]
#     Uninstalling six-1.17.0:
#    -------- -------------------------------  2/10 [threadpoolctl]
#    ------------ ---------------------------  3/10 [six]
#    ------------ ---------------------------  3/10 [six]
#       Successfully uninstalled six-1.17.0
#    ------------ ---------------------------  3/10 [six]
#    ------------ ---------------------------  3/10 [six]
#   Attempting uninstall: numpy
#    ------------ ---------------------------  3/10 [six]
#     Found existing installation: numpy 2.4.0
#    ------------ ---------------------------  3/10 [six]
#    ---------------- -----------------------  4/10 [numpy]
#     Uninstalling numpy-2.4.0:
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#       Successfully uninstalled numpy-2.4.0
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#   Attempting uninstall: joblib
#    ---------------- -----------------------  4/10 [numpy]
#     Found existing installation: joblib 1.5.3
#    ---------------- -----------------------  4/10 [numpy]
#    -------------------- -------------------  5/10 [joblib]
#     Uninstalling joblib-1.5.3:
#    -------------------- -------------------  5/10 [joblib]
#       Successfully uninstalled joblib-1.5.3
#    -------------------- -------------------  5/10 [joblib]
#    -------------------- -------------------  5/10 [joblib]
#    -------------------- -------------------  5/10 [joblib]
#    -------------------- -------------------  5/10 [joblib]
#    -------------------- -------------------  5/10 [joblib]
#    -------------------- -------------------  5/10 [joblib]
#    -------------------- -------------------  5/10 [joblib]
#    -------------------- -------------------  5/10 [joblib]
#    -------------------- -------------------  5/10 [joblib]
#    -------------------- -------------------  5/10 [joblib]
#    -------------------- -------------------  5/10 [joblib]
#    -------------------- -------------------  5/10 [joblib]
#    -------------------- -------------------  5/10 [joblib]
#    -------------------- -------------------  5/10 [joblib]
#    -------------------- -------------------  5/10 [joblib]
#   Attempting uninstall: scipy
#    -------------------- -------------------  5/10 [joblib]
#     Found existing installation: scipy 1.16.3
#    -------------------- -------------------  5/10 [joblib]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#     Uninstalling scipy-1.16.3:
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#       Successfully uninstalled scipy-1.16.3
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#   Attempting uninstall: python-dateutil
#    ------------------------ ---------------  6/10 [scipy]
#    ---------------------------- -----------  7/10 [python-dateutil]
#     Found existing installation: python-dateutil 2.9.0.post0
#    ---------------------------- -----------  7/10 [python-dateutil]
#     Uninstalling python-dateutil-2.9.0.post0:
#    ---------------------------- -----------  7/10 [python-dateutil]
#       Successfully uninstalled python-dateutil-2.9.0.post0
#    ---------------------------- -----------  7/10 [python-dateutil]
#    ---------------------------- -----------  7/10 [python-dateutil]
#    ---------------------------- -----------  7/10 [python-dateutil]
#    ---------------------------- -----------  7/10 [python-dateutil]
#    ---------------------------- -----------  7/10 [python-dateutil]
#   Attempting uninstall: scikit-learn
#    ---------------------------- -----------  7/10 [python-dateutil]
#     Found existing installation: scikit-learn 1.2.2
#    ---------------------------- -----------  7/10 [python-dateutil]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#     Uninstalling scikit-learn-1.2.2:
#    -------------------------------- -------  8/10 [scikit-learn]
#       Successfully uninstalled scikit-learn-1.2.2
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#   Attempting uninstall: pandas
#    -------------------------------- -------  8/10 [scikit-learn]
#     Found existing installation: pandas 2.3.3
#    -------------------------------- -------  8/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#     Uninstalling pandas-2.3.3:
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#       Successfully uninstalled pandas-2.3.3
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ---------------------------------------- 10/10 [pandas]
#
# Successfully installed joblib-1.5.3 numpy-2.4.0 pandas-2.3.3 python-dateutil-2.9.0.post0 pytz-2025.2 scikit-learn-1.8.0 scipy-1.16.3 six-1.17.0 threadpoolctl-3.6.0 tzdata-2025.3
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts f2py.exe and numpy-config.exe are installed in 'c:\Users\Abhishek\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Abhishek\AppData\Roaming\Python\Python311\site-packages\~cipy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Abhishek\AppData\Roaming\Python\Python311\site-packages\~cipy'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Abhishek\AppData\Local\Programs\Python\Python311\Lib\site-packages\~klearn'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.4.0 which is incompatible.

# %%
pip install "numpy<2.0"
# Out:
# Collecting numpy<2.0
#   Downloading numpy-1.26.4-cp311-cp311-win_amd64.whl.metadata (61 kB)
# Downloading numpy-1.26.4-cp311-cp311-win_amd64.whl (15.8 MB)
#    ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#    - -------------------------------------- 0.5/15.8 MB 4.2 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.8/15.8 MB 5.9 MB/s eta 0:00:03
#    -------- ------------------------------- 3.4/15.8 MB 6.5 MB/s eta 0:00:02
#    ------------- -------------------------- 5.2/15.8 MB 7.1 MB/s eta 0:00:02
#    ------------------ --------------------- 7.3/15.8 MB 7.6 MB/s eta 0:00:02
#    ----------------------- ---------------- 9.4/15.8 MB 8.0 MB/s eta 0:00:01
#    ---------------------------- ----------- 11.3/15.8 MB 8.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 13.6/15.8 MB 8.6 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.8 MB 8.8 MB/s eta 0:00:01
#    ---------------------------------------- 15.8/15.8 MB 8.5 MB/s  0:00:01
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.4.0
#     Uninstalling numpy-2.4.0:
#       Successfully uninstalled numpy-2.4.0
# Successfully installed numpy-1.26.4
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script f2py.exe is installed in 'c:\Users\Abhishek\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.

# %%
pip install --force-reinstall pandas scipy scikit-learn
# Out:
# Collecting pandas
#   Downloading pandas-2.3.3-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Collecting scipy
#   Downloading scipy-1.16.3-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Collecting scikit-learn
#   Downloading scikit_learn-1.8.0-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Collecting numpy>=1.23.2 (from pandas)
#   Downloading numpy-2.4.0-cp311-cp311-win_amd64.whl.metadata (6.6 kB)
# Collecting python-dateutil>=2.8.2 (from pandas)
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting joblib>=1.3.0 (from scikit-learn)
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting six>=1.5 (from python-dateutil>=2.8.2->pandas)
#   Using cached six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Downloading pandas-2.3.3-cp311-cp311-win_amd64.whl (11.3 MB)
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/11.3 MB 6.7 MB/s eta 0:00:02
#    --------- ------------------------------ 2.6/11.3 MB 7.9 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.7/11.3 MB 8.6 MB/s eta 0:00:01
#    ------------------------ --------------- 6.8/11.3 MB 9.1 MB/s eta 0:00:01
#    ------------------------------- -------- 8.9/11.3 MB 9.2 MB/s eta 0:00:01
#    ---------------------------------------  11.3/11.3 MB 9.5 MB/s eta 0:00:01
#    ---------------------------------------- 11.3/11.3 MB 9.0 MB/s  0:00:01
# Downloading scipy-1.16.3-cp311-cp311-win_amd64.whl (38.7 MB)
#    ---------------------------------------- 0.0/38.7 MB ? eta -:--:--
#    -- ------------------------------------- 2.4/38.7 MB 11.2 MB/s eta 0:00:04
#    ---- ----------------------------------- 4.2/38.7 MB 10.5 MB/s eta 0:00:04
#    ------ --------------------------------- 6.6/38.7 MB 10.6 MB/s eta 0:00:04
#    --------- ------------------------------ 9.2/38.7 MB 11.0 MB/s eta 0:00:03
#    ----------- ---------------------------- 11.3/38.7 MB 11.0 MB/s eta 0:00:03
#    -------------- ------------------------- 13.9/38.7 MB 11.0 MB/s eta 0:00:03
#    ---------------- ----------------------- 16.3/38.7 MB 11.1 MB/s eta 0:00:03
#    ------------------- -------------------- 18.9/38.7 MB 11.2 MB/s eta 0:00:02
#    --------------------- ------------------ 21.2/38.7 MB 11.3 MB/s eta 0:00:02
#    ------------------------ --------------- 23.3/38.7 MB 11.1 MB/s eta 0:00:02
#    -------------------------- ------------- 25.7/38.7 MB 11.1 MB/s eta 0:00:02
#    ---------------------------- ----------- 27.8/38.7 MB 11.1 MB/s eta 0:00:01
#    ------------------------------- -------- 30.4/38.7 MB 11.1 MB/s eta 0:00:01
#    --------------------------------- ------ 32.2/38.7 MB 10.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 34.1/38.7 MB 10.9 MB/s eta 0:00:01
#    ------------------------------------- -- 36.4/38.7 MB 10.7 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.7 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------- 38.7/38.7 MB 10.2 MB/s  0:00:03
# Downloading numpy-2.4.0-cp311-cp311-win_amd64.whl (12.6 MB)
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ------ --------------------------------- 2.1/12.6 MB 9.8 MB/s eta 0:00:02
#    ------------- -------------------------- 4.2/12.6 MB 9.7 MB/s eta 0:00:01
#    ------------------- -------------------- 6.3/12.6 MB 9.6 MB/s eta 0:00:01
#    ------------------------- -------------- 8.1/12.6 MB 10.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 9.4/12.6 MB 8.8 MB/s eta 0:00:01
#    ------------------------------------- -- 11.8/12.6 MB 9.1 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 8.9 MB/s  0:00:01
# Downloading scikit_learn-1.8.0-cp311-cp311-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ----------- ---------------------------- 2.4/8.1 MB 11.2 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.7/8.1 MB 11.4 MB/s eta 0:00:01
#    ------------------------------------ --- 7.3/8.1 MB 11.6 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 10.0 MB/s  0:00:00
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached six-1.17.0-py2.py3-none-any.whl (11 kB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Using cached tzdata-2025.3-py2.py3-none-any.whl (348 kB)
# Installing collected packages: pytz, tzdata, threadpoolctl, six, numpy, joblib, scipy, python-dateutil, scikit-learn, pandas
#
#   Attempting uninstall: pytz
#
#     Found existing installation: pytz 2025.2
#
#     Uninstalling pytz-2025.2:
#
#       Successfully uninstalled pytz-2025.2
#
#    ----------------------------------------  0/10 [pytz]
#    ----------------------------------------  0/10 [pytz]
#    ----------------------------------------  0/10 [pytz]
#    ----------------------------------------  0/10 [pytz]
#    ----------------------------------------  0/10 [pytz]
#   Attempting uninstall: tzdata
#    ----------------------------------------  0/10 [pytz]
#     Found existing installation: tzdata 2025.3
#    ----------------------------------------  0/10 [pytz]
#     Uninstalling tzdata-2025.3:
#    ----------------------------------------  0/10 [pytz]
#       Successfully uninstalled tzdata-2025.3
#    ----------------------------------------  0/10 [pytz]
#    ---- -----------------------------------  1/10 [tzdata]
#    ---- -----------------------------------  1/10 [tzdata]
#    ---- -----------------------------------  1/10 [tzdata]
#    ---- -----------------------------------  1/10 [tzdata]
#    ---- -----------------------------------  1/10 [tzdata]
#   Attempting uninstall: threadpoolctl
#    ---- -----------------------------------  1/10 [tzdata]
#     Found existing installation: threadpoolctl 3.6.0
#    ---- -----------------------------------  1/10 [tzdata]
#     Uninstalling threadpoolctl-3.6.0:
#    ---- -----------------------------------  1/10 [tzdata]
#    -------- -------------------------------  2/10 [threadpoolctl]
#       Successfully uninstalled threadpoolctl-3.6.0
#    -------- -------------------------------  2/10 [threadpoolctl]
#    -------- -------------------------------  2/10 [threadpoolctl]
#   Attempting uninstall: six
#    -------- -------------------------------  2/10 [threadpoolctl]
#     Found existing installation: six 1.17.0
#    -------- -------------------------------  2/10 [threadpoolctl]
#     Uninstalling six-1.17.0:
#    -------- -------------------------------  2/10 [threadpoolctl]
#    ------------ ---------------------------  3/10 [six]
#    ------------ ---------------------------  3/10 [six]
#       Successfully uninstalled six-1.17.0
#    ------------ ---------------------------  3/10 [six]
#    ------------ ---------------------------  3/10 [six]
#   Attempting uninstall: numpy
#    ------------ ---------------------------  3/10 [six]
#     Found existing installation: numpy 1.26.4
#    ------------ ---------------------------  3/10 [six]
#    ---------------- -----------------------  4/10 [numpy]
#     Uninstalling numpy-1.26.4:
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#       Successfully uninstalled numpy-1.26.4
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#    ---------------- -----------------------  4/10 [numpy]
#   Attempting uninstall: joblib
#    ---------------- -----------------------  4/10 [numpy]
#     Found existing installation: joblib 1.5.3
#    ---------------- -----------------------  4/10 [numpy]
#     Uninstalling joblib-1.5.3:
#    ---------------- -----------------------  4/10 [numpy]
#       Successfully uninstalled joblib-1.5.3
#    ---------------- -----------------------  4/10 [numpy]
#    -------------------- -------------------  5/10 [joblib]
#    -------------------- -------------------  5/10 [joblib]
#    -------------------- -------------------  5/10 [joblib]
#    -------------------- -------------------  5/10 [joblib]
#    -------------------- -------------------  5/10 [joblib]
#    -------------------- -------------------  5/10 [joblib]
#    -------------------- -------------------  5/10 [joblib]
#    -------------------- -------------------  5/10 [joblib]
#    -------------------- -------------------  5/10 [joblib]
#    -------------------- -------------------  5/10 [joblib]
#    -------------------- -------------------  5/10 [joblib]
#    -------------------- -------------------  5/10 [joblib]
#   Attempting uninstall: scipy
#    -------------------- -------------------  5/10 [joblib]
#     Found existing installation: scipy 1.16.3
#    -------------------- -------------------  5/10 [joblib]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#     Uninstalling scipy-1.16.3:
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#       Successfully uninstalled scipy-1.16.3
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#   Attempting uninstall: python-dateutil
#    ------------------------ ---------------  6/10 [scipy]
#    ---------------------------- -----------  7/10 [python-dateutil]
#     Found existing installation: python-dateutil 2.9.0.post0
#    ---------------------------- -----------  7/10 [python-dateutil]
#     Uninstalling python-dateutil-2.9.0.post0:
#    ---------------------------- -----------  7/10 [python-dateutil]
#       Successfully uninstalled python-dateutil-2.9.0.post0
#    ---------------------------- -----------  7/10 [python-dateutil]
#    ---------------------------- -----------  7/10 [python-dateutil]
#    ---------------------------- -----------  7/10 [python-dateutil]
#    ---------------------------- -----------  7/10 [python-dateutil]
#    ---------------------------- -----------  7/10 [python-dateutil]
#   Attempting uninstall: scikit-learn
#    ---------------------------- -----------  7/10 [python-dateutil]
#     Found existing installation: scikit-learn 1.8.0
#    ---------------------------- -----------  7/10 [python-dateutil]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#     Uninstalling scikit-learn-1.8.0:
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#       Successfully uninstalled scikit-learn-1.8.0
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#    -------------------------------- -------  8/10 [scikit-learn]
#   Attempting uninstall: pandas
#    -------------------------------- -------  8/10 [scikit-learn]
#     Found existing installation: pandas 2.3.3
#    -------------------------------- -------  8/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#     Uninstalling pandas-2.3.3:
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#       Successfully uninstalled pandas-2.3.3
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ------------------------------------ ---  9/10 [pandas]
#    ---------------------------------------- 10/10 [pandas]
#
# Successfully installed joblib-1.5.3 numpy-2.4.0 pandas-2.3.3 python-dateutil-2.9.0.post0 pytz-2025.2 scikit-learn-1.8.0 scipy-1.16.3 six-1.17.0 threadpoolctl-3.6.0 tzdata-2025.3
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts f2py.exe and numpy-config.exe are installed in 'c:\Users\Abhishek\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.4.0 which is incompatible.

# %%
import re
from spellchecker import SpellChecker
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

nltk.download('punkt')
nltk.download('stopwords')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 3
#       1 import re
#       2 from spellchecker import SpellChecker
# ----> 3 import nltk
#       4 from nltk.tokenize import word_tokenize
#       5 from nltk.corpus import stopwords
#
# File c:\Users\Abhishek\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\__init__.py:147
#     141 from nltk.jsontags import *
#     143 ###########################################################
#     144 # PACKAGES
#     145 ###########################################################
# --> 147 from nltk.chunk import *
#     148 from nltk.classify import *
#     149 from nltk.inference import *
#
# File c:\Users\Abhishek\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\chunk\__init__.py:155
#       1 # Natural Language Toolkit: Chunkers
#       2 #
#       3 # Copyright (C) 2001-2025 NLTK Project
#    (...)      7 # For license information, see LICENSE.TXT
#       8 #
#      10 """
#      11 Classes and interfaces for identifying non-overlapping linguistic
#      12 groups (such as base noun phrases) in unrestricted text.  This task is
#    (...)    152      pattern is valid.
#     153 """
# --> 155 from nltk.chunk.api import ChunkParserI
#     156 from nltk.chunk.named_entity import Maxent_NE_Chunker
#     157 from nltk.chunk.regexp import RegexpChunkParser, RegexpParser
#
# File c:\Users\Abhishek\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\chunk\api.py:13
#       1 # Natural Language Toolkit: Chunk parsing API
#       2 #
#       3 # Copyright (C) 2001-2025 NLTK Project
#    (...)     10 ##  Chunk Parser Interface
#      11 ##//////////////////////////////////////////////////////
# ---> 13 from nltk.chunk.util import ChunkScore
#      14 from nltk.internals import deprecated
#      15 from nltk.parse import ParserI
#
# File c:\Users\Abhishek\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\chunk\util.py:12
#       9 import re
#      11 from nltk.metrics import accuracy as _accuracy
# ---> 12 from nltk.tag.mapping import map_tag
#      13 from nltk.tag.util import str2tuple
#      14 from nltk.tree import Tree
#
# File c:\Users\Abhishek\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\tag\__init__.py:72
#      70 from nltk.tag.api import TaggerI
#      71 from nltk.tag.util import str2tuple, tuple2str, untag
# ---> 72 from nltk.tag.sequential import (
#      73     SequentialBackoffTagger,
#      74     ContextTagger,
#      75     DefaultTagger,
#      76     NgramTagger,
#      77     UnigramTagger,
#      78     BigramTagger,
#      79     TrigramTagger,
#      80     AffixTagger,
#      81     RegexpTagger,
#      82     ClassifierBasedTagger,
#      83     ClassifierBasedPOSTagger,
#      84 )
#      85 from nltk.tag.brill import BrillTagger
#      86 from nltk.tag.brill_trainer import BrillTaggerTrainer
#
# File c:\Users\Abhishek\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\tag\sequential.py:26
#      23 from typing import List, Optional, Tuple
#      25 from nltk import jsontags
# ---> 26 from nltk.classify import NaiveBayesClassifier
#      27 from nltk.probability import ConditionalFreqDist
#      28 from nltk.tag.api import FeaturesetTaggerI, TaggerI
#
# File c:\Users\Abhishek\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\classify\__init__.py:97
#      95 from nltk.classify.positivenaivebayes import PositiveNaiveBayesClassifier
#      96 from nltk.classify.rte_classify import RTEFeatureExtractor, rte_classifier, rte_features
# ---> 97 from nltk.classify.scikitlearn import SklearnClassifier
#      98 from nltk.classify.senna import Senna
#      99 from nltk.classify.textcat import TextCat
#
# File c:\Users\Abhishek\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\classify\scikitlearn.py:38
#      35 from nltk.probability import DictionaryProbDist
#      37 try:
# ---> 38     from sklearn.feature_extraction import DictVectorizer
#      39     from sklearn.preprocessing import LabelEncoder
#      40 except ImportError:
#
# File c:\Users\Abhishek\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\__init__.py:70
#      62 # `_distributor_init` allows distributors to run custom init code.
#      63 # For instance, for the Windows wheel, this is used to pre-load the
#      64 # vcomp shared library runtime for OpenMP embedded in the sklearn/.libs
#    (...)     67 # later is linked to the OpenMP runtime to make it possible to introspect
#      68 # it and importing it first would fail if the OpenMP dll cannot be found.
#      69 from sklearn import __check_build, _distributor_init  # noqa: E402 F401
# ---> 70 from sklearn.base import clone  # noqa: E402
#      71 from sklearn.utils._show_versions import show_versions  # noqa: E402
#      73 _submodules = [
#      74     "calibration",
#      75     "cluster",
#    (...)    111     "compose",
#     112 ]
#
# File c:\Users\Abhishek\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:25
#      23 from sklearn.utils._repr_html.estimator import estimator_html_repr
#      24 from sklearn.utils._repr_html.params import ParamsDict
# ---> 25 from sklearn.utils._set_output import _SetOutputMixin
#      26 from sklearn.utils._tags import (
#      27     ClassifierTags,
#      28     RegressorTags,
#    (...)     32     get_tags,
#      33 )
#      34 from sklearn.utils.fixes import _IS_32BIT
#
# File c:\Users\Abhishek\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\__init__.py:33
#      31 from sklearn.utils.discovery import all_estimators
#      32 from sklearn.utils.extmath import safe_sqr
# ---> 33 from sklearn.utils.murmurhash import murmurhash3_32
#      34 from sklearn.utils.validation import (
#      35     as_float_array,
#      36     assert_all_finite,
#    (...)     44     indexable,
#      45 )
#      47 __all__ = [
#      48     "Bunch",
#      49     "ClassifierTags",
#    (...)     80     "shuffle",
#      81 ]
#
# File c:\Users\Abhishek\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\murmurhash.pyx:1, in init sklearn.utils.murmurhash()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject
