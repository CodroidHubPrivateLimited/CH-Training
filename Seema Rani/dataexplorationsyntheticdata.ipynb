# %% [markdown]
# Synthetic Data Creation

# %%
import pandas as pd  #importing pandas

# %%
# Create a simple, clean synthetic dataset
data = { 'Roll_no': [1, 2, 3, 4, 5],
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
    'Age': [25, 30, 35, 40, 45],
    'marks': [85, 90, 95, 80, 75],
    'Department': ['CSE', 'ECE', 'BT', 'AIML', 'CSE']
    }

# %%
import pandas as pd
df = pd.DataFrame(data)
df
# Out:
#    Roll_no     Name  Age  marks Department
# 0        1    Alice   25     85        CSE
# 1        2      Bob   30     90        ECE
# 2        3  Charlie   35     95         BT
# 3        4    David   40     80       AIML
# 4        5      Eva   45     75        CSE

# %%
data1 = { 'Roll_no': [1, 2, 3, 4, None ,4],
    'Name': ['Alice', 'Bob','David', None, 'Eva', 'David'],
    'Age': [25, 30, 35,45, None, 40],
    'marks': [85, 90, 95, 80, None, "Pass"],
    'Department': ['CSE', 'ECE', 'BT', 'AIML', 'CSE', 'AIML']
    }

# %%
import pandas as pd
import numpy as np  # to use random functions if needed


df = pd.DataFrame(data1)
df
# Out:
#    Roll_no   Name   Age marks Department
# 0      1.0  Alice  25.0    85        CSE
# 1      2.0    Bob  30.0    90        ECE
# 2      3.0  David  35.0    95         BT
# 3      4.0   None  45.0    80       AIML
# 4      NaN    Eva   NaN  None        CSE
# 5      4.0  David  40.0  Pass       AIML

# %%
np.random.seed(42)  # for reproducibility
n=10
np.random.randint(1,101,size=n)  # generate n random integers between 1 and 100
# Out:
# array([52, 93, 15, 72, 61, 21, 83, 87, 75, 75])

# %%
np.random.seed(24)  # for reproducibility
n=10
np.random.randint(1,101,size=n)  # generat
# Out:
# array([ 35,   4,  65,  88,  18,  18,   2,  80,   5, 100])

# %%
#np.random.seed(42)  # for reproducibility
n=10
np.random.randint(1,101,size=n)  # generat
# Out:
# array([ 83,  12, 100,  16,  74,  19,   8,  26,  36,  96])

# %%
np.random.seed(42)  # for reproducibility
n=1000
df =pd.DataFrame(
    { 'Roll_no': np.random.randint(101,101+n),

    'Age': np.random.randint(18,24, size=n),
    'marks': np.random.randint(40,101,size=n),
    'Department': np.random.choice(['CSE', 'ECE', 'BT', 'Automation', 'ME', 'AIML'], size=n)
    })
#df['Random_Number'] = np.random.randint(1,2001,size=n)  # generate n random integers between 1 and 100
df
# Out:
#      Roll_no  Age  marks  Department
# 0        203   21     61  Automation
# 1        203   22     60          BT
# 2        203   20     45         CSE
# 3        203   22     45  Automation
# 4        203   22     94        AIML
# ..       ...  ...    ...         ...
# 995      203   23     43  Automation
# 996      203   22     59         ECE
# 997      203   18     71         CSE
# 998      203   18     75         ECE
# 999      203   22     89        AIML
#
# [1000 rows x 4 columns]

# %%
df.head()
# Out:
#    Roll_no  Age  marks  Department
# 0      203   21     61  Automation
# 1      203   22     60          BT
# 2      203   20     45         CSE
# 3      203   22     45  Automation
# 4      203   22     94        AIML

# %%
#Introduce missing values in AGE, MARKS and Department columns randomly
for col in ['Age', 'marks', 'Department']:
    df.loc[df.sample(frac=0.05).index, col] = np.nan    
# Dupilcate Rows/records
pd.concat([df, df.sample(20)], ignore_index=True)
# Introduce invalid ages
df.loc[df.sample(10).index,'Age'] = np.random.choice([-5, 240], size=10)
# Introduce Outliers in marks
df.loc[df.sample(10).index,'marks'] = np.random.choice([-10, 150], size=10)
#Inconsistent entries in Department
df["Department"]= df["Department"].astype(str)
df.loc[df.sample(10).index,'Department'] = df["Department"].str.lower()    

df.tail()
# Out:
#      Roll_no   Age  marks Department
# 995      203   NaN   43.0        nan
# 996      203  22.0   59.0        ECE
# 997      203  18.0   71.0        CSE
# 998      203  18.0   75.0        ECE
# 999      203  22.0   89.0       AIML

# %%
# Initial data quality check
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Roll_no     1000 non-null   int64
#  1   Age         952 non-null    float64
#  2   marks       951 non-null    float64
#  3   Department  1000 non-null   object
# dtypes: float64(2), int64(1), object(1)
# memory usage: 31.4+ KB

# %%
df.isnull().sum()
# Out:
# Roll_no        0
# Age           48
# marks         49
# Department     0
# dtype: int64

# %%
#Data Exploration
df.shape
# Out:
# (1000, 4)

# %%
df.columns
# Out:
# Index(['Roll_no', 'Age', 'marks', 'Department'], dtype='object')

# %%
#show random 10 records
df.sample(10)
# Out:
#      Roll_no    Age  marks  Department
# 428      203   23.0    NaN         CSE
# 599      203  240.0   73.0         CSE
# 356      203   22.0   58.0          ME
# 116      203   18.0   80.0         nan
# 663      203   22.0   65.0        AIML
# 868      203   19.0   68.0         ECE
# 4        203   22.0   94.0        AIML
# 847      203   19.0   63.0        AIML
# 251      203   20.0   87.0  Automation
# 625      203   22.0   73.0        AIML

# %%
df.isnull().sum()
# Out:
# Roll_no        0
# Age           48
# marks         49
# Department     0
# dtype: int64

# %%
#how much % of missing values in each column
df.isnull().mean()*100
# Out:
# Roll_no       0.0
# Age           4.8
# marks         4.9
# Department    0.0
# dtype: float64

# %%
df[df.isnull().any(axis=1)].count()  # total rows with atleast one missing value
# Out:
# Roll_no       96
# Age           48
# marks         47
# Department    96
# dtype: int64

# %%
#check duplicate rows
df.duplicated().sum()
# Out:
# 165

# %%
pd.concat([df, df.sample(20)], ignore_index=True)
# Out:
#       Roll_no   Age  marks  Department
# 0         203  21.0   61.0  Automation
# 1         203  22.0   60.0          BT
# 2         203  20.0   45.0         CSE
# 3         203  22.0   45.0  Automation
# 4         203  22.0   94.0        AIML
# ...       ...   ...    ...         ...
# 1015      203  23.0   57.0        AIML
# 1016      203  22.0   48.0         ECE
# 1017      203  18.0   92.0          ME
# 1018      203  19.0   68.0         ECE
# 1019      203   NaN   97.0  Automation
#
# [1020 rows x 4 columns]

# %%
df.describe()
# Out:
#        Roll_no         Age       marks
# count   1000.0  952.000000  951.000000
# mean     203.0   20.945378   69.626709
# std        0.0   12.628692   19.202316
# min      203.0   -5.000000  -10.000000
# 25%      203.0   19.000000   54.000000
# 50%      203.0   20.000000   70.000000
# 75%      203.0   22.000000   85.000000
# max      203.0  240.000000  150.000000

# %%
pd.set_option('display.max_rows', None) 
pd.set_option('display.max_columns', 2)   
pd.reset_option('display.max_rows')
df
# Out:
#      Roll_no  ...  Department
# 0        203  ...  Automation
# 1        203  ...          BT
# 2        203  ...         CSE
# 3        203  ...  Automation
# 4        203  ...        AIML
# ..       ...  ...         ...
# 995      203  ...         nan
# 996      203  ...         ECE
# 997      203  ...         CSE
# 998      203  ...         ECE
# 999      203  ...        AIML
#
# [1000 rows x 4 columns]

# %%
# Display rows 500 to 600 
df.iloc[500:601]
# Out:
#      Roll_no    Age  marks  Department
# 500      203   18.0   84.0          ME
# 501      203    NaN   64.0          ME
# 502      203   23.0   78.0          BT
# 503      203   22.0   48.0          ME
# 504      203   19.0   93.0  Automation
# ..       ...    ...    ...         ...
# 596      203   23.0   98.0  Automation
# 597      203   22.0   84.0          BT
# 598      203   20.0   82.0         ECE
# 599      203  240.0   73.0         CSE
# 600      203   18.0   48.0        AIML
#
# [101 rows x 4 columns]

# %%
df.iloc[500:601].to_string()
# Out:
# '     Roll_no    Age  marks  Department\n500      203   18.0   84.0          ME\n501      203    NaN   64.0          ME\n502      203   23.0   78.0          BT\n503      203   22.0   48.0          ME\n504      203   19.0   93.0  Automation\n505      203   19.0   61.0         CSE\n506      203   23.0   82.0  Automation\n507      203   22.0   85.0          BT\n508      203   21.0   43.0          BT\n509      203   19.0    NaN  Automation\n510      203   21.0   97.0          ME\n511      203   19.0   68.0          ME\n512      203   19.0   84.0         nan\n513      203   20.0   73.0          BT\n514      203   19.0    NaN         ECE\n515      203   18.0   76.0        AIML\n516      203   22.0   50.0          ME\n517      203   22.0   45.0  Automation\n518      203   21.0   57.0          ME\n519      203   19.0   60.0  Automation\n520      203    NaN   81.0         nan\n521      203   21.0   75.0          BT\n522      203   20.0   80.0          ME\n523      203   21.0   77.0  Automation\n524      203   21.0   73.0          BT\n525      203   19.0   56.0         ECE\n526      203   20.0   76.0  Automation\n527      203    NaN   64.0        AIML\n528      203   18.0   77.0         ECE\n529      203   18.0   97.0         ECE\n530      203   22.0   51.0         CSE\n531      203   20.0   62.0          ME\n532      203   20.0   92.0  Automation\n533      203   22.0   81.0         ECE\n534      203   21.0   61.0         CSE\n535      203   20.0   60.0        AIML\n536      203   18.0   66.0          BT\n537      203   18.0   96.0  Automation\n538      203   19.0   70.0         ECE\n539      203   20.0   45.0          ME\n540      203   21.0   66.0         CSE\n541      203   22.0   79.0         ECE\n542      203   22.0   73.0          ME\n543      203   21.0   51.0         ECE\n544      203   23.0    NaN  Automation\n545      203   19.0   96.0  Automation\n546      203   22.0    NaN  Automation\n547      203   20.0   46.0         nan\n548      203   19.0   49.0        AIML\n549      203   20.0   84.0         CSE\n550      203   18.0   56.0  Automation\n551      203   19.0   65.0          ME\n552      203   22.0   60.0         ECE\n553      203   19.0   67.0          BT\n554      203   19.0   97.0          ME\n555      203   19.0   85.0        AIML\n556      203   23.0   41.0        AIML\n557      203   19.0   99.0         nan\n558      203   20.0   93.0        AIML\n559      203   18.0   82.0  Automation\n560      203   21.0   40.0         CSE\n561      203   19.0   90.0         ECE\n562      203   22.0    NaN         cse\n563      203   19.0   75.0         ECE\n564      203   22.0   90.0         ECE\n565      203   20.0   65.0         CSE\n566      203   22.0   68.0          ME\n567      203    NaN   60.0         ECE\n568      203   18.0   50.0         CSE\n569      203   22.0    NaN         ECE\n570      203   22.0   50.0          BT\n571      203   18.0   75.0          ME\n572      203   21.0   88.0  Automation\n573      203   19.0   98.0         ECE\n574      203   22.0   78.0          BT\n575      203   18.0   79.0  Automation\n576      203   20.0   74.0  Automation\n577      203   18.0   93.0         ECE\n578      203   20.0   73.0         CSE\n579      203   21.0   94.0         ECE\n580      203   19.0    NaN          BT\n581      203   18.0   63.0  Automation\n582      203   23.0   93.0         ECE\n583      203   22.0   61.0         CSE\n584      203   21.0   44.0         ECE\n585      203   18.0   95.0          ME\n586      203   22.0   72.0         CSE\n587      203   18.0   97.0          BT\n588      203   20.0   75.0         nan\n589      203   18.0  -10.0         ECE\n590      203   23.0   59.0         CSE\n591      203   18.0   58.0          ME\n592      203   18.0   74.0         CSE\n593      203   23.0   91.0        AIML\n594      203   21.0   82.0         nan\n595      203   18.0   56.0          BT\n596      203   23.0   98.0  Automation\n597      203   22.0   84.0          BT\n598      203   20.0   82.0         ECE\ ...

# %%
df.to_csv('synthetic_student_data.csv', index=False)
df
# Out:
#      Roll_no   Age  marks  Department
# 0        203  21.0   61.0  Automation
# 1        203  22.0   60.0          BT
# 2        203  20.0   45.0         CSE
# 3        203  22.0   45.0  Automation
# 4        203  22.0   94.0        AIML
# ..       ...   ...    ...         ...
# 995      203   NaN   43.0         nan
# 996      203  22.0   59.0         ECE
# 997      203  18.0   71.0         CSE
# 998      203  18.0   75.0         ECE
# 999      203  22.0   89.0        AIML
#
# [1000 rows x 4 columns]

# %%
df.to_excel('synthetic_student_data.xlsx', index=False)
