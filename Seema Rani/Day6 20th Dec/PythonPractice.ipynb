# %%
"Hello"
# Out:
# 'Hello'

# %%
20+30
# Out:
# 50

# %%
40+70
# Out:
# 110

# %%
_+10
# Out:
# 120

# %%
print("A","B", sep="!", end="!\n")
# Out:
# A!B!

# %%
price=200
tax=18
print("The price including tax is:", price + (price*tax)/100)
print(f"The price including tax is: {price + (price*tax)/100}")
# Out:
# The price including tax is: 236.0
# The price including tax is: 236.0

# %%
pi=3
print(f"The value of pi is approximately {pi:03d}")
# Out:
# The value of pi is approximately 003

# %%
pi=3
print(f"The value of pi is approximately {pi:.03f}")
# Out:
# The value of pi is approximately 3.000

# %%
name="Seema Rani"
print(f"Hello, {name:>20}!")
# Out:
# Hello,           Seema Rani!

# %%
class Student:
    def __init__(self, name: str, marks: int):
        if not isinstance(name, str):
            raise TypeError("Name must be a string")
        if not isinstance(marks, int):  
            raise TypeError("Marks must be an integer")
        self.name = name
        self.marks = marks
    def display(self) ->str:
        #print(f"Name: {self.name}, Marks: {self.marks}")
        return f"Name: {self.name}, Marks: {self.marks}"

# %%
stud2 = Student("Reema", 96)
#stud2.display()
print(stud2.display())
# Out:
# Name: Reema, Marks: 96

# %%
#assert keyword in python - Debugging purpose
# To verify assumptions made by the program and to catch logical errors
x = 10
assert x > 0, "x should be positive"
print("Assertion passed.")
# Out:
# Assertion passed.

# %%
import numpy as np
np.random.seed(1)
id= np.random.arrange(1,21,5)
data= ({'ID': id,
        'Name': np.random.choice(['Alice', 'Bob', 'Charlie', 'David'], len(id)),
        'age' : np.random.randint(18, 60, len(id)),
        'Score': np.random.uniform(0, 100, len(id))
        })
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [18], in <cell line: 3>()
#       1 import numpy as np
#       2 np.random.seed(1)
# ----> 3 id= np.random.arrange(1,21,5)
#       4 data= ({'ID': id,
#       5         'Name': np.random.choice(['Alice', 'Bob', 'Charlie', 'David'], len(id)),
#       6         'age' : np.random.randint(18, 60, len(id)),
#       7         'Score': np.random.uniform(0, 100, len(id))
#       8         })
#
# AttributeError: module 'numpy.random' has no attribute 'arrange'
