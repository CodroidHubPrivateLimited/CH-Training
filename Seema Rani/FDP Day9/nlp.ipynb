# %%
import re

# %%
# %pip install nltk
# Out:
# ...
#   Obtaining dependency information for nltk from https://files.pythonhosted.org/packages/60/90/81ac364ef94209c100e12579629dc92bf7a709a84af32f8c551b02c07e94/nltk-3.9.2-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for click from https://files.pythonhosted.org/packages/98/78/01c019cdb5d6498122777c1a43056ebb3ebfeef2076d9d026bfe15583b2b/click-8.3.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for joblib from https://files.pythonhosted.org/packages/7b/91/984aca2ec129e2757d1e4e3c81c3fcda9d0f85b74670a094cc443d9ee949/joblib-1.5.3-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for regex>=2021.8.3 from https://files.pythonhosted.org/packages/50/1e/15f08b2f82a9bbb510621ec9042547b54d11e83cb620643ebb54e4eb7d71/regex-2025.11.3-cp311-cp311-win_amd64.whl.metadata
# ...
#      ---------------------------------------- 0.0/41.5 kB ? eta -:--:--
#      --------- ------------------------------ 10.2/41.5 kB ? eta -:--:--
# ...

# %%
import nltk

# %%
import nltk

# %%
nltk.download('punkt')
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
nltk.download('omw-1.4')
from nltk.stem import PorterStemmer

text= "Seema Rani is a data scientist. She is working in Infosys. She loves to work on NLP projects."
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Seema\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Seema\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Seema\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Seema\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Seema\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import re
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
nltk.download('punkt') #for tokenization
nltk.download('stopwords') # for stopword removal
nltk.download('punktk_tab') #if punkt does not work
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Seema\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Seema\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Error loading punktk_tab: Package 'punktk_tab' not found
# [nltk_data]     in index
# False

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Seema\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
text1="NLTK is Amazing tool!!! it helps students to understand NLP easily!"

stop_words=set(stopwords.words('english')) #setting stopwords of english langauge
filtered_tokens= [word for word in word_tokenize(text1) if word not in stop_words]

print(filtered_tokens)
# Out:
# ['NLTK', 'Amazing', 'tool', '!', '!', '!', 'helps', 'students', 'understand', 'NLP', 'easily', '!']

# %%
stop_words=set(stopwords.words('english')) #setting stopwords of english langauge
clean_word=[word for word in stop_words if word not in stop_words]
print(clean_word)
# Out:
# []
