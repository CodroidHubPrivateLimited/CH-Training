# %%
import cv2

# %%
print("OpenCV version:", cv2.__version__)
# Out:
# OpenCV version: 4.12.0

# %%
img=cv2.imread('FDP Day9\FDP img.jpg')
cv2.imread('Image', img)
cv2.waitKey(0)
cv2.destroyAllWindows()
