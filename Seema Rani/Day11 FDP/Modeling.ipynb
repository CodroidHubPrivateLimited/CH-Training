# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC


from sklearn.metrics import(confusion_matrix, 
accuracy_score, precision_score, recall_score,f1_score,roc_auc_score)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [3], in <cell line: 2>()
#       1 import numpy as np
# ----> 2 import pandas as pd
#       4 from sklearn.model_selection import train_test_split
#       5 from sklearn.preprocessing import StandardScaler
#
# File c:\Users\Seema\anaconda3\lib\site-packages\pandas\__init__.py:22, in <module>
#      19 del hard_dependencies, dependency, missing_dependencies
#      21 # numpy compat
# ---> 22 from pandas.compat import is_numpy_dev as _is_numpy_dev
#      24 try:
#      25     from pandas._libs import hashtable as _hashtable, lib as _lib, tslib as _tslib
#
# File c:\Users\Seema\anaconda3\lib\site-packages\pandas\compat\__init__.py:15, in <module>
#      12 import sys
#      14 from pandas._typing import F
# ---> 15 from pandas.compat.numpy import (
#      16     is_numpy_dev,
#      17     np_version_under1p19,
#      18     np_version_under1p20,
#      19 )
#      20 from pandas.compat.pyarrow import (
#      21     pa_version_under1p01,
#      22     pa_version_under2p0,
#      23     pa_version_under3p0,
#      24     pa_version_under4p0,
#      25 )
#      27 PY39 = sys.version_info >= (3, 9)
#
# File c:\Users\Seema\anaconda3\lib\site-packages\pandas\compat\numpy\__init__.py:4, in <module>
#       1 """ support numpy compatibility across versions """
#       2 import numpy as np
# ----> 4 from pandas.util.version import Version
#       6 # numpy versioning
#       7 _np_version = np.__version__
#
# File c:\Users\Seema\anaconda3\lib\site-packages\pandas\util\__init__.py:1, in <module>
# ----> 1 from pandas.util._decorators import (  # noqa:F401
#       2     Appender,
#       3     Substitution,
#       4     cache_readonly,
#       5 )
#       7 from pandas.core.util.hashing import (  # noqa:F401
#       8     hash_array,
#       9     hash_pandas_object,
#      10 )
#      13 def __getattr__(name):
#
# File c:\Users\Seema\anaconda3\lib\site-packages\pandas\util\_decorators.py:14, in <module>
#       6 from typing import (
#       7     Any,
#       8     Callable,
#       9     Mapping,
#      10     cast,
#      11 )
#      12 import warnings
# ---> 14 from pandas._libs.properties import cache_readonly  # noqa:F401
#      15 from pandas._typing import F
#      18 def deprecate(
#      19     name: str,
#      20     alternative: Callable[..., Any],
#    (...)
#      25     msg: str | None = None,
#      26 ) -> Callable[[F], F]:
#
# File c:\Users\Seema\anaconda3\lib\site-packages\pandas\_libs\__init__.py:13, in <module>
#       1 __all__ = [
#       2     "NaT",
#       3     "NaTType",
#    (...)
#       9     "Interval",
#      10 ]
# ---> 13 from pandas._libs.interval import Interval
#      14 from pandas._libs.tslibs import (
#      15     NaT,
#      16     NaTType,
#    (...)
#      21     iNaT,
#      22 )
#
# File c:\Users\Seema\anaconda3\lib\site-packages\pandas\_libs\interval.pyx:1, in init pandas._libs.interval()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\seema\anaconda3\lib\site-packages (1.4.2)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy>=1.18.5 in c:\users\seema\anaconda3\lib\site-packages (from pandas) (2.0.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\seema\anaconda3\lib\site-packages (from pandas) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\seema\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\seema\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
np.random.seed(42)
n = 500

# %%
data = pd.DataFrame({
    "attendance_rate":np.random.normal(75,10,n).clip(40,100),
    "avg_marks":np.random.normal(80,40,n).clip(30,100),
    "assignments_submitted":np.random.normal(80,15,n).clip(20,100),
    "disciplinary_cases":np.random.poisson(1.2,n)
})

# %%
data
# Out:
#      attendance_rate   avg_marks  assignments_submitted  disciplinary_cases
# 0          79.967142  100.000000             100.000000                   0
# 1          73.617357  100.000000              93.869505                   2
# 2          81.476885   30.000000              80.894456                   0
# 3          90.230299  100.000000              70.295948                   1
# 4          72.658466   53.974297              90.473350                   2
# ..               ...         ...                    ...                 ...
# 495        80.389100   68.755988             100.000000                   2
# 496        64.627538  100.000000             100.000000                   0
# 497        73.096613  100.000000              98.125493                   0
# 498        66.243817   57.152840              95.360938                   2
# 499        61.172003  100.000000              88.887904                   1
#
# [500 rows x 4 columns]

# %%
data["dropout"] =(
    (data["attendance_rate"]<60) |
    (data["avg_marks"]<50) |
    (data["disciplinary_cases"]>3)
).astype(int)

# %%
data
# Out:
#      attendance_rate   avg_marks  assignments_submitted  disciplinary_cases  \
# 0          79.967142  100.000000             100.000000                   0
# 1          73.617357  100.000000              93.869505                   2
# 2          81.476885   30.000000              80.894456                   0
# 3          90.230299  100.000000              70.295948                   1
# 4          72.658466   53.974297              90.473350                   2
# ..               ...         ...                    ...                 ...
# 495        80.389100   68.755988             100.000000                   2
# 496        64.627538  100.000000             100.000000                   0
# 497        73.096613  100.000000              98.125493                   0
# 498        66.243817   57.152840              95.360938                   2
# 499        61.172003  100.000000              88.887904                   1
#
#      dropout
# 0          0
# 1          0
# 2          1
# 3          0
# 4          0
# ..       ...
# 495        0
# 496        0
# 497        0
# 498        0
# 499        0
#
# [500 rows x 5 columns]

# %%
X = data.drop("dropout", axis=1)

# %%
X
# Out:
#      attendance_rate   avg_marks  assignments_submitted  disciplinary_cases
# 0          79.967142  100.000000             100.000000                   0
# 1          73.617357  100.000000              93.869505                   2
# 2          81.476885   30.000000              80.894456                   0
# 3          90.230299  100.000000              70.295948                   1
# 4          72.658466   53.974297              90.473350                   2
# ..               ...         ...                    ...                 ...
# 495        80.389100   68.755988             100.000000                   2
# 496        64.627538  100.000000             100.000000                   0
# 497        73.096613  100.000000              98.125493                   0
# 498        66.243817   57.152840              95.360938                   2
# 499        61.172003  100.000000              88.887904                   1
#
# [500 rows x 4 columns]

# %%
y = data["dropout"]

# %%
y
# Out:
# 0      0
# 1      0
# 2      1
# 3      0
# 4      0
#       ..
# 495    0
# 496    0
# 497    0
# 498    0
# 499    0
# Name: dropout, Length: 500, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
X_train
# Out:
#      attendance_rate   avg_marks  assignments_submitted  disciplinary_cases
# 227        64.222552   93.903268              77.794970                   4
# 417        76.156746   87.464365              84.028884                   0
# 203        85.538021   30.000000              88.149470                   1
# 126        65.094637   40.415807              84.539532                   2
# 329        81.283455   68.728616              88.998931                   1
# ..               ...         ...                    ...                 ...
# 106        93.861859   49.048432              89.191609                   1
# 270        89.412733  100.000000              96.369652                   1
# 348        67.815558   54.490401              59.496820                   2
# 435        75.740948   59.917831              84.238699                   0
# 102        71.572855  100.000000             100.000000                   3
#
# [375 rows x 4 columns]

# %%
X_test
# Out:
#      attendance_rate  avg_marks  assignments_submitted  disciplinary_cases
# 361        90.327389  30.000000              88.689372                   1
# 73         90.646437  71.235979              60.755117                   2
# 374        96.531825  78.674921             100.000000                   1
# 155        67.856486  82.368737              95.147256                   0
# 104        73.387143  96.537396              96.622742                   0
# ..               ...        ...                    ...                 ...
# 220        98.146586  92.312071              62.186024                   0
# 176        75.130019  35.576966              54.605648                   2
# 320        75.969960  59.308462              80.849749                   0
# 153        77.322537  35.738964              60.153653                   1
# 231        77.164586  40.865089              59.452955                   1
#
# [125 rows x 4 columns]

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.fit_transform(X_test)

# %%
X_train_scaled
# Out:
# array([[-1.0983454 ,  0.75933133, -0.19133222,  2.40723973],
#        [ 0.11235364,  0.49741138,  0.25852556, -1.06474065],
#        [ 1.06406428, -1.84010839,  0.55587931, -0.19674555],
#        ...,
#        [-0.7338425 , -0.84389455, -1.51178115,  0.67124954],
#        [ 0.07017174, -0.62311902,  0.27366644, -1.06474065],
#        [-0.35267257,  1.00733252,  1.41104875,  1.53924463]])

# %%
models = {
    "Logistic Regression":LogisticRegression(max_iter=1000),
    "Decision Tree":DecisionTreeClassifier(max_depth=5),
    "Random Forest":RandomForestClassifier(n_estimators=100),
    "SVM":SVC(probability=True)
}

# %%
result=[]

for name, model in models.items():
    if name in["Logistic Regression","SVM"]:
        model.fit(X_train_scaled, y_train)
        y_pred = model.predict(X_test_scaled)
        y_prob = model.predict_proba(X_test_scaled)[:1]
    else:
        model.fit(X_train,y_train)
        y_pred = model.predict(X_test)
        y_prob = model.predict_proba(X_test)[:1]

# %%
cm =  confusion_matrix(y_test,y_pred)

# %%
result.append({
    "Model": name,
    "Accuracy":accuracy_score(y_test,y_pred),
    "Precision":precision_score(y_test,y_pred),
    "Recall":recall_score(y_test,y_pred),
    "FI-Score":f1_score(y_test,y_pred),
    "ROC-AUC":roc_auc_score(y_test,y_pred),
    "Confusion Matrix":cm
})

# %%
result_df = pd.DataFrame(result)
print(result_df)
# Out:
#   Model  Accuracy  Precision    Recall  FI-Score   ROC-AUC    Confusion Matrix
# 0   SVM     0.944        1.0  0.810811  0.895522  0.905405  [[88, 0], [7, 30]]

# %%
for r in result:
    print(f"\n{r['Model']}Confusion Matrix:")
    print(r["Confusion Matrix"])
# Out:
# SVMConfusion Matrix:
# [[88  0]
#  [ 7 30]]
