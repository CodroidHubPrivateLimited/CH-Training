# %%
import numpy as np
import pandas as pd
#Task1
df=pd.DataFrame(
    {'Member ID':[1,2,3,4,5]},
    {'Member Name':['Neha', 'Sumedha', 'Seema', 'Reena','Lalit']},
    {'Membership type':['Student','Faculty','External']})

# %%
valid_membership=['Neha', 'Sumedha', 'Seema', 'Reena','Lalit']
df=df[df['Membership type'].isin(valid_membership)]
df
# Out:
# Empty DataFrame
# Columns: [Membership type]
# Index: []

# %%
#Task2
#Record book information
book=pd.DataFrame(
    {'Book_ID':[1,2,3,4,5]},
    {'Book_Name':['C++','Java','Python','DS','Expert System']},
    {'Book_Author_Name':['Dev','Hari','John','Shreya','Sneha']}
)
book
# Out:
#           Book_Author_Name
# Book_Name              NaN

# %%
if len(book)==0:
  print("No book available")

# %%
#Task 3
