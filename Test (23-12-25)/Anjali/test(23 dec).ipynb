# %%
import pandas as pd
import numpy as np
ccount_number = input("Enter Account Number: ")

customer_name = input("Enter Customer Name: ")
if not customer_name.isalpha():
    raise ValueError("Customer name must contain only alphabets.")

account_type = input("Enter Account Type (Savings/Current): ").lower()
if account_type not in ["savings", "current"]:
    raise ValueError("Invalid account type.")

initial_balance = float(input("Enter Initial Balance: "))
if initial_balance < 1000:
    raise ValueError("Initial balance must be at least ₹1,000.")

# %%
account = BankAccount(account_number, customer_name, account_type, initial_balance)
print(f"\nAccount created successfully!")
print(f"Account Number: {account.account_number}")
print(f"Current Balance: ₹{account.balance}")

# %%
deposit_amount = float(input("\nEnter deposit amount: "))
account.deposit(deposit_amount)

# %%
withdraw_amount = float(input("\nEnter withdrawal amount: "))
account.withdraw(withdraw_amount)
