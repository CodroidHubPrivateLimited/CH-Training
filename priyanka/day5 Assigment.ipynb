# %%
# Data Augmentation
import numpy as np
import pandas as pd

# %%
np.random.seed(42)
n=500
df = pd.DataFrame ({
    "Age": np.random.randint(20,26,n),
    "CGPA" : np.round(np.random.uniform(6.0,9.5,n), 2),
    "Internship_Count": np.random.randint(0,4,n),
    "Technical_Score" : np.random.randint(50,100, n),
    "Attendence_Percentage": np.random.randint (60,100,n)
    "First Name":np.random.rantint(50,100,n)
    "last Name":np.random.rantint(70,100,n)
    "Address":np.random.rantint(50,100,n)
    
    
    
})
# Out:
#   Cell In[2], line 8
#     "Attendence_Percentage": np.random.randint (60,100,n)
#                              ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
