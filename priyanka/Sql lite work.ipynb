# %%
import sqlite3 as sql
connection =sql.connect('demo.db')
cursor=connection.cursor() #db tracing

# %%
connection.commit()

# %%
cursor.execute("insert into Student1( id,name,age ,Values(2, 'honey',22);")
#connection.execute("")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 cursor.execute("insert into Student1( id,name,age ,Values(2, 'honey',22);")
#       2 #connection.execute("")
#
# OperationalError: near "Values": syntax error
