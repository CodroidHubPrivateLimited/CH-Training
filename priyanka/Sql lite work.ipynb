# %%
import sqlite3 as sql
connection =sql.connect('demo.db')
cursor=connection.cursor() #db tracing

# %%
connection.commit()

# %%
connection.commit()

# %%
cursor.execute("Insert into Student2 (id,name,age)values (2,'PRIYANKA',23)")
connection.execute("")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 cursor.execute("Insert into Student2 (id,name,age)values (2,'PRIYANKA',23)")
#       2 connection.execute("")
#
# OperationalError: no such table: Student2

# %%
import pandas as pd #

# %%
import pandas as pd#
