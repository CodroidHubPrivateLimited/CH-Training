# %%
num1=10
type(num1)
# Out:
# int

# %%
print (num1.__class__)
# Out:
# <class 'int'>

# %%
print("hello world")#with print statement it convert object into string  whether its possible in another program
"hello" # without print statement
# Out:
# hello world
# 'hello'

# %%
print (20+30) #it convert object into string
# Out:
# 50

# %%
pr=print ("hello")
print (pr)
# Out:
# hello
# None

# %%
sum1 =print(20 +3) #
#when you display the print statement  and store in variable sum1 ,
#  it will display nome becuase it will take only print  statement that type none

print (sum1)
# Out:
# 23
# None

# %%
sum1=10+20 #this statement tell the data type of sum1 that is of int
type(sum1)
# Out:
# int

# %%
10+20
# Out:
# 30

# %%
_+20#  significance if ypu want to add the value in the given output then you have to use underscore
# Out:
# 50

# %%
10+30
# Out:
# 40

# %%
_+30 #  if you want to addthe output 40  with 30 value then output 70
# Out:
# 70

# %%
print ("A", "B",sep=",", end="!\n")
# Out:
# A,B!

# %%
num1=32
num2=40
print ("num1:",num1,"num2:",num2) # if you display the value of  num1 and num2 in variable
print(num1,num2)
# Out:
# num1: 32 num2: 40
# 32 40

# %%
# print + String Formatting
price =200
tax=18
print (f"The total amount is{price+tax}") #f is used for formatting string
# Out:
# The total amount is218

# %%
price =200
tax=18
print ("The total amount is:", price+tax) #f is used for formatting string
# Out:
# The total amount is: 218

# %%
pi=3.1415
print (f"{pi:.3f}")
# Out:
# 3.142

# %%
pi=3
print (f"{pi:04d}")#total size is 4 inculuding 3 zeros
# Out:
# 0003

# %%
name="Priyanka"
print (f"{name:>20}")
print (f"{"Priyanka":^20}") #you can add string directly in double quotes
print (f"{name:<20}")
# Out:
#             Priyanka
#       Priyanka
# Priyanka

# %%
class student:
    def __init__(self,name,marks): #magic mthod is init
        self.name=name   #inbulit functions constructor call ing implicity
        self.marks=marks
    def display(self):
        print (f"Name:{self.name}, Marks:{self.marks}")

# %%
stud1= student("Priyanka",93)
print(stud1.display())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[103], line 2
#       1 stud1= student("Priyanka",93)
# ----> 2 print(stud1.display())
#
# AttributeError: 'student' object has no attribute 'display'

# %%
class Student:
    def __init__(self,name:str,marks :int): #magic mthod is init
        self.name=name   #inbulit functions constructor call ing implicity
        self.marks=marks
        def display(self)->str:
             print (f"Name:{self.name}, Marks:{self.marks}")
             return (f"Name:{self.name}, Marks:{self.marks}")
        stude2= Student("43",93)
        print (stud2.display())

# %%
class Student:
    def __init__(self,name:str,marks :int):
        if not isinstance(name,str):
            raise TypeError("name must be string" )
        if not isinstance(marks,int):
            raise TypeError("marks must be integer")
        self.name=name   #inbulit functions constructor call ing implicity
        self.marks=marks
        def display(self)->str:
             print (f"Name:{self.name}, Marks:{self.marks}")
             return (f"Name:{self.name}, Marks:{self.marks}")
        stude2= Student("43",93)
        print (stud2.display())

# %%
num1=10
type(num1)
num1
# Out:
# 10

# %%
num1=str(num1)
num1
# Out:
# '10'
