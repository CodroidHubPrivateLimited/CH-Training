# %%
import numpy as np
import pandas as pd

# %%
np.random.seed(45)
n = 200
        {
            "cell_type": "code",
            "id": "#VSC-f467054c",
            "metadata": {
                "language": "python"
            },
            "source": [
                "np.random.seed(45)",
                "n = 200",
                "data = {",
                "    'student_ID': np.arange(100, 100 + n),",
                "    'age': np.random.randint(18, 30, n),",
                "    'marks': np.random.randint(40, 100, n),",
                "    'grade': np.random.choice(['A', 'B', 'C', 'D', 'E'], n),",
                "    'department': np.random.choice(['Physics', 'Chemistry', 'Mathematics', 'Biology', 'Computer Science'], n)",
                "}"
            ]
        },
