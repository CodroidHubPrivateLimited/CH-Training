# %%
import re

# %%
# !pip install nltk

# %%
# !pip install pyspellchecker

# %%
from spellchecker import spellchecker

# %%
import nltk
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_54032/1734127563.py in <module>
# ----> 1 import nltk
#
# c:\Users\DELL\Anaconda3\lib\site-packages\nltk\__init__.py in <module>
#     130 # Import top-level functionality into top-level namespace
#     131
# --> 132 from nltk.collocations import *
#     133 from nltk.decorators import decorator, memoize
#     134 from nltk.featstruct import *
#
# c:\Users\DELL\Anaconda3\lib\site-packages\nltk\collocations.py in <module>
#      34
#      35 # these two unused imports are referenced in collocations.doctest
# ---> 36 from nltk.metrics import (
#      37     BigramAssocMeasures,
#      38     ContingencyMeasures,
#
# c:\Users\DELL\Anaconda3\lib\site-packages\nltk\metrics\__init__.py in <module>
#      16 from nltk.metrics.agreement import AnnotationTask
#      17 from nltk.metrics.aline import align
# ...

# %%
from spellchecker import spellchecker
import nltk
from nltk.tokenize import word_takenize
from nltk.corpus import stopwords
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_54032/446261901.py in <module>
#       1 from spellchecker import spellchecker
# ----> 2 import nltk
#       3 from nltk.tokenize import word_takenize
#       4 from nltk.corpus import stopwords
#
# c:\Users\DELL\Anaconda3\lib\site-packages\nltk\__init__.py in <module>
#     130 # Import top-level functionality into top-level namespace
#     131
# --> 132 from nltk.collocations import *
#     133 from nltk.decorators import decorator, memoize
#     134 from nltk.featstruct import *
#
# c:\Users\DELL\Anaconda3\lib\site-packages\nltk\collocations.py in <module>
#      34
#      35 # these two unused imports are referenced in collocations.doctest
# ---> 36 from nltk.metrics import (
#      37     BigramAssocMeasures,
#      38     ContingencyMeasures,
#
# ...

# %%
nltk.dwnload('punkt')
nltk.dwnload('stopwords')
ltk.dwnload('punkt_tab')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_54032/1306183143.py in <module>
# ----> 1 nltk.dwnload('punkt')
#       2 nltk.dwnload('stopwords')
#       3 ltk.dwnload('punkt_tab')
#
# NameError: name 'nltk' is not defined

# %%
text = "OMG!! 😱 I cant believed u getting the job!!! thats gr8! 🎉 I'm so happi for u! 😊 btw, I still remembr when we last met, u were so nervous abt the interview..lol 😂. Hope u come soon so we can hang out! 😎 Don't forget to call me 2moro!! 📞"

# %%
stop_word = set(stopwords.Words('English'))
filtered_token =
