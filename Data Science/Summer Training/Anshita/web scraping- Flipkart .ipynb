# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
 }

# %%
url="https://www.flipkart.com/search?q=laptop&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off"

# %%
response=requests.get(url, headers=headers)

# %%
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <link href="https://rukminim2.flixcart.com" rel="preconnect"/>
#   <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.c48a12.css" rel="stylesheet"/>
#   <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.066267.css" rel="stylesheet"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="102988293558" property="fb:page_id"/>
#   <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
#   <link href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/>
#   <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
#   <meta content="website" property="og:type"/>
#   <meta content="Flipkart.com" name="og_site_name" property="og:site_name"/>
# ...

# %%
product=soup.find_all("div",class_ ="_75nlfW")

# %%
print(len(product))
# Out:
# 24

# %%
product
# Out:
# [<div class="_75nlfW"><div data-id="COMGZUYDGFJGHZR4" style="width:100%"><div class="tUxRFH"><a class="CGtC98" href="/samsung-galaxy-book4-metal-intel-core-i5-13th-gen-1335u-16-gb-512-gb-ssd-windows-11-home-np750xgj-kg2in-np750xgj-lg2in-thin-light-laptop/p/itm1df5212efb9fc?pid=COMGZUYDGFJGHZR4&amp;lid=LSTCOMGZUYDGFJGHZR4AA4AUB&amp;marketplace=FLIPKART&amp;q=laptop&amp;store=6bo%2Fb5g&amp;srno=s_1_1&amp;otracker=search&amp;otracker1=search&amp;fm=organic&amp;iid=en_FMFFDRLSXFyPGao-dbReSQDEYvzAAHIKndIDFmHTnIZA8QhE5hyJ2ObdsW76LiwFcQF7cPftrh4hJf0D_fTj8fUFjCTyOHoHZs-Z5_PS_w0%3D&amp;ppt=None&amp;ppn=None&amp;ssid=2cr8qbck3k0000001754382282552&amp;qH=312f91285e048e09" rel="noopener noreferrer" target="_blank"><div class="Otbq5D"><div class="yPq5Io"><div><div class="_4WELSP" style="height:200px;width:200px"><img alt="Samsung Galaxy Book4 Metal Intel Core i5 13th Gen 1335U - (16 GB/512 GB SSD/Windows 11 Home) NP750XGJ-..." class="DByuf4" loading="eager" src="https://rukminim2.flixcart.com/ima
# ...

# %%
Laptop=[]

# %%
for i in product:
    title=i.find( "div" ,class_="KzDlHZ").get_text(strip=True)
    price=i.find("div", class_="Nx9bqj _4b5DiR").get_text(strip=True)
    features=i.find("ul", class_="G4BRas").get_text(strip=True)
    rating=i.find("div",class_="XQDdHH")
    if rating:
        ratings=rating.get_text(strip=True)

        Laptop.append({
     "Name":title,
      "Price": price,
    "Ratings" : ratings,

        })

# %%
Laptop
# Out:
# [{'Name': 'Samsung Galaxy Book4 Metal Intel Core i5 13th Gen 1335U - (16 GB/512 GB SSD/Windows 11 Home) NP750XGJ-...',
#   'Price': '₹50,990',
#   'Ratings': '4.4'},
#  {'Name': 'Lenovo 100e Chromebook Gen 4 MediaTek Kompanio 520 - (4 GB/32 GB EMMC Storage/Chrome OS) 82W00004HA Ch...',
#   'Price': '₹8,990',
#   'Ratings': '3.9'},
#  {'Name': 'ASUS Expertbook P1 Intel Core i3 13th Gen 1315U - (8 GB/512 GB SSD/Windows 11 Home) P1403CVA-S60343WS ...',
#   'Price': '₹34,490',
#   'Ratings': '4.1'},
#  {'Name': 'Acer Aspire 3 Intel Celeron Dual Core - (8 GB/256 GB SSD/Windows 11 Home) A311-45 Thin and Light Lapto...',
#   'Price': '₹15,990',
#   'Ratings': '3.7'},
#  {'Name': 'Acer Aspire 3 Backlit AMD Ryzen 7 Octa Core 7730U - (16 GB/512 GB SSD/Windows 11 Home) Aspire AS15 - 4...',
#   'Price': '₹37,990',
#   'Ratings': '4'},
#  {'Name': 'Acer Aspire 3 Intel Core i3 13th Gen 1305U - (8 GB/512 GB SSD/Windows 11 Home) A324-53 Thin and Light ...',
#   'Price': '₹27,990',
# ...

# %%
df=pd.DataFrame(Laptop)

# %%
df
# Out:
#                                                  Name    Price Ratings
# 0   Samsung Galaxy Book4 Metal Intel Core i5 13th ...  ₹50,990     4.4
# 1   Lenovo 100e Chromebook Gen 4 MediaTek Kompanio...   ₹8,990     3.9
# 2   ASUS Expertbook P1 Intel Core i3 13th Gen 1315...  ₹34,490     4.1
# 3   Acer Aspire 3 Intel Celeron Dual Core - (8 GB/...  ₹15,990     3.7
# 4   Acer Aspire 3 Backlit AMD Ryzen 7 Octa Core 77...  ₹37,990       4
# 5   Acer Aspire 3 Intel Core i3 13th Gen 1305U - (...  ₹27,990     4.3
# 6   Acer Aspire 3 Intel Celeron Dual Core - (8 GB/...  ₹14,870     3.9
# 7   Acer Aspire 3 Intel Celeron Dual Core - (8 GB/...  ₹17,990     3.9
# 8   HP MSO 2024 Intel Core i3 13th Gen 1315U - (16...  ₹40,000     3.9
# 9   Acer Aspire 3 Intel Celeron Dual Core N4500 - ...  ₹21,990     3.9
# 10  Samsung Galaxy Book4 Metal Intel Core i3 13th ...  ₹34,990     4.5
# 11  ASUS Chromebook Intel Celeron Dual Core N4500 ...  ₹14,990     3.8
# ...

# %%
df.to_csv("Flipkart-Laptop.csv")

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data1= np.sort(df["Ratings"])

# %%
plt.bar(df["Name"], data)
plt.xticks(rotation=90)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 plt.bar(df["Name"], data)
#       2 plt.xticks(rotation=90)
#       3 plt.show()
#
# NameError: name 'data' is not defined

# %%
from collections import Counter
counts = Counter(df["Ratings"])
labels = list(counts.keys())
sizes = list(counts.values())
plt.pie(sizes, labels = labels, autopct = "%1.1f%%")
plt.show()
