# %% [markdown]
# ## Create a nested dictonary which stores the details of the students and the grades of the student

# %%
student={
    'name':'chetan',
    'age':21,
    'grade':{
        'math':93,
        'science':
    }

    
}
