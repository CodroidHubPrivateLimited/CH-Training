# %%
a='*'
for i in range(6):
    for j in range(6):
        print(a,end=" ")
    print()
    # op=1
# Out:
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *

# %%
for i in range(6):
    print("* "*6)
# Out:
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *

# %%
for i in range(6):
    if i==0:
        print("* "*6)
    else:
        print("*"+" "*4+"*")
# Out:
# * * * * * *
# *    *
# *    *
# *    *
# *    *
# *    *
