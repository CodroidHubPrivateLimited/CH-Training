# %%
from bs4 import BeautifulSoup as b 
import requests as r
import pandas as pd

# %%
url='https://www.hungama.com/all/premium-rental-movies/'

# %%
headers={    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/536.37 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}
response=r.get(url,headers=headers)
response
# Out:
# <Response [200]>

# %%
movie=b(response.content,'html.parser')

# %%
movie
# Out:
# <!DOCTYPE html>
# <html lang="en"><head>
# <!-- <script type="text/javascript">
#     (function(c,l,a,r,i,t,y){
#         c[a]=c[a]||function(){(c[a].q=c[a].q||[]).push(arguments)};
#         t=l.createElement(r);t.async=1;t.src="https://www.clarity.ms/tag/"+i;
#         y=l.getElementsByTagName(r)[0];y.parentNode.insertBefore(t,y);
#     })(window, document, "clarity", "script", "mvb6zmir19");
# </script> -->
# <link href="https://assetsun.hungama.com/css/dropdown.css" media="print" onload="this.media='all'" rel="stylesheet"/>
# <link href="https://assetsun.hungama.com/css/card-with-play-slider.css" media="print" onload="this.media='all'" rel="stylesheet"/>
# <link href="https://assetsun.hungama.com/css/premium-movie-slider.css" media="print" onload="this.media='all'" rel="stylesheet"/>
# <link href="https://assetsun.hungama.com/css/artist-slider.css" media="print" onload="this.media='all'" rel="stylesheet"/>
# ...

# %%
print(movie.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <!-- <script type="text/javascript">
#     (function(c,l,a,r,i,t,y){
#         c[a]=c[a]||function(){(c[a].q=c[a].q||[]).push(arguments)};
#         t=l.createElement(r);t.async=1;t.src="https://www.clarity.ms/tag/"+i;
#         y=l.getElementsByTagName(r)[0];y.parentNode.insertBefore(t,y);
#     })(window, document, "clarity", "script", "mvb6zmir19");
# </script> -->
#   <link href="https://assetsun.hungama.com/css/dropdown.css" media="print" onload="this.media='all'" rel="stylesheet"/>
#   <link href="https://assetsun.hungama.com/css/card-with-play-slider.css" media="print" onload="this.media='all'" rel="stylesheet"/>
#   <link href="https://assetsun.hungama.com/css/premium-movie-slider.css" media="print" onload="this.media='all'" rel="stylesheet"/>
#   <link href="https://assetsun.hungama.com/css/artist-slider.css" media="print" onload="this.media='all'" rel="stylesheet"/>
# ...

# %%
all_movies=movie.find_all('div',class_='trending_slider zoom_in_slider')

# %%
len(all_movies)
# Out:
# 0
