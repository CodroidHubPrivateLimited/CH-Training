# %%
from bs4 import BeautifulSoup as b
import requests as r
import pandas as pd

# %%
url='https://www.zeptonow.com/search?query=biscuit'

# %%
# res=r.get(url)

headers={    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/536.37 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}
res=r.get(url,headers=headers)
res
# Out:
# <Response [200]>

# %%
zepto=b(res.content,'html.parser')

# %%
zepto
# Out:
# <!DOCTYPE html>
# ...

# %%
print(zepto.prettify())
# Out:
# <!DOCTYPE html>
# <html class="font-mweb lg:font-desktop" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
#   <link data-precedence="next" href="https://cdn.zeptonow.com/web-static-assets-prod/artifacts/13.17.2/_next/static/css/560486fcd893463b.css" rel="stylesheet"/>
#   <link as="script" fetchpriority="low" href="https://cdn.zeptonow.com/web-static-assets-prod/artifacts/13.17.2/_next/static/chunks/webpack-0e81bfe72d66107d.js" rel="preload"/>
#   <script async="" src="https://cdn.zeptonow.com/web-static-assets-prod/artifacts/13.17.2/_next/static/chunks/87c73c54-69ef69b7676879fd.js">
#   </script>
#   <script async="" src="https://cdn.zeptonow.com/web-static-assets-prod/artifacts/13.17.2/_next/static/chunks/696-b3185588f3170684.js">
#   </script>
#   <script async="" src="https://cdn.zeptonow.com/web-static-assets-prod/artifacts/13.17.2/_next/static/chunks/main-app-ae3f64652839e3ee.js">
# ...

# %%
all_names=zepto.find_all('div',class_='v4er3 Ilt0K')

# %%
len(all_names)
# Out:
# 0

# %%
# for bqt in all_biscuits
