# %%
num1=10
type=(num1)

# %%
print("Hello World")
print(type)
# Out:
# Hello World
# 10

# %%
"Hello World"
# Out:
# 'Hello World'

# %%
print(20+30)
# Out:
# 50

# %%
20+30
# Out:
# 50

# %%
_+20
# Out:
# 70

# %%
print("A","B",sep=",",end=" !\n")
# Out:
# A,B !

# %%
num3=40
num4=50
print("num3:",num3, "num4:",num4, sep=" | ", end=" ***\n")
# Out:
# num3: | 40 | num4: | 50 ***

# %%
print(num3,num4)
# Out:
# 40 50

# %%
price=100
tax= 18
print("Total Price:", price + tax)
# Out:
# Total Price: 118

# %%
pi= 3.14
print(f"value of pi up to  {pi}")
# Out:
# value of pi up to  3.14
