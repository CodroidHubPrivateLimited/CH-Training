# %%
num1=10
type=(num1)

# %%
print("Hwllo World")
print(type)
# Out:
# Hwllo World
# 10

# %%
"Hello World"
# Out:
# 'Hello World'

# %%
'Hello World'
# Out:
# 'Hello World'

# %%
print(20+30)
# Out:
# 50

# %%
20+30
# Out:
# 50

# %%
_+20
# Out:
# 70

# %%
print("A","B",sep=",",end="!\n ")
# Out:
# A,B!

# %%
num3=40
num4=50
print("num3:",num3,"num4:",num4,sep=" | ",end=".\n")
# Out:
# num3: | 40 | num4: | 50.

# %%
print(num3,num4)
# Out:
# 40 50

# %%
# Print + String formatting

price= 200
tax =18
print(f"The total price is {price + tax}")
# Out:
# The total price is 218

# %%
pi = 3.14159 
print(f"Value of pi up to 2 decimal places: {pi:.2f}")
# Out:
# Value of pi up to 2 decimal places: 3.14

# %%
pi = 3
print(f"{pi:03d}")
# Out:
# 003

# %%
name= "Deepanshu_Saini"
print(f"{name:^150}")
# Out:
#                                                                    Deepanshu_Saini
