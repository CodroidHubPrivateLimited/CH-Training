# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
headers = {
"User-Agent": "Mozilla/5.0"
}

# %%
url = "https://finance.yahoo.com/markets/crypto/gainers/"

# %%
response = requests.get(url, headers=headers)

# %%
soup = BeautifulSoup(response.text, "html.parser")

# %%
table = soup.find("table")
if table is None:
	print("Table not found. The data may be loaded dynamically")
else:
	rows = table.find("tbody").find_all("tr")

# %%
data=[]

# %%
for row in rows:
	cols = row.find_all("td")
	data.append([col.get_text(strip=True) for col in cols])

# %%
data
# Out:
# [['SSEAGULL-USD',
#   'SEAGULL SAM USD',
#   '',
#   '0.30+0.30(+634,591.60%)',
#   '+0.30',
#   '+634,591.60%',
#   '0',
#   '43,141',
#   '43,141',
#   '43,141',
#   '0',
#   '-99.55%',
#   '0.000.03'],
#  ['DDOGEX38772-USD',
#   'DOGEX USD',
#   '',
#   '0.00+0.00(+3,781.24%)',
#   '+0.00',
#   '+3,781.24%',
#   '0',
#   '139,443',
#   '139,443',
#   '139,443',
#   '0',
#   '-75.00%',
#   '0.000.00'],
#  ['CCATX31291-USD',
#   'CATX USD',
#   '',
#   '0.00+0.00(+2,802.50%)',
#   '+0.00',
#   '+2,802.50%',
#   '0',
#   '166,286',
#   '166,286',
#   '166,286',
#   '0',
#   '+300.00%',
#   '0.000.00'],
#  ['VVMC37642-USD',
#   'VMS Classic USD',
#   '',
#   '24.44+22.22(+1,000.90%)',
#   '+22.22',
#   '+1,000.90%',
#   '0',
#   '72,036',
#   '72,036',
#   '72,036',
#   '0',
#   '-95.85%',
#   '1.892,462.19'],
#  ['GGROK36159-USD',
#   'TRUMP GROK (trumpgrok.org) USD',
#   '',
#   '0.00+0.00(+668.76%)',
#   '+0.00',
#   '+668.76%',
#   '0',
#   '874,010',
#   '874,010',
#   '874,010',
#   '0',
#   '+400.00%',
#   '0.000.00'],
#  ['HHOOD37295-USD',
#   'Robinhood USD',
#   '',
#   '0.03+0.02(+613.19%)',
#   '+0.02',
#   '+613.19%',
#   '0',
#   '19,346',
#   '19,346',
#   '19,346',
#   '0',
#   '+4,669.73%',
#   '0.0014.20'],
#  ['BBEER32150-USD',
#   'Beers USD',
#   '',
#   '0.00+0.00(+552.13%)',
#   '+0.00',
#   '+552.13%',
#   '0',
#   '376,933',
#   '376,933',
#   '376,933',
#   '0',
#   '-99.95%',
#   '0.001.15'],
#  ['TTRUMP32865-USD',
#   'TRUMP AI USD',
#   '',
#   '0.00+0.00(+459.45%)',
#   '+0.00',
#   '+459.45%',
#   '0',
#   '347,905',
#   '347,905',
#   '347,905',
#   '0',
#   '-74.64%',
#   '0.000.37'],
#  ['BBPX10720-USD',
#   'Black Phoenix USD',
#   '',
#   '2.40+1.97(+459.35%)',
#   '+1.97',
#   '+459.35%',
#   '0',
#   '14.293M',
#   '14.293M',
#   '14.293M',
#   '0',
#   '+4.83%',
#   '0.003.38'],
#  ['TTRUMP31874-USD',
#   'PEPE USD',
#   '',
#   '0.00+0.00(+445.52%)',
#   '+0.00',
#   '+445.52%',
#   '0',
#   '248,815',
#   '248,815',
#   '248,815',
#   '0',
#   '-99.07%',
#   '0.000.00'],
#  ['GGME32488-USD',
#   'GameStop Coin USD',
#   '',
#   '0.00+0.00(+444.16%)',
#   '+0.00',
#   '+444.16%',
#   '0',
#   '348,253',
#   '348,253',
#   '348,253',
#   '0',
#   '-50.00%',
#   '0.000.44'],
#  ['MMOODENG33647-USD',
#   'Moo Deng (moodeng.sbs) USD',
#   '',
#   '0.00+0.00(+434.85%)',
#   '+0.00',
#   '+434.85%',
#   '0',
#   '72,144',
#   '72,144',
#   '72,144',
#   '0',
#   '-99.50%',
#   '0.000.00'],
#  ['PPEOPLE32079-USD',
#   'MAGA USD',
#   '',
#   '0.00+0.00(+416.35%)',
#   '+0.00',
#   '+416.35%',
#   '0',
#   '136,563',
#   '136,563',
#   '136,563',
#   '0',
#   '-98.95%',
#   '0.000.12'],
#  ['RRATS34039-USD',
#   'rats (Ethereum) USD',
#   '',
#   '52,728,967,168.00+41,373,396,992.00(+364.34%)',
#   '+41,373,396,992.00',
#   '+364.34%',
#   '0',
#   '167,488',
#   '167,488',
#   '167,488',
#   '0',
#   '+764,561,168,793,600.00%',
#   '0.0013,960,887,300.00'],
#  ['GGROK33471-USD',
#   'SORA GROK USD',
#   '',
#   '2.52+1.97(+361.42%)',
#   '+1.97',
#   '+361.42%',
#   '0',
#   '205,765',
#   '205,765',
#   '205,765',
#   '0',
#   '+2,052,230.47%',
#   '0.0027.34'],
#  ['GGROOVE-USD',
#   'GROOVE USD',
#   '',
#   '0.00+0.00(+354.16%)',
#   '+0.00',
#   '+354.16%',
#   '0',
#   '121,925',
#   '121,925',
#   '121,925',
#   '0',
#   '-58.06%',
#   '0.000.00'],
#  ['CCOIN36756-USD',
#   '[Fake]COINBASE USD',
#   '',
#   '137.12+105.80(+337.83%)',
#   '+105.80',
#   '+337.83%',
#   '0',
#   '511,183',
#   '511,183',
#   '511,183',
#   '0',
#   '+312.59%',
#   '2.16423.75'],
#  ['BBSTER-USD',
#   'Bster USD',
#   '',
#   '0.01+0.01(+315.42%)',
#   '+0.01',
#   '+315.42%',
#   '0',
#   '199,086',
#   '199,086',
#   '199,086',
#   '0',
#   '+152.47%',
#   '0.000.03'],
#  ['BBASE38263-USD',
#   'Base AI USD',
#   '',
#   '0.00+0.00(+302.79%)',
#   '+0.00',
#   '+302.79%',
#   '0',
#   '395,008',
#   '395,008',
#   '395,008',
#   '0',
#   '-93.58%',
#   '0.000.00'],
#  ['TTRUMP36286-USD',
#   'PEPE TRUMP (pepetrump.cc) USD',
#   '',
#   '0.00+0.00(+294.04%)',
#   '+0.00',
#   '+294.04%',
#   '0',
#   '372,196',
#   '372,196',
#   '372,196',
#   '0',
#   '--',
#   '0.000.00'],
#  ['GGOAT38260-USD',
#   'Goatcoin USD',
#   '',
#   '0.00+0.00(+293.07%)',
#   '+0.00',
#   '+293.07%',
#   '0',
#   '181,931',
#   '181,931',
#   '181,931',
#   '0',
#   '-48.37%',
#   '0.000.00'],
#  ['HHBTC38220-USD',
#   'Hold BTC USD',
#   '',
#   '0.00+0.00(+285.93%)',
#   '+0.00',
#   '+285.93%',
#   '0',
#   '719,260',
#   '719,260',
#   '719,260',
#   '0',
#   '--',
#   '0.000.00'],
#  ['FFUR36326-USD',
#   'Furfication USD',
#   '',
#   '0.00+0.00(+282.08%)',
#   '+0.00',
#   '+282.08%',
#   '0',
#   '340,073',
#   '340,073',
#   '340,073',
#   '0',
#   '+838.10%',
#   '0.000.00'],
#  ['IIBIT37350-USD',
#   'BlackRock USD',
#   '',
#   '0.02+0.01(+270.35%)',
#   '+0.01',
#   '+270.35%',
#   '0',
#   '185,142',
#   '185,142',
#   '185,142',
#   '0',
#   '-35.23%',
#   '0.000.17'],
#  ['PPEPE36287-USD',
#   'PEPE AI (pepeai.one) USD',
#   '',
#   '0.00+0.00(+269.70%)',
#   '+0.00',
#   '+269.70%',
#   '0',
#   '286,081',
#   '286,081',
#   '286,081',
#   '0',
#   '+560.00%',
#   '0.000.00']]

# %%
print(data[0])
print(len(data[0]))
# Out:
# ['SSEAGULL-USD', 'SEAGULL SAM USD', '', '0.30+0.30(+634,591.60%)', '+0.30', '+634,591.60%', '0', '43,141', '43,141', '43,141', '0', '-99.55%', '0.000.03']
# 13

# %%
columns=[
"Symbol",
"Name",
" ",
"Price",
"Change",
"% Change",
"Market Cap",
"Volume ",
"Volume in currency( 24 hr)",
"Volume in all currencies(in 24 hr)",
"Circulating Supply",
"52 Weeks Change%",
" "
]

# %%
df = pd.DataFrame(data, columns=columns)

# %%
df
# Out:
#                Symbol                            Name    \
# 0        SSEAGULL-USD                 SEAGULL SAM USD
# 1     DDOGEX38772-USD                       DOGEX USD
# 2      CCATX31291-USD                        CATX USD
# 3       VVMC37642-USD                 VMS Classic USD
# 4      GGROK36159-USD  TRUMP GROK (trumpgrok.org) USD
# 5      HHOOD37295-USD                   Robinhood USD
# 6      BBEER32150-USD                       Beers USD
# 7     TTRUMP32865-USD                    TRUMP AI USD
# 8       BBPX10720-USD               Black Phoenix USD
# 9     TTRUMP31874-USD                        PEPE USD
# 10      GGME32488-USD               GameStop Coin USD
# 11  MMOODENG33647-USD      Moo Deng (moodeng.sbs) USD
# 12   PPEOPLE32079-USD                        MAGA USD
# 13     RRATS34039-USD             rats (Ethereum) USD
# 14     GGROK33471-USD                   SORA GROK USD
# 15        GGROOVE-USD                      GROOVE USD
# 16     CCOIN36756-USD              [Fake]COINBASE USD
# 17         BBSTER-USD                       Bster USD
# 18     BBASE38263-USD                     Base AI USD
# 19    TTRUMP36286-USD   PEPE TRUMP (pepetrump.cc) USD
# 20     GGOAT38260-USD                    Goatcoin USD
# 21     HHBTC38220-USD                    Hold BTC USD
# 22      FFUR36326-USD                 Furfication USD
# 23     IIBIT37350-USD                   BlackRock USD
# 24     PPEPE36287-USD        PEPE AI (pepeai.one) USD
#
#                                             Price              Change  \
# 0                         0.30+0.30(+634,591.60%)               +0.30
# 1                           0.00+0.00(+3,781.24%)               +0.00
# 2                           0.00+0.00(+2,802.50%)               +0.00
# 3                         24.44+22.22(+1,000.90%)              +22.22
# 4                             0.00+0.00(+668.76%)               +0.00
# 5                             0.03+0.02(+613.19%)               +0.02
# 6                             0.00+0.00(+552.13%)               +0.00
# 7                             0.00+0.00(+459.45%)               +0.00
# 8                             2.40+1.97(+459.35%)               +1.97
# 9                             0.00+0.00(+445.52%)               +0.00
# 10                            0.00+0.00(+444.16%)               +0.00
# 11                            0.00+0.00(+434.85%)               +0.00
# 12                            0.00+0.00(+416.35%)               +0.00
# 13  52,728,967,168.00+41,373,396,992.00(+364.34%)  +41,373,396,992.00
# 14                            2.52+1.97(+361.42%)               +1.97
# 15                            0.00+0.00(+354.16%)               +0.00
# 16                        137.12+105.80(+337.83%)             +105.80
# 17                            0.01+0.01(+315.42%)               +0.01
# 18                            0.00+0.00(+302.79%)               +0.00
# 19                            0.00+0.00(+294.04%)               +0.00
# 20                            0.00+0.00(+293.07%)               +0.00
# 21                            0.00+0.00(+285.93%)               +0.00
# 22                            0.00+0.00(+282.08%)               +0.00
# 23                            0.02+0.01(+270.35%)               +0.01
# 24                            0.00+0.00(+269.70%)               +0.00
#
#         % Change Market Cap  Volume  Volume in currency( 24 hr)  \
# 0   +634,591.60%          0   43,141                     43,141
# 1     +3,781.24%          0  139,443                    139,443
# 2     +2,802.50%          0  166,286                    166,286
# 3     +1,000.90%          0   72,036                     72,036
# 4       +668.76%          0  874,010                    874,010
# 5       +613.19%          0   19,346                     19,346
# 6       +552.13%          0  376,933                    376,933
# 7       +459.45%          0  347,905                    347,905
# 8       +459.35%          0  14.293M                    14.293M
# 9       +445.52%          0  248,815                    248,815
# 10      +444.16%          0  348,253                    348,253
# 11      +434.85%          0   72,144                     72,144
# 12      +416.35%          0  136,563                    136,563
# 13      +364.34%          0  167,488                    167,488
# 14      +361.42%          0  205,765                    205,765
# 15      +354.16%          0  121,925                    121,925
# 16      +337.83%          0  511,183                    511,183
# 17      +315.42%          0  199,086                    199,086
# 18      +302.79%          0  395,008                    395,008
# 19      +294.04%          0  372,196                    372,196
# 20      +293.07%          0  181,931                    181,931
# 21      +285.93%          0  719,260                    719,260
# 22      +282.08%          0  340,073                    340,073
# 23      +270.35%          0  185,142                    185,142
# 24      +269.70%          0  286,081                    286,081
#
#    Volume in all currencies(in 24 hr) Circulating Supply  \
# 0                              43,141                  0
# 1                             139,443                  0
# 2                             166,286                  0
# 3                              72,036                  0
# 4                             874,010                  0
# 5                              19,346                  0
# 6                             376,933                  0
# 7                             347,905                  0
# 8                             14.293M                  0
# 9                             248,815                  0
# 10                            348,253                  0
# 11                             72,144                  0
# 12                            136,563                  0
# 13                            167,488                  0
# 14                            205,765                  0
# 15                            121,925                  0
# 16                            511,183                  0
# 17                            199,086                  0
# 18                            395,008                  0
# 19                            372,196                  0
# 20                            181,931                  0
# 21                            719,260                  0
# 22                            340,073                  0
# 23                            185,142                  0
# 24                            286,081                  0
#
#             52 Weeks Change%
# 0                    -99.55%               0.000.03
# 1                    -75.00%               0.000.00
# 2                   +300.00%               0.000.00
# 3                    -95.85%           1.892,462.19
# 4                   +400.00%               0.000.00
# 5                 +4,669.73%              0.0014.20
# 6                    -99.95%               0.001.15
# 7                    -74.64%               0.000.37
# 8                     +4.83%               0.003.38
# 9                    -99.07%               0.000.00
# 10                   -50.00%               0.000.44
# 11                   -99.50%               0.000.00
# 12                   -98.95%               0.000.12
# 13  +764,561,168,793,600.00%  0.0013,960,887,300.00
# 14            +2,052,230.47%              0.0027.34
# 15                   -58.06%               0.000.00
# 16                  +312.59%             2.16423.75
# 17                  +152.47%               0.000.03
# 18                   -93.58%               0.000.00
# 19                        --               0.000.00
# 20                   -48.37%               0.000.00
# 21                        --               0.000.00
# 22                  +838.10%               0.000.00
# 23                   -35.23%               0.000.17
# 24                  +560.00%               0.000.00

# %%
df.to_csv("Top Gainer Crypto currency.csv")

# %%
df.shape
# Out:
# (25, 13)

# %%
df.describe()
# Out:
#               Symbol             Name                        Price Change  \
# count             25               25  25                       25     25
# unique            25               25   1                       25      8
# top     SSEAGULL-USD  SEAGULL SAM USD      0.30+0.30(+634,591.60%)  +0.00
# freq               1                1  25                        1     16
#
#             % Change Market Cap Volume  Volume in currency( 24 hr)  \
# count             25         25      25                         25
# unique            25          1      25                         25
# top     +634,591.60%          0  43,141                     43,141
# freq               1         25       1                          1
#
#        Volume in all currencies(in 24 hr) Circulating Supply 52 Weeks Change%  \
# count                                  25                 25               25
# unique                                 25                  1               24
# top                                43,141                  0               --
# freq                                    1                 25                2
#
#
# count         25
# unique        13
# top     0.000.00
# freq          12

# %%
df.sample(10)
# Out:
#              Symbol                           Name    \
# 17       BBSTER-USD                      Bster USD
# 24   PPEPE36287-USD       PEPE AI (pepeai.one) USD
# 1   DDOGEX38772-USD                      DOGEX USD
# 7   TTRUMP32865-USD                   TRUMP AI USD
# 19  TTRUMP36286-USD  PEPE TRUMP (pepetrump.cc) USD
# 22    FFUR36326-USD                Furfication USD
# 10    GGME32488-USD              GameStop Coin USD
# 2    CCATX31291-USD                       CATX USD
# 13   RRATS34039-USD            rats (Ethereum) USD
# 15      GGROOVE-USD                     GROOVE USD
#
#                                             Price              Change  \
# 17                            0.01+0.01(+315.42%)               +0.01
# 24                            0.00+0.00(+269.70%)               +0.00
# 1                           0.00+0.00(+3,781.24%)               +0.00
# 7                             0.00+0.00(+459.45%)               +0.00
# 19                            0.00+0.00(+294.04%)               +0.00
# 22                            0.00+0.00(+282.08%)               +0.00
# 10                            0.00+0.00(+444.16%)               +0.00
# 2                           0.00+0.00(+2,802.50%)               +0.00
# 13  52,728,967,168.00+41,373,396,992.00(+364.34%)  +41,373,396,992.00
# 15                            0.00+0.00(+354.16%)               +0.00
#
#       % Change Market Cap  Volume  Volume in currency( 24 hr)  \
# 17    +315.42%          0  199,086                    199,086
# 24    +269.70%          0  286,081                    286,081
# 1   +3,781.24%          0  139,443                    139,443
# 7     +459.45%          0  347,905                    347,905
# 19    +294.04%          0  372,196                    372,196
# 22    +282.08%          0  340,073                    340,073
# 10    +444.16%          0  348,253                    348,253
# 2   +2,802.50%          0  166,286                    166,286
# 13    +364.34%          0  167,488                    167,488
# 15    +354.16%          0  121,925                    121,925
#
#    Volume in all currencies(in 24 hr) Circulating Supply  \
# 17                            199,086                  0
# 24                            286,081                  0
# 1                             139,443                  0
# 7                             347,905                  0
# 19                            372,196                  0
# 22                            340,073                  0
# 10                            348,253                  0
# 2                             166,286                  0
# 13                            167,488                  0
# 15                            121,925                  0
#
#             52 Weeks Change%
# 17                  +152.47%               0.000.03
# 24                  +560.00%               0.000.00
# 1                    -75.00%               0.000.00
# 7                    -74.64%               0.000.37
# 19                        --               0.000.00
# 22                  +838.10%               0.000.00
# 10                   -50.00%               0.000.44
# 2                   +300.00%               0.000.00
# 13  +764,561,168,793,600.00%  0.0013,960,887,300.00
# 15                   -58.06%               0.000.00

# %%
df.head()
# Out:
#             Symbol                            Name                      Price  \
# 0     SSEAGULL-USD                 SEAGULL SAM USD    0.30+0.30(+634,591.60%)
# 1  DDOGEX38772-USD                       DOGEX USD      0.00+0.00(+3,781.24%)
# 2   CCATX31291-USD                        CATX USD      0.00+0.00(+2,802.50%)
# 3    VVMC37642-USD                 VMS Classic USD    24.44+22.22(+1,000.90%)
# 4   GGROK36159-USD  TRUMP GROK (trumpgrok.org) USD        0.00+0.00(+668.76%)
#
#    Change      % Change Market Cap  Volume  Volume in currency( 24 hr)  \
# 0   +0.30  +634,591.60%          0   43,141                     43,141
# 1   +0.00    +3,781.24%          0  139,443                    139,443
# 2   +0.00    +2,802.50%          0  166,286                    166,286
# 3  +22.22    +1,000.90%          0   72,036                     72,036
# 4   +0.00      +668.76%          0  874,010                    874,010
#
#   Volume in all currencies(in 24 hr) Circulating Supply 52 Weeks Change%  \
# 0                             43,141                  0          -99.55%
# 1                            139,443                  0          -75.00%
# 2                            166,286                  0         +300.00%
# 3                             72,036                  0          -95.85%
# 4                            874,010                  0         +400.00%
#
#
# 0      0.000.03
# 1      0.000.00
# 2      0.000.00
# 3  1.892,462.19
# 4      0.000.00

# %%
df.isnull().sum()
# Out:
# Symbol                                0
# Name                                  0
#                                       0
# Price                                 0
# Change                                0
# % Change                              0
# Market Cap                            0
# Volume                                0
# Volume in currency( 24 hr)            0
# Volume in all currencies(in 24 hr)    0
# Circulating Supply                    0
# 52 Weeks Change%                      0
#                                       0
# dtype: int64
