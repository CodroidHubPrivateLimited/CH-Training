# %%
import cv2
import numpy as np
import sys

# %%
print("You have successfully installed OpenCV version:", cv2.__version__)
print("Your version of Python is:"+ sys.version)
# Out:
# You have successfully installed OpenCV version: 4.12.0
# Your version of Python is:3.12.10 (tags/v3.12.10:0cc8128, Apr  8 2025, 12:21:36) [MSC v.1943 64 bit (AMD64)]

# %%
img = cv2.imread("image1.jpeg")
cv2.imshow("Image", img)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
print (img[:,:,2].shape)
# Out:
# (600, 800)

# %%
from matplotlib import pyplot as plt

img_1 = cv2.imread("image1.jpeg")
img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)
plt.imshow(img_1)
plt.title("image1")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(799.5), np.float64(599.5), np.float64(-0.5))

# %%
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Cannot open webcam")
else:
    while True:
        ret, frame = cap.read()
        if not ret:
            print("Failed to grab frame")
            break

        cv2.imshow("Webcam", frame)

        # Exit on 'q'
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

        # Exit if window is closed
        if cv2.getWindowProperty("Webcam", cv2.WND_PROP_VISIBLE) < 1:
            break

    cap.release()
    cv2.destroyAllWindows()

# %%
print(img.shape)
# Out:
# (600, 800, 3)

# %%
print(img[0,0])
# Out:
# [  1 255   0]

# %%
# want to know the colour at top left corner

print(img[0,799])
# Out:
# [254   0   0]

# %% [markdown]
# ### Image Processing

# %%
img_1 = cv2.imread("image1.jpeg")
grey = cv2.cvtColor(img_1, cv2.COLOR_BGR2GRAY)
cv2.imshow("Grey", grey)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img_1 = cv2.imread("image1.jpeg")

# Convert to grayscale
grey = cv2.cvtColor(img_1, cv2.COLOR_BGR2GRAY)

plt.imshow(grey, cmap='gray')
plt.title("Grey Image")
plt.axis("off")
plt.show()
