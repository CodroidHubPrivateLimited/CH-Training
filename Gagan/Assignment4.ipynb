# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
headers = {"User-Agent": "Mozilla/5.0"}

# %%
url = "https://finance.yahoo.com/markets/mutualfunds/top/?start=0&count=25"

# %%
response = requests.get(url, headers=headers)

# %%
soup = BeautifulSoup(response.text, "html.parser")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 soup = BeautifulSoup(response.text, "html.parser")
#
# NameError: name 'response' is not defined

# %%
table = soup.find("table")
if table is None:
   print("Table not found. The data may be loaded dynamically")
else:
   rows = table.find("tbody").find_all("tr")

# %%
data = []
for row in rows:
   cols = row.find_all("td")
   data.append([col.get_text(strip=True) for col in cols])

# %%
data

# %%
print(data[0])
print(len(data[0]))
columns = ["Symbol", "Name", "Price (Intraday)", "Change", "% Change", "Volume", "Market Cap", "PE Ratio (TTM)"]

# %%
df = pd.DataFrame(data, columns=columns)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df = pd.DataFrame(data, columns=columns)
#       2 df
#
# NameError: name 'data' is not defined

# %%
df.to_csv("Top 25 Mutual Funds.csv")

# %%
df.shape

# %%
df.describe()

# %%
df.sample(10)

# %%
df.head()

# %%
df.isnull().sum()
