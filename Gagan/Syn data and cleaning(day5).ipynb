# %% [markdown]
# ### Synthetic Data Creation

# %%
import pandas as pd #
import numpy as np  # Random() function used later

# %%
# Create a Simple, Clean Synthetic Dataset
data = {
    "Student_ID": [101, 102, 103, 104, 105],
    "Name": ["Alice", "Bob", "Charlie", "David", "Eva"],
    "Age": [20, 21, 19, 22, 20],
    "Marks": [85, 90, 78, 88, 92],
    "Department": ["AIML", "AIML", "AIML", "CSE", "CSE"]
}
df=pd.DataFrame(data)
df
# Out:
#    Student_ID     Name  Age  Marks Department
# 0         101    Alice   20     85       AIML
# 1         102      Bob   21     90       AIML
# 2         103  Charlie   19     78       AIML
# 3         104    David   22     88        CSE
# 4         105      Eva   20     92        CSE

# %%
# Create a Synthetic Dataset with Noise/Which is not clean
data = {
    "Student_ID": [101, 102, 103, 104, None,104],
    "Name": ["Alice", "Bob", None, "David", "Eva","Sanjay"],
    "Age": [20, None, 19, None, 20,"25"],
    "Marks": [85, 90, 78, None, 92,1009],
    "Department": ["AIML", "AIML", "AIML", None, "CSE", "CSE"]
}
df=pd.DataFrame(data)
df
# Out:
#    Student_ID    Name   Age   Marks Department
# 0       101.0   Alice    20    85.0       AIML
# 1       102.0     Bob  None    90.0       AIML
# 2       103.0    None    19    78.0       AIML
# 3       104.0   David  None     NaN       None
# 4         NaN     Eva    20    92.0        CSE
# 5       104.0  Sanjay    25  1009.0        CSE

# %%
np.random.seed(42)  # For reproducibility
n=10
np.random.randint(1, 101, size=n)  # Random integers between 1 and 100
# Out:
# array([52, 93, 15, 72, 61, 21, 83, 87, 75, 75])

# %%
np.random.seed(41)
n=1000
df=pd.DataFrame({
    "Student_ID": np.arange(101, 101+n),
    "Age": np.random.randint(18, 24,size=n),
    "Marks": np.random.randint(50, 100,size=n),
    "Department": np.random.choice(["AIML", "ECE", "ME", "CSE", "AR"], size=n)
})

# %%
df
# Out:
#      Student_ID  Age  Marks Department
# 0           101   18     66        CSE
# 1           102   21     75        CSE
# 2           103   22     56         ME
# 3           104   20     90         ME
# 4           105   18     82         ME
# ..          ...  ...    ...        ...
# 995        1096   21     88         AR
# 996        1097   21     80        ECE
# 997        1098   20     51        CSE
# 998        1099   21     53         AR
# 999        1100   23     90         AR
#
# [1000 rows x 4 columns]

# %%
df.head() #show first 5 rows
# Out:
#    Student_ID  Age  Marks Department
# 0         101   18     66        CSE
# 1         102   21     75        CSE
# 2         103   22     56         ME
# 3         104   20     90         ME
# 4         105   18     82         ME

# %%
# Introduce Missing Values in Age, Marks, Department
for col in["Age", "Marks", "Department"]:
    df.loc[df.sample(frac=0.05).index, col] = np.nan  # Introduce 5% missing values
df
# Out:
#      Student_ID   Age  Marks Department
# 0           101  18.0   66.0        CSE
# 1           102  21.0   75.0        CSE
# 2           103  22.0   56.0         ME
# 3           104  20.0   90.0         ME
# 4           105  18.0   82.0         ME
# ..          ...   ...    ...        ...
# 995        1096  21.0   88.0         AR
# 996        1097  21.0   80.0        ECE
# 997        1098   NaN   51.0        CSE
# 998        1099  21.0   53.0         AR
# 999        1100  23.0   90.0         AR
#
# [1000 rows x 4 columns]

# %%
#Introdece Duplicate records/Rows
pd.concat([df, df.sample(20)], ignore_index=True) # Duplicate 20 random rows

#Introduce invalid ages
df.loc[df.sample(10).index, "Age"] = np.random.choice([-5, 240], size=10)  
df
# Out:
#      Student_ID   Age  Marks Department
# 0           101  18.0   66.0        CSE
# 1           102  21.0   75.0        CSE
# 2           103  22.0   56.0         ME
# 3           104  20.0   90.0         ME
# 4           105  18.0   82.0         ME
# ..          ...   ...    ...        ...
# 995        1096  21.0   88.0         AR
# 996        1097  21.0   80.0        ECE
# 997        1098   NaN   51.0        CSE
# 998        1099  21.0   53.0         AR
# 999        1100  23.0   90.0         AR
#
# [1000 rows x 4 columns]

# %%
#Introduce Outliers
df.loc[df.sample(10).index, "Marks"] = np.random.choice([150, 300], size=10)
df
# Out:
#      Student_ID   Age  Marks Department
# 0           101  18.0   66.0        CSE
# 1           102  21.0   75.0        CSE
# 2           103  22.0   56.0         ME
# 3           104  20.0   90.0         ME
# 4           105  18.0   82.0         ME
# ..          ...   ...    ...        ...
# 995        1096  21.0   88.0         AR
# 996        1097  21.0   80.0        ECE
# 997        1098   NaN   51.0        CSE
# 998        1099  21.0   53.0         AR
# 999        1100  23.0   90.0         AR
#
# [1000 rows x 4 columns]

# %%
# Inconsistent Text Formatting
df["Department"] = df["Department"].astype(str)
df.loc[df.sample(frac=0.1).index, "Department"] = df["Department"].sample(10).str.lower()
df
df.head() #show first 5 rows
df.tail() #show last 5 rows
# Out:
#      Student_ID   Age  Marks Department
# 995        1096  21.0   88.0         AR
# 996        1097  21.0   80.0        ECE
# 997        1098   NaN   51.0        CSE
# 998        1099  21.0   53.0         AR
# 999        1100  23.0   90.0         AR

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Student_ID  1000 non-null   int32
#  1   Age         950 non-null    float64
#  2   Marks       950 non-null    float64
#  3   Department  900 non-null    object
# dtypes: float64(2), int32(1), object(1)
# memory usage: 27.5+ KB

# %%
#column wise null value
df.isnull().sum()
# Out:
# Student_ID      0
# Age            50
# Marks          50
# Department    100
# dtype: int64

# %%
df.shape
# Out:
# (1000, 4)

# %%
df.columns
# Out:
# Index(['Student_ID', 'Age', 'Marks', 'Department'], dtype='object')

# %%
df.columns
# Out:
# Index(['Student_ID', 'Age', 'Marks', 'Department'], dtype='object')

# %%
df.sample(10)
# Out:
#      Student_ID   Age  Marks Department
# 990        1091  21.0   86.0        ECE
# 288         389  23.0   64.0        CSE
# 100         201  19.0   55.0       AIML
# 244         345  19.0   87.0         ME
# 194         295  19.0   92.0        ECE
# 641         742  20.0   98.0         ME
# 904        1005  21.0   53.0        ECE
# 500         601  21.0   97.0        NaN
# 481         582   NaN   75.0       AIML
# 759         860   NaN   82.0        ECE

# %%
df.isnull().sum()
# Out:
# Student_ID      0
# Age            50
# Marks          50
# Department    100
# dtype: int64

# %%
df.isnull().mean()*100  # Percentage of missing values per column
# Out:
# Student_ID     0.0
# Age            5.0
# Marks          5.0
# Department    10.0
# dtype: float64

# %%
df[df.isnull().any(axis=1)]
# Out:
#      Student_ID   Age  Marks Department
# 13          114  21.0    NaN       AIML
# 14          115  21.0   59.0        NaN
# 15          116  20.0   67.0        NaN
# 16          117   NaN   78.0         AR
# 38          139  20.0   55.0        NaN
# ..          ...   ...    ...        ...
# 972        1073   NaN   74.0        CSE
# 974        1075  19.0   72.0        NaN
# 981        1082  20.0    NaN         AR
# 983        1084  23.0    NaN        ECE
# 997        1098   NaN   51.0        CSE
#
# [191 rows x 4 columns]

# %%
df[df.isnull().any(axis=1)].count()
# Out:
# Student_ID    191
# Age           141
# Marks         141
# Department     91
# dtype: int64

# %%
df.duplicated().sum()  # Count of duplicate rows
# Out:
# 0

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
df.duplicated().sum()  # Count of duplicate rows
# Out:
# 0

# %%
df[df.duplicated(keep=False)]  # Show all duplicate rows
# Out:
# Empty DataFrame
# Columns: [Student_ID, Age, Marks, Department]
# Index: []

# %%
df.duplicated(subset=["Student_ID"]).sum() # Duplicates based on specific columns
# Out:
# 0

# %%
df.describe()
# Out:
#         Student_ID         Age       Marks
# count  1000.000000  950.000000  950.000000
# mean    600.500000   20.986316   76.233684
# std     288.819436   12.639144   23.467533
# min     101.000000   -5.000000   50.000000
# 25%     350.750000   19.000000   62.000000
# 50%     600.500000   20.000000   75.000000
# 75%     850.250000   22.000000   87.000000
# max    1100.000000  240.000000  300.000000

# %%
pd.set_option('display.max_rows', None)  # Show all rows
pd.set_option('display.max_columns', None)  # Show all columns

# %%
df.head()
# Out:
#    Student_ID   Age  Marks Department
# 0         101  18.0   66.0        CSE
# 1         102  21.0   75.0        CSE
# 2         103  22.0   56.0         ME
# 3         104  20.0   90.0         ME
# 4         105  18.0   82.0         ME

# %%
pd.reset_option('display.max_rows')
pd.reset_option('display.max_columns')

# %%
df
# Out:
#      Student_ID   Age  Marks Department
# 0           101  18.0   66.0        CSE
# 1           102  21.0   75.0        CSE
# 2           103  22.0   56.0         ME
# 3           104  20.0   90.0         ME
# 4           105  18.0   82.0         ME
# ..          ...   ...    ...        ...
# 995        1096  21.0   88.0         AR
# 996        1097  21.0   80.0        ECE
# 997        1098   NaN   51.0        CSE
# 998        1099  21.0   53.0         AR
# 999        1100  23.0   90.0         AR
#
# [1000 rows x 4 columns]

# %%
# Display rows 500-600
df.iloc[500:600].to_string()
# Out:
# '     Student_ID   Age  Marks Department\n500         601  21.0   97.0        NaN\n501         602  19.0   57.0        CSE\n502         603  20.0   55.0        ECE\n503         604  20.0   76.0        NaN\n504         605  21.0   72.0         ME\n505         606  22.0   68.0        CSE\n506         607  21.0   90.0         AR\n507         608  18.0   72.0         ME\n508         609  22.0   76.0       AIML\n509         610  19.0   70.0         ME\n510         611  22.0   99.0        CSE\n511         612  21.0   50.0        NaN\n512         613  21.0   92.0        ECE\n513         614  21.0   94.0         AR\n514         615  23.0   63.0        NaN\n515         616  23.0   96.0       AIML\n516         617  20.0   66.0         AR\n517         618  19.0   69.0        ECE\n518         619  22.0   75.0         ME\n519         620  20.0   76.0        CSE\n520         621  20.0   88.0         ME\n521         622  18.0   81.0        nan\n522         623  21.0   65.0       AIML\n523         624  18.0   51.0        ECE\n524         625  23.0   77.0         AR\n525         626  18.0   60.0         ME\n526         627  22.0   97.0         AR\n527         628  20.0   62.0         ME\n528         629  18.0   91.0         ME\n529         630  20.0   64.0        ECE\n530         631  23.0   70.0         AR\n531         632  18.0   74.0       AIML\n532         633  18.0   54.0         ME\n533         634  19.0   77.0        NaN\n534         635  23.0   82.0         ME\n535         636  23.0   81.0        ECE\n536         637  23.0   98.0         ME\n537         638  23.0   92.0        CSE\n538         639  19.0   80.0       AIML\n539         640  19.0   81.0        NaN\n540         641  19.0   68.0         AR\n541         642  19.0   59.0       AIML\n542         643  19.0   76.0        ECE\n543         644  20.0   53.0         AR\n544         645  18.0   81.0         ME\n545         646  23.0   71.0         ME\n546         647  18.0   57.0        CSE\n547         648  21.0   54.0         AR\n548         649  21.0    NaN        ECE\n549         650  23.0   84.0         ME\n550         651  21.0   57.0        nan\n551         652  19.0   76.0        CSE\n552         653  21.0   56.0        ECE\n553         654  21.0   76.0        ECE\n554         655  19.0   71.0        CSE\n555         656  21.0   78.0        CSE\n556         657  20.0   65.0        ECE\n557         658  23.0   90.0        ECE\n558         659  19.0   79.0        NaN\n559         660  20.0    NaN        ECE\n560         661  18.0   82.0       AIML\n561         662  20.0   79.0        NaN\n562         663  22.0   92.0        CSE\n563         664  18.0   89.0        CSE\n564         665  23.0   59.0       AIML\n565         666  18.0   95.0        CSE\n566         667  23.0   99.0         ME\n567         668  22.0   64.0         AR\n568         669  23.0   80.0        NaN\n569         670   NaN   83.0        ECE\n570         671  18.0    NaN        CSE\n571         672  22.0   57.0        ECE\n572         673  18.0   51.0         AR\n573         674  21.0   88.0        CSE\n574         675  19.0   85.0        ECE\n575         676  22.0   70.0         ME\n576         677  18.0   51.0        ECE\n577         678  22.0   65.0        NaN\n578         679  23.0   97.0        NaN\n579         680  20.0   62.0         AR\n580         681  19.0   71.0         AR\n581         682  23.0   98.0       AIML\n582         683  18.0   73.0        CSE\n583         684  21.0   91.0        nan\n584         685  21.0   74.0       AIML\n585         686  21.0   99.0       AIML\n586         687  22.0   59.0         AR\n587         688  20.0   53.0        NaN\n588         689  18.0   86.0         AR\n589         690  21.0   58.0       AIML\n590         691  19.0   84.0        NaN\n591         692  22.0   58.0         AR\n592         693   NaN   89.0         AR\n593         694  22.0   98.0        NaN\n594         695  20.0   64.0         AR\n595         696  19.0   65.0        CSE\n596         697  23.0  ...

# %%
# convert dataframe into csv file
df.to_csv("synthetic_student_data.csv", index=False)

# %%
df
# Out:
#      Student_ID   Age  Marks Department
# 0           101  18.0   66.0        CSE
# 1           102  21.0   75.0        CSE
# 2           103  22.0   56.0         ME
# 3           104  20.0   90.0         ME
# 4           105  18.0   82.0         ME
# ..          ...   ...    ...        ...
# 995        1096  21.0   88.0         AR
# 996        1097  21.0   80.0        ECE
# 997        1098   NaN   51.0        CSE
# 998        1099  21.0   53.0         AR
# 999        1100  23.0   90.0         AR
#
# [1000 rows x 4 columns]

# %%
df.to_excel("synthetic_student_data.xlsx", index=False)

# %%
df
# Out:
#      Student_ID   Age  Marks Department
# 0           101  18.0   66.0        CSE
# 1           102  21.0   75.0        CSE
# 2           103  22.0   56.0         ME
# 3           104  20.0   90.0         ME
# 4           105  18.0   82.0         ME
# ..          ...   ...    ...        ...
# 995        1096  21.0   88.0         AR
# 996        1097  21.0   80.0        ECE
# 997        1098   NaN   51.0        CSE
# 998        1099  21.0   53.0         AR
# 999        1100  23.0   90.0         AR
#
# [1000 rows x 4 columns]
