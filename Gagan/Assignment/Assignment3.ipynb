# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
headers = {"User-Agent": "Mozilla/5.0"}

# %%
url = "https://finance.yahoo.com/markets/crypto/gainers/"

# %%
response = requests.get(url, headers=headers)

# %%
soup = BeautifulSoup(response.text, "html.parser")

# %%
table = soup.find("table")
if table is None:
    print("Table not found. The data may be loaded dynamically")
else:
    rows = table.find("tbody").find_all("tr")

# %%
data = []

# %%
for row in rows:
        cols = row.find_all("td")
        data.append([col.get_text(strip=True) for col in cols])

# %%
data
# Out:
# [['SSEAGULL-USD',
#   'SEAGULL SAM USD',
#   '',
#   '0.30+0.30(+634,591.60%)',
#   '+0.30',
#   '+634,591.60%',
#   '0',
#   '43,141',
#   '43,141',
#   '43,141',
#   '0',
#   '-99.55%',
#   '0.000.03'],
#  ['DDOGO29570-USD',
#   'DOGO USD',
#   '',
#   '0.00+0.00(+1,703.65%)',
#   '+0.00',
#   '+1,703.65%',
#   '0',
#   '194,618',
#   '194,618',
#   '194,618',
#   '0',
#   '+500.00%',
#   '0.000.00'],
#  ['GGMRT-USD',
#   'The Game Company USD',
#   '',
#   '0.01+0.01(+1,388.25%)',
#   '+0.01',
#   '+1,388.25%',
#   '3.591M',
#   '15,889',
#   '15,889',
#   '15,889',
#   '301.559M',
#   '-83.32%',
#   '0.000.05'],
#  ['FFELIS-USD',
#   'Felis USD',
#   '',
#   '0.00+0.00(+1,042.67%)',
#   '+0.00',
#   '+1,042.67%',
#   '0',
#   '152,511',
#   '152,511',
#   '152,511',
#   '0',
#   '-66.67%',
#   '0.000.00'],
#  ['RRFOX-USD',
#   'RFOX USD',
#   '',
#   '0.00+0.00(+854.76%)',
#   '+0.00',
#   '+854.76%',
#   '264,853',
#   '8.647M',
#   '8.647M',
#   '8.647M',
#   '1.312B',
#   '-77.88%',
#   '0.000.00'],
#  ['AAI16Z-USD',
#   'ai16z USD',
#   '',
#   '0.01+0.01(+666.33%)',
#   '+0.01',
#   '+666.33%',
#   '0',
#   '2.641M',
#   '2.641M',
#   '2.641M',
#   '0',
#   '-99.88%',
#   '0.002.48'],
#  ['PPEOPLE32079-USD',
#   'MAGA USD',
#   '',
#   '0.00+0.00(+554.69%)',
#   '+0.00',
#   '+554.69%',
#   '0',
#   '134,596',
#   '134,596',
#   '134,596',
#   '0',
#   '-96.41%',
#   '0.000.12'],
#  ['MMOODENG33647-USD',
#   'Moo Deng (moodeng.sbs) USD',
#   '',
#   '0.00+0.00(+499.43%)',
#   '+0.00',
#   '+499.43%',
#   '0',
#   '113,185',
#   '113,185',
#   '113,185',
#   '0',
#   '-99.50%',
#   '0.000.00'],
#  ['TTRUMP31874-USD',
#   'PEPE USD',
#   '',
#   '0.00+0.00(+486.27%)',
#   '+0.00',
#   '+486.27%',
#   '0',
#   '302,809',
#   '302,809',
#   '302,809',
#   '0',
#   '-97.48%',
#   '0.000.00'],
#  ['CCAT32486-USD',
#   'NOT USD',
#   '',
#   '0.04+0.03(+481.25%)',
#   '+0.03',
#   '+481.25%',
#   '0',
#   '276,787',
#   '276,787',
#   '276,787',
#   '0',
#   '+2,058.09%',
#   '0.000.90'],
#  ['TTRUMP32865-USD',
#   'TRUMP AI USD',
#   '',
#   '0.00+0.00(+477.53%)',
#   '+0.00',
#   '+477.53%',
#   '0',
#   '338,802',
#   '338,802',
#   '338,802',
#   '0',
#   '-27.10%',
#   '0.000.37'],
#  ['GGME32488-USD',
#   'GameStop Coin USD',
#   '',
#   '0.00+0.00(+477.01%)',
#   '+0.00',
#   '+477.01%',
#   '0',
#   '352,094',
#   '352,094',
#   '352,094',
#   '0',
#   '+38.46%',
#   '0.000.44'],
#  ['BBEER32150-USD',
#   'Beers USD',
#   '',
#   '0.01+0.01(+455.06%)',
#   '+0.01',
#   '+455.06%',
#   '0',
#   '325,314',
#   '325,314',
#   '325,314',
#   '0',
#   '+52,800.00%',
#   '0.001.15'],
#  ['PPENGU38135-USD',
#   'PENGU AI USD',
#   '',
#   '0.22+0.18(+448.73%)',
#   '+0.18',
#   '+448.73%',
#   '0',
#   '157,340',
#   '157,340',
#   '157,340',
#   '0',
#   '--',
#   '0.00303.86'],
#  ['MMAGA32751-USD',
#   'TRUMP MAGA (trumpmaga.me) USD',
#   '',
#   '0.01+0.01(+432.21%)',
#   '+0.01',
#   '+432.21%',
#   '0',
#   '227,384',
#   '227,384',
#   '227,384',
#   '0',
#   '+2,681.11%',
#   '0.004,243,702.50'],
#  ['DDOGS32713-USD',
#   'HARRIS DOGS USD',
#   '',
#   '0.01+0.01(+405.01%)',
#   '+0.01',
#   '+405.01%',
#   '0',
#   '320,816',
#   '320,816',
#   '320,816',
#   '0',
#   '+2,489.86%',
#   '0.000.12'],
#  ['TTURBO33724-USD',
#   'Turbo Trump USD',
#   '',
#   '0.02+0.01(+350.52%)',
#   '+0.01',
#   '+350.52%',
#   '0',
#   '130,520',
#   '130,520',
#   '130,520',
#   '0',
#   '+432,200.00%',
#   '0.007,500,205.50'],
#  ['DDG8833-USD',
#   'DeGate USD',
#   '',
#   '0.05+0.04(+328.26%)',
#   '+0.04',
#   '+328.26%',
#   '0',
#   '15,112',
#   '15,112',
#   '15,112',
#   '0',
#   '-91.15%',
#   '0.000.13'],
#  ['TTRUMP36286-USD',
#   'PEPE TRUMP (pepetrump.cc) USD',
#   '',
#   '0.00+0.00(+326.68%)',
#   '+0.00',
#   '+326.68%',
#   '0',
#   '319,422',
#   '319,422',
#   '319,422',
#   '0',
#   '--',
#   '0.000.00'],
#  ['TTST35796-USD',
#   '[Fake] Test (testtoken.me) USD',
#   '',
#   '0.00+0.00(+323.02%)',
#   '+0.00',
#   '+323.02%',
#   '0',
#   '68,305',
#   '68,305',
#   '68,305',
#   '0',
#   '-93.95%',
#   '0.000.00'],
#  ['BBASE38263-USD',
#   'Base AI USD',
#   '',
#   '0.00+0.00(+303.72%)',
#   '+0.00',
#   '+303.72%',
#   '0',
#   '321,118',
#   '321,118',
#   '321,118',
#   '0',
#   '-79.10%',
#   '0.000.00'],
#  ['CCHARLIE-USD',
#   'Charlie Kirk USD',
#   '',
#   '0.00+0.00(+300.18%)',
#   '+0.00',
#   '+300.18%',
#   '0',
#   '340,149',
#   '340,149',
#   '340,149',
#   '0',
#   '-19.29%',
#   '0.000.00'],
#  ['LLABUBU37563-USD',
#   'LABUBU (labubu.farm) USD',
#   '',
#   '0.01+0.00(+291.63%)',
#   '+0.00',
#   '+291.63%',
#   '0',
#   '160,919',
#   '160,919',
#   '160,919',
#   '0',
#   '+508.88%',
#   '0.000.03'],
#  ['GGROK36159-USD',
#   'TRUMP GROK (trumpgrok.org) USD',
#   '',
#   '0.00+0.00(+280.46%)',
#   '+0.00',
#   '+280.46%',
#   '0',
#   '592,943',
#   '592,943',
#   '592,943',
#   '0',
#   '+1,566.67%',
#   '0.000.00'],
#  ['FFISH2-USD',
#   'FISH2 USD',
#   '',
#   '0.00+0.00(+279.00%)',
#   '+0.00',
#   '+279.00%',
#   '0',
#   '316,836',
#   '316,836',
#   '316,836',
#   '0',
#   '+71.96%',
#   '0.000.02']]

# %%
print(data[0])
print(len(data[0]))
# Out:
# ['SSEAGULL-USD', 'SEAGULL SAM USD', '', '0.30+0.30(+634,591.60%)', '+0.30', '+634,591.60%', '0', '43,141', '43,141', '43,141', '0', '-99.55%', '0.000.03']
# 13

# %%
columns=[
   "Symbol",
   "Name",
   " ",
   "Price",
   "Change",
   "% Change",
   "Market Cap",
   "Volume ",
   "Volume in currency( 24 hr)",
   "Volume in all currencies(in 24 hr)",
   "Circulating Supply",
   "52 Weeks Change%",
   " "
]

# %%
df = pd.DataFrame(data, columns=columns)
df
# Out:
#                Symbol                            Name    \
# 0        SSEAGULL-USD                 SEAGULL SAM USD
# 1      DDOGO29570-USD                        DOGO USD
# 2           GGMRT-USD            The Game Company USD
# 3          FFELIS-USD                       Felis USD
# 4           RRFOX-USD                        RFOX USD
# 5          AAI16Z-USD                       ai16z USD
# 6    PPEOPLE32079-USD                        MAGA USD
# 7   MMOODENG33647-USD      Moo Deng (moodeng.sbs) USD
# 8     TTRUMP31874-USD                        PEPE USD
# 9       CCAT32486-USD                         NOT USD
# 10    TTRUMP32865-USD                    TRUMP AI USD
# 11      GGME32488-USD               GameStop Coin USD
# 12     BBEER32150-USD                       Beers USD
# 13    PPENGU38135-USD                    PENGU AI USD
# 14     MMAGA32751-USD   TRUMP MAGA (trumpmaga.me) USD
# 15     DDOGS32713-USD                 HARRIS DOGS USD
# 16    TTURBO33724-USD                 Turbo Trump USD
# 17        DDG8833-USD                      DeGate USD
# 18    TTRUMP36286-USD   PEPE TRUMP (pepetrump.cc) USD
# 19      TTST35796-USD  [Fake] Test (testtoken.me) USD
# 20     BBASE38263-USD                     Base AI USD
# 21       CCHARLIE-USD                Charlie Kirk USD
# 22   LLABUBU37563-USD        LABUBU (labubu.farm) USD
# 23     GGROK36159-USD  TRUMP GROK (trumpgrok.org) USD
# 24         FFISH2-USD                       FISH2 USD
#
#                       Price Change      % Change Market Cap  Volume   \
# 0   0.30+0.30(+634,591.60%)  +0.30  +634,591.60%          0   43,141
# 1     0.00+0.00(+1,703.65%)  +0.00    +1,703.65%          0  194,618
# 2     0.01+0.01(+1,388.25%)  +0.01    +1,388.25%     3.591M   15,889
# 3     0.00+0.00(+1,042.67%)  +0.00    +1,042.67%          0  152,511
# 4       0.00+0.00(+854.76%)  +0.00      +854.76%    264,853   8.647M
# 5       0.01+0.01(+666.33%)  +0.01      +666.33%          0   2.641M
# 6       0.00+0.00(+554.69%)  +0.00      +554.69%          0  134,596
# 7       0.00+0.00(+499.43%)  +0.00      +499.43%          0  113,185
# 8       0.00+0.00(+486.27%)  +0.00      +486.27%          0  302,809
# 9       0.04+0.03(+481.25%)  +0.03      +481.25%          0  276,787
# 10      0.00+0.00(+477.53%)  +0.00      +477.53%          0  338,802
# 11      0.00+0.00(+477.01%)  +0.00      +477.01%          0  352,094
# 12      0.01+0.01(+455.06%)  +0.01      +455.06%          0  325,314
# 13      0.22+0.18(+448.73%)  +0.18      +448.73%          0  157,340
# 14      0.01+0.01(+432.21%)  +0.01      +432.21%          0  227,384
# 15      0.01+0.01(+405.01%)  +0.01      +405.01%          0  320,816
# 16      0.02+0.01(+350.52%)  +0.01      +350.52%          0  130,520
# 17      0.05+0.04(+328.26%)  +0.04      +328.26%          0   15,112
# 18      0.00+0.00(+326.68%)  +0.00      +326.68%          0  319,422
# 19      0.00+0.00(+323.02%)  +0.00      +323.02%          0   68,305
# 20      0.00+0.00(+303.72%)  +0.00      +303.72%          0  321,118
# 21      0.00+0.00(+300.18%)  +0.00      +300.18%          0  340,149
# 22      0.01+0.00(+291.63%)  +0.00      +291.63%          0  160,919
# 23      0.00+0.00(+280.46%)  +0.00      +280.46%          0  592,943
# 24      0.00+0.00(+279.00%)  +0.00      +279.00%          0  316,836
#
#    Volume in currency( 24 hr) Volume in all currencies(in 24 hr)  \
# 0                      43,141                             43,141
# 1                     194,618                            194,618
# 2                      15,889                             15,889
# 3                     152,511                            152,511
# 4                      8.647M                             8.647M
# 5                      2.641M                             2.641M
# 6                     134,596                            134,596
# 7                     113,185                            113,185
# 8                     302,809                            302,809
# 9                     276,787                            276,787
# 10                    338,802                            338,802
# 11                    352,094                            352,094
# 12                    325,314                            325,314
# 13                    157,340                            157,340
# 14                    227,384                            227,384
# 15                    320,816                            320,816
# 16                    130,520                            130,520
# 17                     15,112                             15,112
# 18                    319,422                            319,422
# 19                     68,305                             68,305
# 20                    321,118                            321,118
# 21                    340,149                            340,149
# 22                    160,919                            160,919
# 23                    592,943                            592,943
# 24                    316,836                            316,836
#
#    Circulating Supply 52 Weeks Change%
# 0                   0          -99.55%          0.000.03
# 1                   0         +500.00%          0.000.00
# 2            301.559M          -83.32%          0.000.05
# 3                   0          -66.67%          0.000.00
# 4              1.312B          -77.88%          0.000.00
# 5                   0          -99.88%          0.002.48
# 6                   0          -96.41%          0.000.12
# 7                   0          -99.50%          0.000.00
# 8                   0          -97.48%          0.000.00
# 9                   0       +2,058.09%          0.000.90
# 10                  0          -27.10%          0.000.37
# 11                  0          +38.46%          0.000.44
# 12                  0      +52,800.00%          0.001.15
# 13                  0               --        0.00303.86
# 14                  0       +2,681.11%  0.004,243,702.50
# 15                  0       +2,489.86%          0.000.12
# 16                  0     +432,200.00%  0.007,500,205.50
# 17                  0          -91.15%          0.000.13
# 18                  0               --          0.000.00
# 19                  0          -93.95%          0.000.00
# 20                  0          -79.10%          0.000.00
# 21                  0          -19.29%          0.000.00
# 22                  0         +508.88%          0.000.03
# 23                  0       +1,566.67%          0.000.00
# 24                  0          +71.96%          0.000.02

# %%
df.to_csv("Top Gainer Crypto currency.csv")

# %%
df.shape
# Out:
# (25, 13)

# %%
df.describe()
# Out:
#               Symbol             Name                        Price Change  \
# count             25               25  25                       25     25
# unique            25               25   1                       25      6
# top     SSEAGULL-USD  SEAGULL SAM USD      0.30+0.30(+634,591.60%)  +0.00
# freq               1                1  25                        1     15
#
#             % Change Market Cap Volume  Volume in currency( 24 hr)  \
# count             25         25      25                         25
# unique            25          3      25                         25
# top     +634,591.60%          0  43,141                     43,141
# freq               1         23       1                          1
#
#        Volume in all currencies(in 24 hr) Circulating Supply 52 Weeks Change%  \
# count                                  25                 25               25
# unique                                 25                  3               24
# top                                43,141                  0               --
# freq                                    1                 23                2
#
#
# count         25
# unique        14
# top     0.000.00
# freq          10

# %%
df.sample(10)
# Out:
#              Symbol                            Name    \
# 11    GGME32488-USD               GameStop Coin USD
# 21     CCHARLIE-USD                Charlie Kirk USD
# 19    TTST35796-USD  [Fake] Test (testtoken.me) USD
# 3        FFELIS-USD                       Felis USD
# 4         RRFOX-USD                        RFOX USD
# 12   BBEER32150-USD                       Beers USD
# 13  PPENGU38135-USD                    PENGU AI USD
# 14   MMAGA32751-USD   TRUMP MAGA (trumpmaga.me) USD
# 0      SSEAGULL-USD                 SEAGULL SAM USD
# 10  TTRUMP32865-USD                    TRUMP AI USD
#
#                       Price Change      % Change Market Cap  Volume   \
# 11      0.00+0.00(+477.01%)  +0.00      +477.01%          0  352,094
# 21      0.00+0.00(+300.18%)  +0.00      +300.18%          0  340,149
# 19      0.00+0.00(+323.02%)  +0.00      +323.02%          0   68,305
# 3     0.00+0.00(+1,042.67%)  +0.00    +1,042.67%          0  152,511
# 4       0.00+0.00(+854.76%)  +0.00      +854.76%    264,853   8.647M
# 12      0.01+0.01(+455.06%)  +0.01      +455.06%          0  325,314
# 13      0.22+0.18(+448.73%)  +0.18      +448.73%          0  157,340
# 14      0.01+0.01(+432.21%)  +0.01      +432.21%          0  227,384
# 0   0.30+0.30(+634,591.60%)  +0.30  +634,591.60%          0   43,141
# 10      0.00+0.00(+477.53%)  +0.00      +477.53%          0  338,802
#
#    Volume in currency( 24 hr) Volume in all currencies(in 24 hr)  \
# 11                    352,094                            352,094
# 21                    340,149                            340,149
# 19                     68,305                             68,305
# 3                     152,511                            152,511
# 4                      8.647M                             8.647M
# 12                    325,314                            325,314
# 13                    157,340                            157,340
# 14                    227,384                            227,384
# 0                      43,141                             43,141
# 10                    338,802                            338,802
#
#    Circulating Supply 52 Weeks Change%
# 11                  0          +38.46%          0.000.44
# 21                  0          -19.29%          0.000.00
# 19                  0          -93.95%          0.000.00
# 3                   0          -66.67%          0.000.00
# 4              1.312B          -77.88%          0.000.00
# 12                  0      +52,800.00%          0.001.15
# 13                  0               --        0.00303.86
# 14                  0       +2,681.11%  0.004,243,702.50
# 0                   0          -99.55%          0.000.03
# 10                  0          -27.10%          0.000.37

# %%
df.head()
# Out:
#            Symbol                  Name                      Price Change  \
# 0    SSEAGULL-USD       SEAGULL SAM USD    0.30+0.30(+634,591.60%)  +0.30
# 1  DDOGO29570-USD              DOGO USD      0.00+0.00(+1,703.65%)  +0.00
# 2       GGMRT-USD  The Game Company USD      0.01+0.01(+1,388.25%)  +0.01
# 3      FFELIS-USD             Felis USD      0.00+0.00(+1,042.67%)  +0.00
# 4       RRFOX-USD              RFOX USD        0.00+0.00(+854.76%)  +0.00
#
#        % Change Market Cap  Volume  Volume in currency( 24 hr)  \
# 0  +634,591.60%          0   43,141                     43,141
# 1    +1,703.65%          0  194,618                    194,618
# 2    +1,388.25%     3.591M   15,889                     15,889
# 3    +1,042.67%          0  152,511                    152,511
# 4      +854.76%    264,853   8.647M                     8.647M
#
#   Volume in all currencies(in 24 hr) Circulating Supply 52 Weeks Change%  \
# 0                             43,141                  0          -99.55%
# 1                            194,618                  0         +500.00%
# 2                             15,889           301.559M          -83.32%
# 3                            152,511                  0          -66.67%
# 4                             8.647M             1.312B          -77.88%
#
#
# 0  0.000.03
# 1  0.000.00
# 2  0.000.05
# 3  0.000.00
# 4  0.000.00

# %%
df.isnull().sum()
# Out:
# Symbol                                0
# Name                                  0
#                                       0
# Price                                 0
# Change                                0
# % Change                              0
# Market Cap                            0
# Volume                                0
# Volume in currency( 24 hr)            0
# Volume in all currencies(in 24 hr)    0
# Circulating Supply                    0
# 52 Weeks Change%                      0
#                                       0
# dtype: int64
