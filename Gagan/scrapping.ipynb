# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
headers={
'user-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
}
url='https://www.flipkart.com/search?q=laptop&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off'
response=requests.get(url,headers=headers)
response
soup=BeautifulSoup(response.content,'html.parser')
soup
if soup.body:
    soup=soup.body
    for tag in soup(["scripy","style","head","nonscript","meta","link"]):
        tag.decompose() 
print(soup.prettify())
product=soup.find_all('div',class_='_jIjQ8S')
print(len(product))
product
Laptop=[]
for i in product:
    title=i.find("div", class_="RG5S1K")
    price=i.find("div", class_="hZ3P6w DeU9vF")
    Laptop.append({
        "Name" :title.get_text(strip=True) if title else None,
        "Price" :price.get_text(strip=True) if price else None,
     })

# %%
pip install beautifulsoup4
# Out:
# ...
#
# ...

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
headers={ 'user-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3' }
url='https://www.flipkart.com/search?q=laptop&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off'
response=requests.get(url,headers=headers)  
response
soup=BeautifulSoup(response.content,'html.parser')
soup
if soup.body:
    soup=soup.body
    for tag in soup(["scripy","style","head","nonscript","meta","link"]):
        tag.decompose() 
        print(soup.prettify())
        product=soup.find_all('div',class_="jIjQ8S")
        print(len(product))
        product
        Laptop=[]
        for i in product:
            title=i.find("div", class_="RG5Slk")
            price=i.find("div", class_="hZ3P6w DeU9vF")
            Laptop.append({
                "Name" :title.get_text(strip=True) if title else None,"Price" :price.get_text(strip=True) if price else None,
             })       
        print(Laptop)
df=pd.DataFrame(Laptop)
df
# Out:
# <body>
#  <div id="container">
#   <div>
#    <div class="CgvN2_">
#     <div class="nzadEb">
#      <div class="VQf4aO">
#      </div>
#      <div class="nS94SX">
#       <div class="Bfhncs">
#        <div class="gWHkja">
#         <a href="/">
#          <img alt="Flipkart" class="TVd0Ah" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/flipkart-plus_8d85f4.png" title="Flipkart" width="75"/>
#         </a>
#         <a class="p8iyLE" href="/plus">
#          Explore
#          <!-- -->
#          <span class="stfyUS">
#           Plus
#          </span>
#          <img src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/plus_aef861.png" width="10"/>
#         </a>
#        </div>
#       </div>
#       <div class="yZCQWU">
#        <form action="/search" class="rcHWnF header-form-search" method="GET">
#         <div class="col-12-12 kdPmDK">
#          <div class="DjsUBA">
# ...
