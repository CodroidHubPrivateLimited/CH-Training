# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
data = {
    "Patient_ID": [1, 2, 3, 4, 5],
    "first_name": ["John", "Jane", "Jim", "Jill", "Jack"],
    "last_name": ["Doe", "Smith", "Brown", "Davis", "Wilson"],  
    "gender": ["M", "F", "M", "F", "M"],
    "Age": [44, 33, 38, 32, 36],
    "Blood_group": ["A+", "B-", "O+", "AB+", "A-"],
    "Contact_number": ["123-456-7890", "234-567-8901", "345-678-9012", "456-789-0123", "567-890-1234"],
    "City": ["New York", "Los Angeles", "Chicago", "Houston", "Phoenix"],
    "State": ["NY", "CA", "IL", "TX", "AZ"],
    "address": ["123 Main St", "456 Oak St", "789 Pine St", "101 Maple St", "202 Birch St"],
    "country": ["USA", "USA", "USA", "USA", "USA"],
    "medical_history": ["Hypertension",  "Diabetes",  "Asthma", "Allergies","Cancer"]
    
    }

# %%
df=pd.DataFrame(data)
df
# Out:
#    Patient_ID first_name last_name gender date_of_birth  Age Blood_group  \
# 0           1       John       Doe      M    1980-01-01   44          A+
# 1           2       Jane     Smith      F    1990-02-02   33          B-
# 2           3        Jim     Brown      M    1985-03-03   38          O+
# 3           4       Jill     Davis      F    1992-04-04   32         AB+
# 4           5       Jack    Wilson      M    1988-05-05   36          A-
#
#   Contact_number         City State       address country medical_history  \
# 0   123-456-7890     New York    NY   123 Main St     USA    Hypertension
# 1   234-567-8901  Los Angeles    CA    456 Oak St     USA        Diabetes
# 2   345-678-9012      Chicago    IL   789 Pine St     USA          Asthma
# 3   456-789-0123      Houston    TX  101 Maple St     USA       Allergies
# 4   567-890-1234      Phoenix    AZ  202 Birch St     USA          Cancer
#
#   Registration_date
# 0        2020-01-15
# 1        2021-03-22
# ...

# %%
data = {
    "Patient_ID": [1, None, 3, 4, 5],
    "first_name": ["John", "Jane", None, "Jill", "Jack"],
    "last_name": ["Doe", "Smith", "Brown", "Davis", None],  
    "gender": [None, "F", "M", "F", "M"],
    "Age": [44, 33, 38, None, 36],
    "Blood_group": ["A+", None, "O+", "AB+", "A-"],
    "Contact_number": ["123-456-7890", "234-567-8901", "345-678-9012", None, "567-890-1234"],
    "City": [None, "Los Angeles", "Chicago", "Houston", "Phoenix"],
    "State": ["NY", "CA", "IL", "TX", None],
    "address": ["123 Main St", None, "789 Pine St", "101 Maple St", "202 Birch St"],
    "country": ["USA", "USA", "USA", "USA", None],
    "medical_history": ["Hypertension",  "Diabetes",  None, "Allergies","Cancer"],
    }
df=pd.DataFrame(data)
df
# Out:
#    Patient_ID first_name last_name gender   Age Blood_group Contact_number  \
# 0         1.0       John       Doe   None  44.0          A+   123-456-7890
# 1         NaN       Jane     Smith      F  33.0        None   234-567-8901
# 2         3.0       None     Brown      M  38.0          O+   345-678-9012
# 3         4.0       Jill     Davis      F   NaN         AB+           None
# 4         5.0       Jack      None      M  36.0          A-   567-890-1234
#
#           City State       address country medical_history
# 0         None    NY   123 Main St     USA    Hypertension
# 1  Los Angeles    CA          None     USA        Diabetes
# 2      Chicago    IL   789 Pine St     USA            None
# 3      Houston    TX  101 Maple St     USA       Allergies
# 4      Phoenix  None  202 Birch St    None          Cancer

# %%
np.random.seed(41)
n=5000
df=pd.DataFrame({
    "Patient_ID":np.random.randint(10,20,n),
    "first_name":np.random.choice(["John", "Jane", "Jim", "J    ill", "Jack"],n),
    "last_name":np.random.choice(["Doe", "Smith", "Brown", "Davis", "Wilson"],n),
    "gender":np.random.choice(["M", "F"],n),
    "Age":np.random.randint(18,80,size=n),
    "Blood_group":np.random.choice(["A+","A-","B+","B-","O+","O-","AB+","AB-"],n),
    "City":np.random.choice(["New York", "Los Angeles", "Chicago", "Houston", "Phoenix"],n),
    "State":np.random.choice(["NY", "CA", "IL", "TX", "AZ"],n),
    "address":np.random.choice(["123 Main St", "456 Oak St", "789 Pine St", "101 Maple St", "202 Birch St"],n),
    "country":np.random.choice(["USA", "Canada", "UK", "Australia", "India"],n),
    "medical_history":np.random.choice(["Hypertension",  "Diabetes",  "Asthma", "Allergies","Cancer"],n),
   
})

# %%
df
# Out:
#       Patient_ID first_name last_name gender  Age Blood_group         City  \
# 0             10       Jane    Wilson      F   43          B+      Houston
# 1             13       Jane     Davis      F   18          A-      Phoenix
# 2             12        Jim     Smith      M   26          O+  Los Angeles
# 3             10       John    Wilson      F   72          A+      Houston
# 4             11       Jack     Brown      F   48          O-      Phoenix
# ...          ...        ...       ...    ...  ...         ...          ...
# 3995          15       Jane    Wilson      M   62          O-  Los Angeles
# 3996          16        Jim     Davis      M   35          B-  Los Angeles
# 3997          12       John       Doe      M   29          O-     New York
# 3998          15       Jane     Smith      M   50          O+     New York
# 3999          19   J    ill    Wilson      F   66          A-  Los Angeles
#
# ...

# %%
df.head()
# Out:
#    Patient_ID first_name last_name gender date_of_birth  Age Blood_group  \
# 0           1       John     Brown      F    1972-03-23   18          A-
# 1           2   J    ill     Davis      M    1994-12-04   66          B-
# 2           3       Jack       Doe      F    1971-11-02   33          O+
# 3           4        Jim     Smith      M    1975-08-08   47          A-
# 4           5       John    Wilson      M    1976-01-21   27          B-
#
#           City State       address    country medical_history  \
# 0      Chicago    NY  101 Maple St  Australia       Allergies
# 1  Los Angeles    IL   789 Pine St  Australia          Asthma
# 2      Houston    TX   789 Pine St     Canada        Diabetes
# 3     New York    TX    456 Oak St  Australia          Cancer
# 4     New York    IL  101 Maple St      India          Asthma
#
#   Registration_date
# 0        2015-02-19
# 1        2021-03-11
# 2        2016-03-14
# 3        2019-10-13
# 4        2016-05-19

# %%
for col in["Patient_ID","first_name","last_name","gender","Age","Blood_group","Contact_number","City","State","address","country","medical_history"]:
    df.loc[df.sample(frac=0.05).index, col] = np.nan  # Introduce 5% missing values
df
# Out:
#       Patient_ID gender   Age Blood_group         City State       address  \
# 0           10.0      M  44.0          B+      Chicago    NY    456 Oak St
# 1           13.0      F  29.0          O-      Phoenix    TX   123 Main St
# 2           12.0    NaN  54.0         AB-      Phoenix    NY    456 Oak St
# 3           10.0      M  67.0          B-  Los Angeles    TX    456 Oak St
# 4           11.0      M  21.0         NaN      Phoenix    IL  202 Birch St
# ...          ...    ...   ...         ...          ...   ...           ...
# 4995        14.0      F  51.0          O-      Houston    CA  202 Birch St
# 4996        18.0      M  58.0          O+     New York    IL    456 Oak St
# 4997        19.0      M  57.0          A-      Chicago    NY   789 Pine St
# 4998        15.0      F  28.0          O+  Los Angeles    NY  202 Birch St
# 4999        10.0      F  37.0          A-      Phoenix    NY  202 Birch St
#
# ...

# %%
pd.concat([df, df.sample(20)], ignore_index=True) # Duplicate 20 random rows

#Introduce invalid ages
df.loc[df.sample(10).index, "Age"] = np.random.choice([-5, 240], size=10)  
df
# Out:
#       Patient_ID first_name last_name gender  Age Blood_group         City  \
# 0             10       Jane    Wilson      F   43          B+      Houston
# 1             13       Jane     Davis      F   18          A-      Phoenix
# 2             12        Jim     Smith      M   26          O+  Los Angeles
# 3             10       John    Wilson      F   72          A+      Houston
# 4             11       Jack     Brown      F   48          O-      Phoenix
# ...          ...        ...       ...    ...  ...         ...          ...
# 3995          15       Jane    Wilson      M   62          O-  Los Angeles
# 3996          16        Jim     Davis      M   35          B-  Los Angeles
# 3997          12       John       Doe      M   29          O-     New York
# 3998          15       Jane     Smith      M   50          O+     New York
# 3999          19   J    ill    Wilson      F   66          A-  Los Angeles
#
# ...

# %%
# Introduce Outliers
df.loc[df.sample(10).index, "Marks"] = np.random.choice([150, 300], size=10)
df
# Out:
#       Patient_ID first_name last_name gender date_of_birth   Age Blood_group  \
# 0            1.0       John     Brown      F    1972-03-23  18.0          A-
# 1            2.0   J    ill     Davis      M    1994-12-04  66.0          B-
# 2            NaN       Jack       Doe      F    1971-11-02  33.0          O+
# 3            4.0        Jim     Smith      M    1975-08-08  47.0          A-
# 4            5.0       John    Wilson      M    1976-01-21  27.0          B-
# ...          ...        ...       ...    ...           ...   ...         ...
# 3995      3996.0   J    ill     Davis      F    1960-07-16  35.0          B+
# 3996      3997.0       John     Smith      F    1972-08-13  63.0          O+
# 3997      3998.0   J    ill     Davis      M    1975-05-04  45.0          O-
# 3998      3999.0       Jane       Doe      F    1970-01-10  23.0          A-
# 3999      4000.0       Jack     Smith      M    2003-10-01  54.0         AB-
#
# ...

# %%
# Inconsistenr Text Formatting
df["medical_history"] = df["medical_history"].astype(str)
df.loc[df.sample(frac=0.1).index, "medical_history"] = df["medical_history"].sample(10).str.lower()
df
# Out:
#       Patient_ID first_name last_name gender date_of_birth   Age Blood_group  \
# 0            1.0       John     Brown      F    1972-03-23  18.0          A-
# 1            2.0   J    ill     Davis      M    1994-12-04  66.0          B-
# 2            NaN       Jack       Doe      F    1971-11-02  33.0          O+
# 3            4.0        Jim     Smith      M    1975-08-08  47.0          A-
# 4            5.0       John    Wilson      M    1976-01-21  27.0          B-
# ...          ...        ...       ...    ...           ...   ...         ...
# 3995      3996.0   J    ill     Davis      F    1960-07-16  35.0          B+
# 3996      3997.0       John     Smith      F    1972-08-13  63.0          O+
# 3997      3998.0   J    ill     Davis      M    1975-05-04  45.0          O-
# 3998      3999.0       Jane       Doe      F    1970-01-10  23.0          A-
# 3999      4000.0       Jack     Smith      M    2003-10-01  54.0         AB-
#
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of       Patient_ID first_name last_name gender date_of_birth   Age Blood_group  \
# 0            1.0       John     Brown      F    1972-03-23  18.0          A-
# 1            2.0   J    ill     Davis      M    1994-12-04  66.0          B-
# 2            NaN       Jack       Doe      F    1971-11-02  33.0          O+
# 3            4.0        Jim     Smith      M    1975-08-08  47.0          A-
# 4            5.0       John    Wilson      M    1976-01-21  27.0          B-
# ...          ...        ...       ...    ...           ...   ...         ...
# 3995      3996.0   J    ill     Davis      F    1960-07-16  35.0          B+
# 3996      3997.0       John     Smith      F    1972-08-13  63.0          O+
# 3997      3998.0   J    ill     Davis      M    1975-05-04  45.0          O-
# 3998      3999.0       Jane       Doe      F    1970-01-10  23.0          A-
# 3999      4000.0       Jack     Smith      M    2003-10-01  54.0         AB-
#
# ...

# %%
df.isnull().sum()
# Out:
# Patient_ID            200
# first_name            200
# last_name             200
# gender                200
# date_of_birth         200
# Age                   199
# Blood_group           200
# City                  200
# State                 200
# address               200
# country               200
# medical_history       399
# Registration_date     200
# Contact_number       4000
# Marks                3990
# dtype: int64

# %%
df.shape
# Out:
# (4000, 15)

# %%
df.columns
# Out:
# Index(['Patient_ID', 'first_name', 'last_name', 'gender', 'Age', 'Blood_group',
#        'City', 'State', 'address', 'country', 'medical_history'],
#       dtype='object')

# %%
df.sample(10)
# Out:
#       Patient_ID first_name last_name gender date_of_birth   Age Blood_group  \
# 2597      2598.0   J    ill     Davis      M    1975-01-07  70.0          B+
# 3730      3731.0       John     Davis      F    1982-10-09  62.0          B+
# 1822      1823.0       Jane     Smith      F    1977-07-05  43.0          O-
# 3599      3600.0       Jack     Smith      M    1989-03-16  47.0          B+
# 2278      2279.0       John     Davis    NaN    1961-03-17  51.0          A+
# 2264      2265.0       Jane       Doe      F    1988-10-25  27.0         AB+
# 3582      3583.0       Jane     Brown      F           NaT  19.0          B+
# 1187      1188.0       Jack     Smith      F           NaT  75.0          A+
# 306        307.0   J    ill       Doe    NaN    1959-11-22  39.0          B-
# 543        544.0        Jim    Wilson      M    1985-12-09  24.0          B+
#
#              City State       address    country medical_history  \
# ...

# %%
df.isnull().sum()
# Out:
# Patient_ID            200
# first_name            200
# last_name             200
# gender                200
# date_of_birth         200
# Age                   199
# Blood_group           200
# City                  200
# State                 200
# address               200
# country               200
# medical_history       399
# Registration_date     200
# Contact_number       4000
# Marks                3990
# dtype: int64

# %%
df.isnull().mean()*100
# Out:
# Patient_ID             5.000
# first_name             5.000
# last_name              5.000
# gender                 5.000
# date_of_birth          5.000
# Age                    4.975
# Blood_group            5.000
# City                   5.000
# State                  5.000
# address                5.000
# country                5.000
# medical_history        9.975
# Registration_date      5.000
# Contact_number       100.000
# Marks                 99.750
# dtype: float64

# %%
df[df.isnull().any(axis=1)]
# Out:
#       Patient_ID first_name last_name gender date_of_birth   Age Blood_group  \
# 0            1.0       John     Brown      F    1972-03-23  18.0          A-
# 1            2.0   J    ill     Davis      M    1994-12-04  66.0          B-
# 2            NaN       Jack       Doe      F    1971-11-02  33.0          O+
# 3            4.0        Jim     Smith      M    1975-08-08  47.0          A-
# 4            5.0       John    Wilson      M    1976-01-21  27.0          B-
# ...          ...        ...       ...    ...           ...   ...         ...
# 3995      3996.0   J    ill     Davis      F    1960-07-16  35.0          B+
# 3996      3997.0       John     Smith      F    1972-08-13  63.0          O+
# 3997      3998.0   J    ill     Davis      M    1975-05-04  45.0          O-
# 3998      3999.0       Jane       Doe      F    1970-01-10  23.0          A-
# 3999      4000.0       Jack     Smith      M    2003-10-01  54.0         AB-
#
# ...

# %%
df[df.isnull().any(axis=1)].count()
# Out:
# Patient_ID           3800
# first_name           3800
# last_name            3800
# gender               3800
# date_of_birth        3800
# Age                  3801
# Blood_group          3800
# City                 3800
# State                3800
# address              3800
# country              3800
# medical_history      3601
# Registration_date    3800
# Contact_number          0
# Marks                  10
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3995    False
# 3996    False
# 3997    False
# 3998    False
# 3999    False
# Length: 4000, dtype: bool

# %%
df.describe()
# Out:
#         Patient_ID                  date_of_birth          Age  \
# count  3800.000000                           3800  3801.000000
# mean   1996.071842  1977-06-12 19:54:03.789473664    48.899763
# min       1.000000            1950-01-05 00:00:00    -5.000000
# 25%     994.750000            1963-07-06 18:00:00    33.000000
# 50%    1993.500000            1977-08-12 00:00:00    49.000000
# 75%    2998.500000            1990-10-10 12:00:00    64.000000
# max    4000.000000            2004-12-30 00:00:00   240.000000
# std    1157.303702                            NaN    19.880437
#
#                    Registration_date  Contact_number       Marks
# count                           3800             0.0   10.000000
# mean   2019-01-12 01:49:08.210526208             NaN  285.000000
# min              2015-01-02 00:00:00             NaN  150.000000
# 25%              2017-02-09 18:00:00             NaN  300.000000
# 50%              2019-01-20 00:00:00             NaN  300.000000
# ...

# %%
pd.set_option('display.max_rows', None)  # Show all rows
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#    Patient_ID first_name last_name gender date_of_birth   Age Blood_group  \
# 0         1.0       John     Brown      F    1972-03-23  18.0          A-
# 1         2.0   J    ill     Davis      M    1994-12-04  66.0          B-
# 2         NaN       Jack       Doe      F    1971-11-02  33.0          O+
# 3         4.0        Jim     Smith      M    1975-08-08  47.0          A-
# 4         5.0       John    Wilson      M    1976-01-21  27.0          B-
#
#           City State       address    country medical_history  \
# 0      Chicago    NY  101 Maple St  Australia       Allergies
# 1  Los Angeles    IL   789 Pine St  Australia          Asthma
# 2          NaN    TX   789 Pine St        NaN        Diabetes
# 3     New York    TX    456 Oak St  Australia          Cancer
# 4     New York    IL  101 Maple St      India          Asthma
#
#   Registration_date  Contact_number  Marks
# 0        2015-02-19             NaN    NaN
# 1        2021-03-11             NaN    NaN
# ...

# %%
pd.reset_option('display.max_rows')
pd.reset_option('display.max_columns')

# %%
df
# Out:
#       Patient_ID first_name last_name gender date_of_birth   Age Blood_group  \
# 0            1.0       John     Brown      F    1972-03-23  18.0          A-
# 1            2.0   J    ill     Davis      M    1994-12-04  66.0          B-
# 2            NaN       Jack       Doe      F    1971-11-02  33.0          O+
# 3            4.0        Jim     Smith      M    1975-08-08  47.0          A-
# 4            5.0       John    Wilson      M    1976-01-21  27.0          B-
# ...          ...        ...       ...    ...           ...   ...         ...
# 3995      3996.0   J    ill     Davis      F    1960-07-16  35.0          B+
# 3996      3997.0       John     Smith      F    1972-08-13  63.0          O+
# 3997      3998.0   J    ill     Davis      M    1975-05-04  45.0          O-
# 3998      3999.0       Jane       Doe      F    1970-01-10  23.0          A-
# 3999      4000.0       Jack     Smith      M    2003-10-01  54.0         AB-
#
# ...

# %%
df.iloc[500:600].to_string()
# Out:
# '     Patient_ID first_name last_name gender date_of_birth   Age Blood_group         City State       address    country medical_history Registration_date  Contact_number  Marks\n500       501.0       John     Smith      M    1982-05-27  18.0         NaN     New York    AZ  101 Maple St        NaN          Asthma        2017-10-03             NaN    NaN\n501       502.0        Jim       NaN      M    2002-11-29  19.0         AB-     New York    TX  202 Birch St      India          Cancer        2018-01-03             NaN    NaN\n502       503.0        NaN     Davis      M           NaT  55.0          A+     New York    AZ  101 Maple St      India          Asthma        2020-09-09             NaN    NaN\n503       504.0       Jack     Smith      F    2002-02-13  47.0          O-      Phoenix    NY   789 Pine St  Australia        Diabetes               NaT             NaN    NaN\n504       505.0       Jane     Davis      M    1991-03-17  26.0         AB-      Houston    AZ    456 Oak S
# ...

# %%
df.to_csv("synthetic_student_data.csv", index=False)
df
# Out:
#       Patient_ID first_name last_name gender date_of_birth   Age Blood_group  \
# 0            1.0       John     Brown      F    1972-03-23  18.0          A-
# 1            2.0   J    ill     Davis      M    1994-12-04  66.0          B-
# 2            NaN       Jack       Doe      F    1971-11-02  33.0          O+
# 3            4.0        Jim     Smith      M    1975-08-08  47.0          A-
# 4            5.0       John    Wilson      M    1976-01-21  27.0          B-
# ...          ...        ...       ...    ...           ...   ...         ...
# 3995      3996.0   J    ill     Davis      F    1960-07-16  35.0          B+
# 3996      3997.0       John     Smith      F    1972-08-13  63.0          O+
# 3997      3998.0   J    ill     Davis      M    1975-05-04  45.0          O-
# 3998      3999.0       Jane       Doe      F    1970-01-10  23.0          A-
# 3999      4000.0       Jack     Smith      M    2003-10-01  54.0         AB-
#
# ...

# %%
df.to_excel("student_data.xlsx", index=False)
df
# Out:
#       Patient_ID first_name last_name gender  Age Blood_group         City  \
# 0             10   J    ill     Brown      M   62         AB+      Houston
# 1             13        Jim     Brown      F   46          B+      Houston
# 2             12       John     Smith      F   55         AB-      Houston
# 3             10   J    ill     Smith      M   56          O+      Houston
# 4             11       Jane     Brown      M   57         AB+      Chicago
# ...          ...        ...       ...    ...  ...         ...          ...
# 4995          14       John    Wilson      M   74         AB-      Chicago
# 4996          18        Jim     Brown      F   36          A-     New York
# 4997          19       John    Wilson      M   47          O-     New York
# 4998          15   J    ill     Brown      F   39          O+     New York
# 4999          10       Jane     Davis      M   24          B-  Los Angeles
#
#      State       address    country medical_history
# ...

# %%
class_counts = df['Age'].value_counts()
print(class_counts)
# Out:
# Age
# 73    97
# 37    95
# 26    94
# 45    94
# 63    92
#       ..
# 58    70
# 39    68
# 69    68
# 77    65
# 68    60
# Name: count, Length: 62, dtype: int64

# %%
plt.figure()
plt.scatter(df["Age"], df["Patient_ID"])
plt.xlabel("Age")
plt.ylabel("Patient_ID")
plt.title("Age vs Patient_ID")
# Out:
# Text(0.5, 1.0, 'Age vs Patient_ID')

# %%
df.columns
# Out:
# Index(['Patient_ID', 'first_name', 'last_name', 'gender', 'Age', 'Blood_group',
#        'City', 'State', 'address', 'country', 'medical_history'],
#       dtype='object')

# %%
df["Admitted"] = np.where(
    (df["Age"]<=26) & (df["Patient_ID"] >=0), "yes", "No"
)

# %%
df.head()
# Out:
#    Patient_ID first_name last_name gender  Age Blood_group     City State  \
# 0          10   J    ill     Brown      M   62         AB+  Houston    TX
# 1          13        Jim     Brown      F   46          B+  Houston    NY
# 2          12       John     Smith      F   55         AB-  Houston    CA
# 3          10   J    ill     Smith      M   56          O+  Houston    IL
# 4          11       Jane     Brown      M   57         AB+  Chicago    AZ
#
#         address    country medical_history Placed Admitted
# 0  101 Maple St     Canada          Cancer     No       No
# 1  101 Maple St  Australia          Cancer     No       No
# 2  202 Birch St         UK       Allergies     No       No
# 3   123 Main St         UK          Asthma     No       No
# 4   123 Main St         UK          Cancer     No       No

# %%
#Bootstrap Resampling[+200}
bootstrap=df.sample(n=200, replace=True, random_state=42)
df_aug=pd.concat([df,bootstrap], ignore_index=True)

# %%
df_aug
# Out:
#       Patient_ID first_name last_name gender  Age Blood_group         City  \
# 0             10   J    ill     Brown      M   62         AB+      Houston
# 1             13        Jim     Brown      F   46          B+      Houston
# 2             12       John     Smith      F   55         AB-      Houston
# 3             10   J    ill     Smith      M   56          O+      Houston
# 4             11       Jane     Brown      M   57         AB+      Chicago
# ...          ...        ...       ...    ...  ...         ...          ...
# 5195          17       Jack    Wilson      F   63          O-  Los Angeles
# 5196          17       John     Smith      F   22          O-      Chicago
# 5197          17       Jack     Smith      M   22         AB-  Los Angeles
# 5198          13   J    ill     Smith      F   38          B-  Los Angeles
# 5199          14       Jane    Wilson      F   28          A+  Los Angeles
#
#      State       address    country medical_history Placed Admitted
# ...

# %%
#Noise Injection
noise=df.sample(n=150, random_state=42).copy()
noise['Age+= np.random.normal(0, 0.1,150)
noise['Technical_skills'] += np.random.normal(-3, 4,150)
noise['Attendance'] += np.random.normal(0, 2,150)

#Logical Constraints
noise['CGPA'] = noise['CGPA'].clip(6.0,9.5)
noise['Technical_skills'] = noise['Technical_skills'].clip(55,100)
noise['Attendance'] = noise['Attendance'].clip(65,100)
df_aug=pd.concat([df_aug,noise], ignore_index=True)
df_aug
# Out:
#   Cell In[1], line 3
#     noise['Age+= np.random.normal(0, 0.1,150)
#           ^
# SyntaxError: unterminated string literal (detected at line 3)
