# %% [markdown]
# ### synthetic Data creation

# %%
import pandas as pd # for data manipulation
import numpy as np  # for numerical operations(random data generation)

# %%
# create a simple, clean synthetic dataset
data = {
    "Student_ID":[101,102,103,104,105],
    "Name": ['Amit', 'Sara', 'John', 'Anita', 'Raj'],
    "Age": [25, 30, 22, 28, 24],
    "Marks":[85, 90, 78, 88, 92],
    "Departrment": ['Physics', 'Chemistry', 'Mathematics', 'Biology', 'Computer Science'],
}
df = pd.DataFrame(data)
df
# Out:
#    Student_ID   Name  Age  Marks       Departrment
# 0         101   Amit   25     85           Physics
# 1         102   Sara   30     90         Chemistry
# 2         103   John   22     78       Mathematics
# 3         104  Anita   28     88           Biology
# 4         105    Raj   24     92  Computer Science

# %%
#create a synthetic data with noiser
import numpy as np
data = {
    "Student_ID":[101,102,103,104,None,104],
    "Name": ['Amit', 'Sara', None, 'Anita', 'Raj', 'Anita'],
    "Age": [25, None, 22, None, 24, '23'],
    "Marks":[85, None, 78, 88, 92, -9],
    "Departrment": ['Physics', 'Chemistry', 'Mathematics', None, 'Computer Science',42],
}
df = pd.DataFrame(data)
df
# Out:
#    Student_ID   Name   Age  Marks       Departrment
# 0       101.0   Amit    25   85.0           Physics
# 1       102.0   Sara  None    NaN         Chemistry
# 2       103.0   None    22   78.0       Mathematics
# 3       104.0  Anita  None   88.0              None
# 4         NaN    Raj    24   92.0  Computer Science
# 5       104.0  Anita    23   -9.0                42

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Student_ID   5 non-null      float64
#  1   Name         5 non-null      object
#  2   Age          4 non-null      object
#  3   Marks        5 non-null      float64
#  4   Departrment  5 non-null      object
# dtypes: float64(2), object(3)
# memory usage: 372.0+ bytes

# %%
np.random.seed(42)  # for reproducibility
n=10
print(np.random.randint(1,100,size=n))
# Out:
# [52 93 15 72 61 21 83 87 75 75]

# %%
#np.random.seed(42)  # for reproducibility
n=10
print(np.random.randint(1,100,size=n))
# Out:
# [88 24  3 22 53  2 88 30 38  2]

# %%
np.random.seed(41)
n=1000
df = pd.DataFrame({    
    "Student_ID":np.arange(101,101+n),
    "Age": np.random.randint(18,30,size=n),
    "Marks":np.random.randint(40,100,size=n),
    "Departrment": np.random.choice(['Physics', 'Chemistry', 'Mathematics', 'Biology', 'Computer Science'], size=n)
})
df
# Out:
#      Student_ID  Age  Marks       Departrment
# 0           101   18     81  Computer Science
# 1           102   21     56  Computer Science
# 2           103   20     99       Mathematics
# 3           104   18     59       Mathematics
# 4           105   19     67           Biology
# ..          ...  ...    ...               ...
# 995        1096   23     76           Physics
# 996        1097   24     42           Physics
# 997        1098   25     79         Chemistry
# 998        1099   26     52         Chemistry
# 999        1100   18     60         Chemistry
#
# [1000 rows x 4 columns]

# %%
df.head()
# Out:
#    Student_ID  Age  Marks       Departrment
# 0         101   18     81  Computer Science
# 1         102   21     56  Computer Science
# 2         103   20     99       Mathematics
# 3         104   18     59       Mathematics
# 4         105   19     67           Biology

# %%
#introduce missing values in age, Marks and Department columns
for col in ['Age', 'Marks', 'Departrment']:
    df.loc[df.sample(frac=0.1).index, col] = np. nan
df
# Out:
#      Student_ID   Age  Marks       Departrment
# 0           101  18.0   81.0  Computer Science
# 1           102  21.0   56.0  Computer Science
# 2           103  20.0   99.0       Mathematics
# 3           104   NaN   59.0       Mathematics
# 4           105  19.0   67.0           Biology
# ..          ...   ...    ...               ...
# 995        1096  23.0    NaN           Physics
# 996        1097  24.0   42.0           Physics
# 997        1098  25.0   79.0         Chemistry
# 998        1099  26.0   52.0         Chemistry
# 999        1100  18.0   60.0         Chemistry
#
# [1000 rows x 4 columns]

# %%
#Adding Duplicate rows 
df = pd.concat([df, df.sample(20)], ignore_index=True)

#Rename misspelled column to correct name if necessary
if 'Departrment' in df.columns and 'Department' not in df.columns:
	df = df.rename(columns={'Departrment': 'Department'})

#Introduce invalid age values
df.loc[df.sample(20).index, 'Age'] = np.random.choice([-5, 240], size=20)

#outliers in Marks
df.loc[df.sample(20).index, 'Marks'] = np.random.choice([-10, 150], size=20)

#Inconsistent text formatting
df['Department'] = df['Department'].astype(str)
df.loc[df.sample(20).index, 'Department'] = df['Department'].str.lower()

df
df.head()
df.tail()
# Out:
#       Student_ID   Age  Marks        Department
# 1015         915  29.0   94.0           Biology
# 1016         598  28.0   65.0         Chemistry
# 1017        1033  29.0   85.0  Computer Science
# 1018         252  18.0   70.0           Physics
# 1019         556  29.0   40.0           Biology

# %%
df.isnull().sum()
# Out:
# Student_ID      0
# Age           103
# Marks          99
# Department      0
# dtype: int64

# %%
df.shape
# Out:
# (1020, 4)

# %%
df.columns
# Out:
# Index(['Student_ID', 'Age', 'Marks', 'Department'], dtype='object')

# %%
df.sample(10)
# Out:
#       Student_ID   Age  Marks        Department
# 303          404  20.0   83.0               nan
# 1005         443  29.0   82.0           Physics
# 982         1083  23.0   61.0           Biology
# 448          549  20.0    NaN           Physics
# 336          437  29.0  150.0         Chemistry
# 17           118  24.0   65.0         Chemistry
# 657          758  25.0   64.0  Computer Science
# 821          922   NaN   58.0  Computer Science
# 901         1002  22.0   40.0           Physics
# 564          665  24.0   72.0           Biology

# %%
df.isnull().mean()*100
# Out:
# Student_ID     0.000000
# Age           10.098039
# Marks          9.705882
# Department     0.000000
# dtype: float64

# %%
df.isnull().any(axis=1)
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 1015    False
# 1016    False
# 1017    False
# 1018    False
# 1019    False
# Length: 1020, dtype: bool

# %%
df[df.isnull().any(axis=1)]
# Out:
#       Student_ID   Age  Marks        Department
# 3            104   NaN   59.0       Mathematics
# 6            107  27.0    NaN           Biology
# 10           111   NaN   99.0       Mathematics
# 13           114  20.0    NaN       Mathematics
# 21           122  29.0    NaN  Computer Science
# ...          ...   ...    ...               ...
# 991         1092   NaN    NaN           Biology
# 995         1096  23.0    NaN           Physics
# 1002         266   NaN   51.0       Mathematics
# 1010         460   NaN   78.0           Biology
# 1012         159   NaN    NaN           Physics
#
# [192 rows x 4 columns]

# %%
df[df.isnull().any(axis=1)].count()
# Out:
# Student_ID    192
# Age            89
# Marks          93
# Department    192
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1015     True
# 1016     True
# 1017     True
# 1018     True
# 1019     True
# Length: 1020, dtype: bool

# %%
df[df.duplicated(keep=False)]
# Out:
#       Student_ID   Age  Marks        Department
# 58           159   NaN    NaN           Physics
# 151          252  18.0   70.0           Physics
# 165          266   NaN   51.0       Mathematics
# 170          271  20.0   58.0       Mathematics
# 243          344  27.0   86.0  Computer Science
# 290          391  22.0   79.0       Mathematics
# 342          443  29.0   82.0           Physics
# 356          457  20.0   92.0       Mathematics
# 359          460   NaN   78.0           Biology
# 455          556  29.0   40.0           Biology
# 497          598  28.0   65.0         Chemistry
# 606          707  29.0   52.0       Mathematics
# 612          713  20.0   81.0           Physics
# 675          776  21.0   71.0           Physics
# 706          807  29.0   47.0           Biology
# 814          915  29.0   94.0           Biology
# 876          977  27.0   61.0  Computer Science
# 932         1033  29.0   85.0  Computer Science
# 951         1052  24.0   93.0           Physics
# 965         1066  27.0   70.0         Chemistry
# 1000         776  21.0   71.0           Physics
# 1001         977  27.0   61.0  Computer Science
# 1002         266   NaN   51.0       Mathematics
# 1003         457  20.0   92.0       Mathematics
# 1004        1066  27.0   70.0         Chemistry
# 1005         443  29.0   82.0           Physics
# 1006         707  29.0   52.0       Mathematics
# 1007         344  27.0   86.0  Computer Science
# 1008         271  20.0   58.0       Mathematics
# 1009        1052  24.0   93.0           Physics
# 1010         460   NaN   78.0           Biology
# 1011         807  29.0   47.0           Biology
# 1012         159   NaN    NaN           Physics
# 1013         391  22.0   79.0       Mathematics
# 1014         713  20.0   81.0           Physics
# 1015         915  29.0   94.0           Biology
# 1016         598  28.0   65.0         Chemistry
# 1017        1033  29.0   85.0  Computer Science
# 1018         252  18.0   70.0           Physics
# 1019         556  29.0   40.0           Biology

# %%
df.describe()
# Out:
#         Student_ID         Age       Marks
# count  1020.000000  917.000000  921.000000
# mean    600.728431   25.895311   70.377850
# std     288.804075   25.048293   20.764636
# min     101.000000   -5.000000  -10.000000
# 25%     350.750000   20.000000   55.000000
# 50%     599.500000   23.000000   70.000000
# 75%     850.250000   26.000000   85.000000
# max    1100.000000  240.000000  150.000000

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
pd.reset_option('display.max_rows')
pd.reset_option('display.max_columns')

# %%
df
# Out:
#       Student_ID   Age  Marks        Department
# 0            101  -5.0   81.0  Computer Science
# 1            102  21.0   56.0  Computer Science
# 2            103  20.0   99.0       Mathematics
# 3            104   NaN   59.0       Mathematics
# 4            105  19.0   67.0           Biology
# ...          ...   ...    ...               ...
# 1015         915  29.0   94.0           Biology
# 1016         598  28.0   65.0         Chemistry
# 1017        1033  29.0   85.0  Computer Science
# 1018         252  18.0   70.0           Physics
# 1019         556  29.0   40.0           Biology
#
# [1020 rows x 4 columns]

# %%
pd.set_option('display.max_rows', 8)
pd.set_option('display.max_columns', 2)
df
# Out:
#       Student_ID  ...        Department
# 0            101  ...  Computer Science
# 1            102  ...  Computer Science
# 2            103  ...       Mathematics
# 3            104  ...       Mathematics
# ...          ...  ...               ...
# 1016         598  ...         Chemistry
# 1017        1033  ...  Computer Science
# 1018         252  ...           Physics
# 1019         556  ...           Biology
#
# [1020 rows x 4 columns]

# %%
#display  rows 500-600
df.iloc[500:600].to_string()
# Out:
# '     Student_ID   Age  Marks        Department\n500         601  21.0   47.0           Biology\n501         602  21.0   50.0               nan\n502         603  28.0   93.0         Chemistry\n503         604   NaN   43.0           Biology\n504         605  22.0   74.0         Chemistry\n505         606  28.0   71.0         Chemistry\n506         607  25.0    NaN         Chemistry\n507         608  21.0   40.0           Physics\n508         609  20.0   52.0         Chemistry\n509         610  29.0   89.0           Physics\n510         611   NaN   89.0               nan\n511         612  20.0   40.0           physics\n512         613  25.0   96.0           Biology\n513         614  20.0   68.0  Computer Science\n514         615  24.0   66.0       Mathematics\n515         616  25.0   40.0           Physics\n516         617  21.0   72.0           Physics\n517         618  22.0   90.0  Computer Science\n518         619  29.0  150.0         Chemistry\n519         620  26.0    NaN  Computer Science\n520         621  22.0   90.0       Mathematics\n521         622  19.0   49.0           Physics\n522         623  -5.0   86.0  Computer Science\n523         624  21.0   66.0               nan\n524         625  29.0   73.0           Physics\n525         626  23.0    NaN           Biology\n526         627  23.0   77.0  Computer Science\n527         628  28.0   59.0  Computer Science\n528         629  27.0    NaN           Physics\n529         630  22.0   77.0  Computer Science\n530         631  24.0   71.0       Mathematics\n531         632  28.0  150.0         Chemistry\n532         633  28.0   97.0       Mathematics\n533         634  26.0   75.0           Biology\n534         635  29.0   60.0  Computer Science\n535         636   NaN   45.0               nan\n536         637  18.0   61.0         Chemistry\n537         638  24.0    NaN           Physics\n538         639   NaN   56.0       Mathematics\n539         640  28.0  150.0           Biology\n540         641  18.0   45.0           Biology\n541         642   NaN   90.0         Chemistry\n542         643  25.0   41.0           physics\n543         644  28.0   43.0           Physics\n544         645  18.0   91.0         Chemistry\n545         646  18.0    NaN       Mathematics\n546         647  27.0   54.0           Biology\n547         648   NaN   51.0               nan\n548         649  23.0   66.0           Physics\n549         650  19.0   60.0         Chemistry\n550         651   NaN   61.0  Computer Science\n551         652  19.0   69.0           Physics\n552         653  19.0   70.0  Computer Science\n553         654  27.0   61.0           Biology\n554         655  20.0   84.0       Mathematics\n555         656  18.0   93.0  Computer Science\n556         657  23.0   63.0           Physics\n557         658   NaN   72.0           Physics\n558         659  29.0   82.0           Biology\n559         660  21.0   61.0       Mathematics\n560         661  21.0   64.0           Physics\n561         662  27.0    NaN               nan\n562         663  29.0   65.0  Computer Science\n563         664  21.0   60.0         Chemistry\n564         665  24.0   72.0           Biology\n565         666  27.0   82.0  Computer Science\n566         667  29.0   74.0           Physics\n567         668  28.0   78.0           Physics\n568         669  19.0   66.0       Mathematics\n569         670  20.0   51.0           Physics\n570         671   NaN   64.0           Physics\n571         672   NaN   62.0           physics\n572         673  26.0   54.0         Chemistry\n573         674   NaN   71.0         Chemistry\n574         675  18.0   64.0           Biology\n575         676  23.0   42.0       Mathematics\n576         677  22.0   88.0       Mathematics\n577         678  29.0   66.0  Computer Science\n578         679  18.0   89.0       Mathematics\n579         680  22.0   90.0           Physics\n580         681  26.0   66.0           Physics\n581         682  21.0   98.0         Chemistry\n582         683 ...

# %%
#convert dataframe to csv
df.to_csv('synthetic_student_data.csv', index=False)

# %%
df.to_excel('synthetic_student_data.xlsx', index=False)
