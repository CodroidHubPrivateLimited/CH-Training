# %%
import re

# %%
import nltk

# %%
from spellchecker import SpellChecker

# %%
pip install pyspellchecker
# Out:
# Requirement already satisfied: pyspellchecker in c:\users\user\anaconda3\lib\site-packages (0.8.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\user\anaconda3\lib\site-packages (3.9.1)
# Requirement already satisfied: click in c:\users\user\anaconda3\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\user\anaconda3\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\user\anaconda3\lib\site-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in c:\users\user\anaconda3\lib\site-packages (from nltk) (4.66.5)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
from spellchecker import SpellChecker

# %%
from nltk.tokenize import word_tokenize

# %%
from nltk.corpus import stopwords

# %%
text = "OMG!! 😱 I cant believed u getting the job!!! thats gr8! 🎉 I'm so happi for u! 😊 btw, I still remembr when we last met, u were so nervous abt the interview..lol 😂. Hope u come soon so we can hang out! 😎 Don't forget to call me 2moro!! 📞"
text
# Out:
# "OMG!! 😱 I cant believed u getting the job!!! thats gr8! 🎉 I'm so happi for u! 😊 btw, I still remembr when we last met, u were so nervous abt the interview..lol 😂. Hope u come soon so we can hang out! 😎 Don't forget to call me 2moro!! 📞"

# %%
tokens = word_tokenize(text)
tokens
# Out:
# ['OMG',
#  '!',
#  '!',
#  '😱',
#  'I',
#  'cant',
#  'believed',
#  'u',
#  'getting',
#  'the',
#  'job',
#  '!',
#  '!',
#  '!',
#  'thats',
#  'gr8',
#  '!',
#  '🎉',
#  'I',
#  "'m",
#  'so',
#  'happi',
#  'for',
#  'u',
#  '!',
#  '😊',
#  'btw',
#  ',',
#  'I',
#  'still',
#  'remembr',
#  'when',
#  'we',
#  'last',
#  'met',
#  ',',
#  'u',
#  'were',
#  'so',
#  'nervous',
#  'abt',
#  'the',
#  'interview',
#  '..',
#  'lol',
#  '😂',
#  '.',
#  'Hope',
#  'u',
#  'come',
#  'soon',
#  'so',
#  'we',
#  'can',
#  'hang',
#  'out',
#  '!',
#  '😎',
#  'Do',
#  "n't",
#  'forget',
#  'to',
#  'call',
#  'me',
#  '2moro',
#  '!',
#  '!',
#  '📞']

# %%
nltk.download("punkt")
nltk.download("stopwords")
nltk.download("punkt_tab")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stop_words = set(stopwords.words("english"))
filtered_tokens = [word for word in tokens if word.lower() not in stop_words]
print(filtered_tokens)
# Out:
# ['OMG', '!', '!', '😱', 'cant', 'believed', 'u', 'getting', 'job', '!', '!', '!', 'thats', 'gr8', '!', '🎉', "'m", 'happi', 'u', '!', '😊', 'btw', ',', 'still', 'remembr', 'last', 'met', ',', 'u', 'nervous', 'abt', 'interview', '..', 'lol', '😂', '.', 'Hope', 'u', 'come', 'soon', 'hang', '!', '😎', "n't", 'forget', 'call', '2moro', '!', '!', '📞']

# %%
#remove a specific word
word_to_remove = "OMG"
filtered_tokens2 = [word for word in tokens if word.lower() != word_to_remove]
print(filtered_tokens)
# Out:
# ['OMG', '!', '!', '😱', 'cant', 'believed', 'u', 'getting', 'job', '!', '!', '!', 'thats', 'gr8', '!', '🎉', "'m", 'happi', 'u', '!', '😊', 'btw', ',', 'still', 'remembr', 'last', 'met', ',', 'u', 'nervous', 'abt', 'interview', '..', 'lol', '😂', '.', 'Hope', 'u', 'come', 'soon', 'hang', '!', '😎', "n't", 'forget', 'call', '2moro', '!', '!', '📞']

# %%
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()

#stem each word
stemmed_words = [stemmer.stem(word) for word in tokens]

print("Orignaltext:" , tokens)
print("Stemmed Text:", stemmed_words)
# Out:
# Orignaltext: ['OMG', '!', '!', '😱', 'I', 'cant', 'believed', 'u', 'getting', 'the', 'job', '!', '!', '!', 'thats', 'gr8', '!', '🎉', 'I', "'m", 'so', 'happi', 'for', 'u', '!', '😊', 'btw', ',', 'I', 'still', 'remembr', 'when', 'we', 'last', 'met', ',', 'u', 'were', 'so', 'nervous', 'abt', 'the', 'interview', '..', 'lol', '😂', '.', 'Hope', 'u', 'come', 'soon', 'so', 'we', 'can', 'hang', 'out', '!', '😎', 'Do', "n't", 'forget', 'to', 'call', 'me', '2moro', '!', '!', '📞']
# Stemmed Text: ['omg', '!', '!', '😱', 'i', 'cant', 'believ', 'u', 'get', 'the', 'job', '!', '!', '!', 'that', 'gr8', '!', '🎉', 'i', "'m", 'so', 'happi', 'for', 'u', '!', '😊', 'btw', ',', 'i', 'still', 'remembr', 'when', 'we', 'last', 'met', ',', 'u', 'were', 'so', 'nervou', 'abt', 'the', 'interview', '..', 'lol', '😂', '.', 'hope', 'u', 'come', 'soon', 'so', 'we', 'can', 'hang', 'out', '!', '😎', 'do', "n't", 'forget', 'to', 'call', 'me', '2moro', '!', '!', '📞']

# %%
def stemmedtext(text):
    tokens = word_tokenize(text)
    from nltk.stem import PorterStemmer
    stemmer = PorterStemmer()
    return [stemmer.stem(word) for word in tokens]
