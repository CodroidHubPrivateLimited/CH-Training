# %% [markdown]
# <div style="background_colo: #c8d5e4ff; padding: 10px; text_align: center; color: white; font_size: 32px; font_family: 'ariel'       ">
# </div>

# %% [markdown]
# <div style="background_color: #f0f0f0;">
#     </div>
