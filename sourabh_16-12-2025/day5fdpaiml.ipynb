# %%
import pandas as pd 
#create a simple,clean syntehtic dataset
data={

    "student_id": [101,102,103,104],
    "name":["sourabh","anjali","abhishek","deepanshu"],
    "age":[40,35,26,23],
    "marks":[90,85,80,75],
    "department":["AIML","AR","CSE","ME"]


}

df=pd.DataFrame(data)
df
# Out:
#    student_id       name  age  marks department
# 0         101    sourabh   40     90       AIML
# 1         102     anjali   35     85         AR
# 2         103   abhishek   26     80        CSE
# 3         104  deepanshu   23     75         ME

# %%
#create a simple,unclean syntehtic dataset
data={

    "student_id": [101,102,103,104,None],
    "name":["sourabh","anjali",None,"abhishek","deepanshu"],
    "age":[40,None,35,26,23],
    "marks":[90,85,None,80,75],
    "department":["AIML","AR","CSE",None,"ME"]


}

df=pd.DataFrame(data)
df
# Out:
#    student_id       name   age  marks department
# 0       101.0    sourabh  40.0   90.0       AIML
# 1       102.0     anjali   NaN   85.0         AR
# 2       103.0       None  35.0    NaN        CSE
# 3       104.0   abhishek  26.0   80.0       None
# 4         NaN  deepanshu  23.0   75.0         ME

# %%
import pandas as pd
import numpy as np
np.random.seed(41)
n=1000

df=pd.DataFrame ({

    "student_id": np.arange(101,101+n),
    
    "age":np.random.randint(18,24,size=n),
    "marks":np.random.randint(40,100,size=n),
    "department":np.random.choice(["AIML","AR","CSE","ME","automation"],size=n)


})

df=pd.DataFrame(df)
df
# Out:
#      student_id  age  marks department
# 0           101   18     92       AIML
# 1           102   21     56        CSE
# 2           103   22     65        CSE
# 3           104   20     46       AIML
# 4           105   18     80       AIML
# ..          ...  ...    ...        ...
# 995        1096   21     48       AIML
# 996        1097   21     76        CSE
# 997        1098   20     42       AIML
# 998        1099   21     62         AR
# 999        1100   23     54         ME
#
# [1000 rows x 4 columns]

# %%
df=df.copy()

# %%
df.columns=(

df.columns.str.strip()   #removing spacing free columns
.str.lower()             #converting column headings into lower case
.str.replace("","")           #removing spacing by ,

    
)
df.columns
# Out:
# Index(['student_id', 'age', 'marks', 'department'], dtype='object')

# %%
#enforcing correct data type
df["age"]=pd.to_numeric(df["age"],errors="coerce")

# %%
df.columns
# Out:
# Index(['student_id', 'age', 'marks', 'department'], dtype='object')

# %%
df
# Out:
#      student_id  age  marks department
# 0           101   18     92       AIML
# 1           102   21     56        CSE
# 2           103   22     65        CSE
# 3           104   20     46       AIML
# 4           105   18     80       AIML
# ..          ...  ...    ...        ...
# 995        1096   21     48       AIML
# 996        1097   21     76        CSE
# 997        1098   20     42       AIML
# 998        1099   21     62         AR
# 999        1100   23     54         ME
#
# [1000 rows x 4 columns]

# %%
from numpy.random.mtrand import sample
# Introduce Missing values in Age, Marks and Department
for col in ["Age","Marks","department"]:
    df.loc[df.sample(frac=0.05).index,col]=np.nan

# %%
#duplicate records/rows
pd.concat([df,df.sample(20)],ignore_index=True)

#introduce invalid ages
df.loc[df.sample(10).index,"Age"]=np.random.choice([-5,240],size=10)

# %%
#introduce outliners
df.loc[df.sample(10).index,"Marks"]=np.random.choice([150,240],size=10)

# %%
#handling missing values
df["age"].fillna(df["age"].median(),inplace=True)
df
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16500\2075376069.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["age"].fillna(df["age"].median(),inplace=True)
#      student_id  age  marks department  Age  Marks
# 0           101   18     92       AIML  NaN    NaN
# 1           102   21     56        CSE  NaN    NaN
# 2           103   22     65        CSE  NaN    NaN
# 3           104   20     46       AIML  NaN    NaN
# 4           105   18     80       AIML  NaN    NaN
# ...

# %%
#handling duplicates
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#      student_id  age  marks department  Age  Marks
# 0           101   18     92       AIML  NaN    NaN
# 1           102   21     56        CSE  NaN    NaN
# 2           103   22     65        CSE  NaN    NaN
# 3           104   20     46       AIML  NaN    NaN
# 4           105   18     80       AIML  NaN    NaN
# ..          ...  ...    ...        ...  ...    ...
# 995        1096   21     48       AIML  NaN    NaN
# 996        1097   21     76        CSE  NaN    NaN
# 997        1098   20     42       AIML  NaN    NaN
# 998        1099   21     62         AR  NaN    NaN
# 999        1100   23     54         ME  NaN    NaN
#
# [1000 rows x 6 columns]

# %%
import pandas as pd
import numpy as np
np.random.seed(41)
n=1000

df=pd.DataFrame ({

    "student_id": np.arange(101,101+n),
    
    "age":np.random.randint(18,24,size=n),
    "marks":np.random.randint(40,100,size=n),
    "department":np.random.choice(["AIML","AR","CSE","ME","automation"],size=n)


})

df=pd.DataFrame(df)
df
# Out:
#      student_id  age  marks department
# 0           101   18     92       AIML
# 1           102   21     56        CSE
# 2           103   22     65        CSE
# 3           104   20     46       AIML
# 4           105   18     80       AIML
# ..          ...  ...    ...        ...
# 995        1096   21     48       AIML
# 996        1097   21     76        CSE
# 997        1098   20     42       AIML
# 998        1099   21     62         AR
# 999        1100   23     54         ME
#
# [1000 rows x 4 columns]

# %%
valid_department=["CSE","AIML","AR","ECE"]
df=df(df["department"].isin(valid_department))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 2
#       1 valid_department=["CSE","AIML","AR","ECE"]
# ----> 2 df=df(df["department"].isin(valid_department))
#
# TypeError: 'DataFrame' object is not callable

# %%
valid_department=["CSE","AIML","AR","ECE"]

# %%
df=df["department"].isin(valid_department)

# %%
df
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 995     True
# 996     True
# 997     True
# 998     True
# 999    False
# Name: department, Length: 1000, dtype: bool

# %%
df.describe
# Out:
# <bound method NDFrame.describe of 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 995     True
# 996     True
# 997     True
# 998     True
# 999    False
# Name: department, Length: 1000, dtype: bool>

# %%
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)
df
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
# 5       True
# 6       True
# 7       True
# 8       True
# 9      False
# 10     False
# 11      True
# 12      True
# 13      True
# 14      True
# 15      True
# 16      True
# 17      True
# 18      True
# 19      True
# 20     False
# 21      True
# 22     False
# 23      True
# 24      True
# 25     False
# 26     False
# 27      True
# 28     False
# 29     False
# 30      True
# 31     False
# 32     False
# 33      True
# 34      True
# 35     False
# 36      True
# 37     False
# 38     False
# 39      True
# 40      True
# 41      True
# 42      True
# 43     False
# 44     False
# 45      True
# 46     False
# 47      True
# 48     False
# 49     False
# 50      True
# 51      True
# 52      True
# 53     False
# 54      True
# 55     False
# 56      True
# 57      True
# 58      True
# 59     False
# 60      True
# 61     False
# 62     False
# 63     False
# 64      True
# 65      True
# ...

# %%
df = pd.DataFrame(data)

df = df[df["age"].between(18, 24)]
df
# Out:
#    student_id       name   age  marks department
# 4         NaN  deepanshu  23.0   75.0         ME

# %%
df = pd.DataFrame(data)

df = df[df["marks"].between(0, 100)]
df
# Out:
#    student_id       name   age  marks department
# 0       101.0    sourabh  40.0   90.0       AIML
# 1       102.0     anjali   NaN   85.0         AR
# 3       104.0   abhishek  26.0   80.0       None
# 4         NaN  deepanshu  23.0   75.0         ME

# %% [markdown]
# ###DATA AUGMENTATION

# %%
import pandas as pd
np.random.seed(41)
n=500

df=pd.DataFrame({

    "age": np.random.randint(20,26,n),
    "CGPA": np.round(np.random.uniform(6.0,9.5,n),2),
    "interenship_count": np.random.randint(0,4,n),
    "Technical_score": np.random.randint(50,100,n),
    "attendance_percentage": np.random.randint(60,100,n)
    


})

df=pd.DataFrame(df)
df
# Out:
#      age  CGPA  interenship_count  Technical_score  attendance_percentage
# 0     20  6.82                  2               72                     62
# 1     23  7.93                  2               75                     87
# 2     24  6.87                  1               98                     79
# 3     22  6.31                  0               75                     67
# 4     20  8.08                  2               76                     89
# 5     21  8.36                  1               88                     80
# 6     23  9.35                  2               55                     75
# 7     21  7.27                  2               83                     90
# 8     25  8.08                  1               83                     84
# 9     22  8.75                  2               92                     95
# 10    25  7.71                  3               87                     71
# 11    24  7.81                  3               86                     98
# ...

# %%
#target variable(imbalanced)

df["Placed"]=np.where(

    (df["CGPA"]>7.5)& (df["Technical_score"]>70),"Yes","No"
)

# %%
df
# Out:
#      age  CGPA  interenship_count  Technical_score  attendance_percentage  \
# 0     20  6.82                  2               72                     62
# 1     23  7.93                  2               75                     87
# 2     24  6.87                  1               98                     79
# 3     22  6.31                  0               75                     67
# 4     20  8.08                  2               76                     89
# 5     21  8.36                  1               88                     80
# 6     23  9.35                  2               55                     75
# 7     21  7.27                  2               83                     90
# 8     25  8.08                  1               83                     84
# 9     22  8.75                  2               92                     95
# 10    25  7.71                  3               87                     71
# 11    24  7.81                  3               86                     98
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   age                    500 non-null    int32
#  1   CGPA                   500 non-null    float64
#  2   interenship_count      500 non-null    int32
#  3   Technical_score        500 non-null    int32
#  4   attendance_percentage  500 non-null    int32
#  5   Placed                 500 non-null    object
# dtypes: float64(1), int32(4), object(1)
# memory usage: 15.8+ KB

# %%
df.shape
# Out:
# (500, 6)

# %%
bootstrap= df.sample(n=200, replace=True,random_state=41)
df_aug= pd.concat([df,bootstrap],ignore_index=True)
df_aug
# Out:
#      age  CGPA  interenship_count  Technical_score  attendance_percentage  \
# 0     20  6.82                  2               72                     62
# 1     23  7.93                  2               75                     87
# 2     24  6.87                  1               98                     79
# 3     22  6.31                  0               75                     67
# 4     20  8.08                  2               76                     89
# 5     21  8.36                  1               88                     80
# 6     23  9.35                  2               55                     75
# 7     21  7.27                  2               83                     90
# 8     25  8.08                  1               83                     84
# 9     22  8.75                  2               92                     95
# 10    25  7.71                  3               87                     71
# 11    24  7.81                  3               86                     98
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      age  CGPA  interenship_count  Technical_score  attendance_percentage  \
# 0     20  6.82                  2               72                     62
# 1     23  7.93                  2               75                     87
# 2     24  6.87                  1               98                     79
# 3     22  6.31                  0               75                     67
# 4     20  8.08                  2               76                     89
# 5     21  8.36                  1               88                     80
# 6     23  9.35                  2               55                     75
# 7     21  7.27                  2               83                     90
# 8     25  8.08                  1               83                     84
# 9     22  8.75                  2               92                     95
# 10    25  7.71                  3               87                     71
# ...

# %%
df_aug
# Out:
#      age  CGPA  interenship_count  Technical_score  attendance_percentage  \
# 0     20  6.82                  2               72                     62
# 1     23  7.93                  2               75                     87
# 2     24  6.87                  1               98                     79
# 3     22  6.31                  0               75                     67
# 4     20  8.08                  2               76                     89
# 5     21  8.36                  1               88                     80
# 6     23  9.35                  2               55                     75
# 7     21  7.27                  2               83                     90
# 8     25  8.08                  1               83                     84
# 9     22  8.75                  2               92                     95
# 10    25  7.71                  3               87                     71
# 11    24  7.81                  3               86                     98
# ...

# %%
df_aug.describe
# Out:
# <bound method NDFrame.describe of      age  CGPA  interenship_count  Technical_score  attendance_percentage  \
# 0     20  6.82                  2               72                     62
# 1     23  7.93                  2               75                     87
# 2     24  6.87                  1               98                     79
# 3     22  6.31                  0               75                     67
# 4     20  8.08                  2               76                     89
# 5     21  8.36                  1               88                     80
# 6     23  9.35                  2               55                     75
# 7     21  7.27                  2               83                     90
# 8     25  8.08                  1               83                     84
# 9     22  8.75                  2               92                     95
# 10    25  7.71                  3               87                     71
# ...

# %%
#adding noise entries
noise=df_aug.sample(n=150,random_state=41).copy()

noise["CGPA"]+=np.random.normal(0,0.1,150)
noise["Technical_score"]+=np.random.randint(-3,4,150)
noise["attendance_percentage"]+=np.random.normal(0,2,150)

# %%
#logical constraints

noise["CGPA"]=noise["CGPA"].clip(6.0,9.5)
noise["Technical_score"]=noise["Technical_score"].clip(50,100)
noise["attendance_percentage"]=noise["attendance_percentage"].clip(60,100)

df_aug=pd.concat([df_aug,noise],ignore_index=True)
df_aug
# Out:
#      age      CGPA  interenship_count  Technical_score  attendance_percentage  \
# 0     20  6.820000                  2               72              62.000000
# 1     23  7.930000                  2               75              87.000000
# 2     24  6.870000                  1               98              79.000000
# 3     22  6.310000                  0               75              67.000000
# 4     20  8.080000                  2               76              89.000000
# 5     21  8.360000                  1               88              80.000000
# 6     23  9.350000                  2               55              75.000000
# 7     21  7.270000                  2               83              90.000000
# 8     25  8.080000                  1               83              84.000000
# 9     22  8.750000                  2               92              95.000000
# 10    25  7.710000                  3               87              71.000000
# ...

# %%
#smote method
from imblearn.over_sampling import SMOTE


x
# Out:
#      age      CGPA  interenship_count  Technical_score  attendance_percentage
# 0     20  6.820000                  2               72              62.000000
# 1     23  7.930000                  2               75              87.000000
# 2     24  6.870000                  1               98              79.000000
# 3     22  6.310000                  0               75              67.000000
# 4     20  8.080000                  2               76              89.000000
# 5     21  8.360000                  1               88              80.000000
# 6     23  9.350000                  2               55              75.000000
# 7     21  7.270000                  2               83              90.000000
# 8     25  8.080000                  1               83              84.000000
# 9     22  8.750000                  2               92              95.000000
# 10    25  7.710000                  3               87              71.000000
# ...

# %%
x=df_aug.drop("Placed",axis=1)

# %%
x
# Out:
#      age      CGPA  interenship_count  Technical_score  attendance_percentage
# 0     20  6.820000                  2               72              62.000000
# 1     23  7.930000                  2               75              87.000000
# 2     24  6.870000                  1               98              79.000000
# 3     22  6.310000                  0               75              67.000000
# 4     20  8.080000                  2               76              89.000000
# 5     21  8.360000                  1               88              80.000000
# 6     23  9.350000                  2               55              75.000000
# 7     21  7.270000                  2               83              90.000000
# 8     25  8.080000                  1               83              84.000000
# 9     22  8.750000                  2               92              95.000000
# 10    25  7.710000                  3               87              71.000000
# ...

# %%
x=df_aug.drop("Placed",axis=1)
y=df_aug[("Placed")]

# %%
y
# Out:
# 0       No
# 1      Yes
# 2       No
# 3       No
# 4      Yes
# 5      Yes
# 6       No
# 7       No
# 8      Yes
# 9      Yes
# 10     Yes
# 11     Yes
# 12      No
# 13     Yes
# 14      No
# 15      No
# 16     Yes
# 17      No
# 18     Yes
# 19      No
# 20      No
# 21     Yes
# 22     Yes
# 23      No
# 24      No
# 25      No
# 26     Yes
# 27     Yes
# 28     Yes
# 29      No
# 30      No
# 31     Yes
# 32     Yes
# 33     Yes
# 34      No
# 35      No
# 36     Yes
# 37      No
# 38      No
# 39     Yes
# 40      No
# 41     Yes
# 42      No
# 43      No
# 44      No
# 45      No
# 46      No
# 47     Yes
# 48     Yes
# 49     Yes
# 50      No
# 51     Yes
# 52     Yes
# 53     Yes
# 54      No
# 55      No
# 56      No
# 57      No
# 58     Yes
# 59      No
# 60      No
# 61      No
# 62      No
# 63      No
# 64      No
# 65      No
# 66      No
# 67     Yes
# 68      No
# 69     Yes
# 70     Yes
# 71      No
# 72     Yes
# 73      No
# 74     Yes
# 75      No
# ...
