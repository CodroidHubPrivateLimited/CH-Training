# %%
#install the required libraries
# !pip install pyspellchecker
# Out:
# ...
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install nltk
# Out:
# ...
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import re  #regular expression it is used for removing special characters, pattern matching, text cleaning
from spellchecker import SpellChecker # pyright: ignore[reportMissingImports]
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
text = "OMG!! 😱 I cant believed u getting the job!!! thats gr8! 🎉 I'm so happi for u! 😊 btw, I still remembr when we last met, u were so nervous abt the interview..lol 😂. Hope u come soon so we can hang out! 😎 Don't forget to call me 2moro!! 📞"

# %%
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
nltk.download('punkt_tab')
tokens = word_tokenize(text)
print(tokens)
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# ['OMG', '!', '!', '😱', 'I', 'cant', 'believed', 'u', 'getting', 'the', 'job', '!', '!', '!', 'thats', 'gr8', '!', '🎉', 'I', "'m", 'so', 'happi', 'for', 'u', '!', '😊', 'btw', ',', 'I', 'still', 'remembr', 'when', 'we', 'last', 'met', ',', 'u', 'were', 'so', 'nervous', 'abt', 'the', 'interview', '..', 'lol', '😂', '.', 'Hope', 'u', 'come', 'soon', 'so', 'we', 'can', 'hang', 'out', '!', '😎', 'Do', "n't", 'forget', 'to', 'call', 'me', '2moro', '!', '!', '📞']

# %%
print(tokens)
# Out:
# ['OMG', '!', '!', '😱', 'I', 'cant', 'believed', 'u', 'getting', 'the', 'job', '!', '!', '!', 'thats', 'gr8', '!', '🎉', 'I', "'m", 'so', 'happi', 'for', 'u', '!', '😊', 'btw', ',', 'I', 'still', 'remembr', 'when', 'we', 'last', 'met', ',', 'u', 'were', 'so', 'nervous', 'abt', 'the', 'interview', '..', 'lol', '😂', '.', 'Hope', 'u', 'come', 'soon', 'so', 'we', 'can', 'hang', 'out', '!', '😎', 'Do', "n't", 'forget', 'to', 'call', 'me', '2moro', '!', '!', '📞']

# %%
from nltk.corpus import stopwords

# %%
stop_words = set(stopwords.words('english'))
filtered_tokens = [word for word in tokens if word.lower() not in stop_words]
print(filtered_tokens)
# Out:
# ['OMG', '!', '!', '😱', 'cant', 'believed', 'u', 'getting', 'job', '!', '!', '!', 'thats', 'gr8', '!', '🎉', "'m", 'happi', 'u', '!', '😊', 'btw', ',', 'still', 'remembr', 'last', 'met', ',', 'u', 'nervous', 'abt', 'interview', '..', 'lol', '😂', '.', 'Hope', 'u', 'come', 'soon', 'hang', '!', '😎', "n't", 'forget', 'call', '2moro', '!', '!', '📞']

# %%
word_to_remove='OMG'
filtered_tokens = [word for word in filtered_tokens if word != word_to_remove]
print(filtered_tokens)
# Out:
# ['!', '!', '😱', 'cant', 'believed', 'u', 'getting', 'job', '!', '!', '!', 'thats', 'gr8', '!', '🎉', "'m", 'happi', 'u', '!', '😊', 'btw', ',', 'still', 'remembr', 'last', 'met', ',', 'u', 'nervous', 'abt', 'interview', '..', 'lol', '😂', '.', 'Hope', 'u', 'come', 'soon', 'hang', '!', '😎', "n't", 'forget', 'call', '2moro', '!', '!', '📞']

# %%
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()
stemmed_words =[stemmer.stem(word) for word in tokens]
text2= "The childern were running quickly, they will be playing untill evening."

def stemmedtext(text):
	toks = word_tokenize(text)
	return [stemmer.stem(w) for w in toks]

stemmedwords = stemmedtext(text2)
print(stemmedwords)
# Out:
# ['the', 'childern', 'were', 'run', 'quickli', ',', 'they', 'will', 'be', 'play', 'until', 'even', '.']
