# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
headers = {
"User-Agent": "Mozilla/5.0"
}

# %%
url = "https://finance.yahoo.com/markets/mutualfunds/top/?start=0&count=25"

# %%
response = requests.get(url, headers=headers)

# %%
soup = BeautifulSoup(response.text, "html.parser")

# %%
table = soup.find("table")
if table is None:
  print("Table not found. The data may be loaded dynamically")
else:
  rows = table.find("tbody").find_all("tr")

# %%
data = []

# %%
for row in rows:
  cols = row.find_all("td")
  data.append([col.get_text(strip=True) for col in cols])
  data
  print (data[0])
# Out:
# ['GNXIX', 'AlphaCentric Robotics and Automation I', '18.07+0.78(+4.51%)', '+0.78', '+4.51%', '19.30', '16.41', '-7.18%', '+17.67%', '+18.34%', '11.1822.08']
# ['GNXIX', 'AlphaCentric Robotics and Automation I', '18.07+0.78(+4.51%)', '+0.78', '+4.51%', '19.30', '16.41', '-7.18%', '+17.67%', '+18.34%', '11.1822.08']
# ['GNXIX', 'AlphaCentric Robotics and Automation I', '18.07+0.78(+4.51%)', '+0.78', '+4.51%', '19.30', '16.41', '-7.18%', '+17.67%', '+18.34%', '11.1822.08']
# ['GNXIX', 'AlphaCentric Robotics and Automation I', '18.07+0.78(+4.51%)', '+0.78', '+4.51%', '19.30', '16.41', '-7.18%', '+17.67%', '+18.34%', '11.1822.08']
# ['GNXIX', 'AlphaCentric Robotics and Automation I', '18.07+0.78(+4.51%)', '+0.78', '+4.51%', '19.30', '16.41', '-7.18%', '+17.67%', '+18.34%', '11.1822.08']
# ['GNXIX', 'AlphaCentric Robotics and Automation I', '18.07+0.78(+4.51%)', '+0.78', '+4.51%', '19.30', '16.41', '-7.18%', '+17.67%', '+18.34%', '11.1822.08']
# ['GNXIX', 'AlphaCentric Robotics and Automation I', '18.07+0.78(+4.51%)', '+0.78', '+4.51%', '19.30', '16.41', '-7.18%', '+17.67%', '+18.34%', '11.1822.08']
# ['GNXIX', 'AlphaCentric Robotics and Automation I', '18.07+0.78(+4.51%)', '+0.78', '+4.51%', '19.30', '16.41', '-7.18%', '+17.67%', '+18.34%', '11.1822.08']
# ['GNXIX', 'AlphaCentric Robotics and Automation I', '18.07+0.78(+4.51%)', '+0.78', '+4.51%', '19.30', '16.41', '-7.18%', '+17.67%', '+18.34%', '11.1822.08']
# ['GNXIX', 'AlphaCentric Robotics and Automation I', '18.07+0.78(+4.51%)', '+0.78', '+4.51%', '19.30', '16.41', '-7.18%', '+17.67%', '+18.34%', '11.1822.08']
# ['GNXIX', 'AlphaCentric Robotics and Automation I', '18.07+0.78(+4.51%)', '+0.78', '+4.51%', '19.30', '16.41', '-7.18%', '+17.67%', '+18.34%', '11.1822.08']
# ['GNXIX', 'AlphaCentric Robotics and Automation I', '18.07+0.78(+4.51%)', '+0.78', '+4.51%', '19.30', '16.41', '-7.18%', '+17.67%', '+18.34%', '11.1822.08']
# ['GNXIX', 'AlphaCentric Robotics and Automation I', '18.07+0.78(+4.51%)', '+0.78', '+4.51%', '19.30', '16.41', '-7.18%', '+17.67%', '+18.34%', '11.1822.08']
# ['GNXIX', 'AlphaCentric Robotics and Automation I', '18.07+0.78(+4.51%)', '+0.78', '+4.51%', '19.30', '16.41', '-7.18%', '+17.67%', '+18.34%', '11.1822.08']
# ['GNXIX', 'AlphaCentric Robotics and Automation I', '18.07+0.78(+4.51%)', '+0.78', '+4.51%', '19.30', '16.41', '-7.18%', '+17.67%', '+18.34%', '11.1822.08']
# ['GNXIX', 'AlphaCentric Robotics and Automation I', '18.07+0.78(+4.51%)', '+0.78', '+4.51%', '19.30', '16.41', '-7.18%', '+17.67%', '+18.34%', '11.1822.08']
# ['GNXIX', 'AlphaCentric Robotics and Automation I', '18.07+0.78(+4.51%)', '+0.78', '+4.51%', '19.30', '16.41', '-7.18%', '+17.67%', '+18.34%', '11.1822.08']
# ['GNXIX', 'AlphaCentric Robotics and Automation I', '18.07+0.78(+4.51%)', '+0.78', '+4.51%', '19.30', '16.41', '-7.18%', '+17.67%', '+18.34%', '11.1822.08']
# ['GNXIX', 'AlphaCentric Robotics and Automation I', '18.07+0.78(+4.51%)', '+0.78', '+4.51%', '19.30', '16.41', '-7.18%', '+17.67%', '+18.34%', '11.1822.08']
# ['GNXIX', 'AlphaCentric Robotics and Automation I', '18.07+0.78(+4.51%)', '+0.78', '+4.51%', '19.30', '16.41', '-7.18%', '+17.67%', '+18.34%', '11.1822.08']
# ['GNXIX', 'AlphaCentric Robotics and Automation I', '18.07+0.78(+4.51%)', '+0.78', '+4.51%', '19.30', '16.41', '-7.18%', '+17.67%', '+18.34%', '11.1822.08']
# ['GNXIX', 'AlphaCentric Robotics and Automation I', '18.07+0.78(+4.51%)', '+0.78', '+4.51%', '19.30', '16.41', '-7.18%', '+17.67%', '+18.34%', '11.1822.08']
# ['GNXIX', 'AlphaCentric Robotics and Automation I', '18.07+0.78(+4.51%)', '+0.78', '+4.51%', '19.30', '16.41', '-7.18%', '+17.67%', '+18.34%', '11.1822.08']
# ['GNXIX', 'AlphaCentric Robotics and Automation I', '18.07+0.78(+4.51%)', '+0.78', '+4.51%', '19.30', '16.41', '-7.18%', '+17.67%', '+18.34%', '11.1822.08']
# ['GNXIX', 'AlphaCentric Robotics and Automation I', '18.07+0.78(+4.51%)', '+0.78', '+4.51%', '19.30', '16.41', '-7.18%', '+17.67%', '+18.34%', '11.1822.08']

# %%
print(len(data[0]))
# Out:
# 11

# %%
columns = [
"Symbol",
"Name",
"Last Price",
"Change",
"% Change",
"50 Days Average",
"200 Days Average ",
"3 Months Average",
"YTD return",
"52 Weeks Change%",
""
]
df=pd.DataFrame(data, columns=columns)
df
# Out:
#    Symbol                                     Name          Last Price Change  \
# 0   GNXIX   AlphaCentric Robotics and Automation I  18.07+0.78(+4.51%)  +0.78
# 1   GNXCX   AlphaCentric Robotics and Automation C  16.46+0.71(+4.51%)  +0.71
# 2   GNXAX   AlphaCentric Robotics and Automation A  17.64+0.76(+4.50%)  +0.76
# 3   BIPIX  ProFunds Biotechnology UltraSector Fund  68.51+2.78(+4.23%)  +2.78
# 4   BIPSX  ProFunds Biotechnology UltraSector Fund  35.40+1.43(+4.21%)  +1.43
# ..    ...                                      ...                 ...    ...
# 70  LFMGX           Lord Abbett Micro Cap Growth F  24.68+0.65(+2.70%)  +0.65
# 71  LMIYX           Lord Abbett Micro Cap Growth I  24.68+0.65(+2.70%)  +0.65
# 72  DVSMX       Driehaus Small Cap Growth Investor  27.11+0.71(+2.69%)  +0.71
# 73  ZVGIX          Zevenbergen Genea Institutional  59.82+1.55(+2.66%)  +1.55
# 74  ZVGNX               Zevenbergen Genea Investor  58.14+1.50(+2.65%)  +1.50
#
#    % Change 50 Days Average 200 Days Average  3 Months Average YTD return  \
# 0    +4.51%           19.30             16.41           -7.18%    +17.67%
# 1    +4.51%           17.62             15.02           -7.39%    +16.47%
# 2    +4.50%           18.85             16.04           -7.24%    +17.35%
# 3    +4.23%           61.62             46.21          +36.57%    +44.02%
# 4    +4.21%           31.88             23.95          +36.21%    +42.61%
# ..      ...             ...               ...              ...        ...
# 70   +2.70%           24.36             21.34          +17.56%    +27.10%
# 71   +2.70%           24.36             21.34           +2.13%    +10.29%
# 72   +2.69%           26.57             22.72           +4.36%    +15.48%
# 73   +2.66%           61.07             55.48           -6.87%    +15.43%
# 74   +2.65%           59.37             54.00           -6.95%    +15.08%
#
#    52 Weeks Change%
# 0           +18.34%  11.1822.08
# 1           +17.01%  10.2720.18
# 2           +18.04%  10.9421.58
# 3            +8.90%  30.4768.81
# 4           -10.01%  15.8638.23
# ..              ...         ...
# 70           +9.18%  16.0225.38
# 71           +9.18%  16.0225.37
# 72          +13.40%  16.6928.27
# 73          +11.27%  38.2166.60
# 74          +10.91%  37.2264.76
#
# [75 rows x 11 columns]
