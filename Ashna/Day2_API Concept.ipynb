# %%
import requests



{
    "message": "https://images.dog.ceo/breeds/schipperke/n02104365_1166.jpg",
    "status": "success"
}
# Out:
# {'message': 'https://images.dog.ceo/breeds/schipperke/n02104365_1166.jpg',
#  'status': 'success'}

# %%
url = "https://dog.ceo/api/breeds/list/all"
url
# Out:
# 'https://dog.ceo/api/breeds/list/all'

# %%
response = requests.get(url)
data=response.json()

# %%
response = requests.get(url)
response.status_code
# Out:
# 200
