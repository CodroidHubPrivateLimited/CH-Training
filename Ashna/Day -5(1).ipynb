# %%
import pandas as pd
import numpy as np
np.random.seed(41)
n=1000
data = ({
    "Student_ID": np.arange(101,101+n),
    "Age": np.random.randint(18,24,size=n),
    "Marks": np.random.randint(40,100,size=n),
    "Department" :np.random.choice(["CSE","ECE","A&R","ME","AIML"],size=n)
})
df = pd.DataFrame(data)
df
# Out:
#      Student_ID  Age  Marks Department
# 0           101   18     92        CSE
# 1           102   21     56        A&R
# 2           103   22     65        A&R
# 3           104   20     46        CSE
# 4           105   18     80        CSE
# ..          ...  ...    ...        ...
# 995        1096   21     48        CSE
# 996        1097   21     76        A&R
# 997        1098   20     42        CSE
# 998        1099   21     62        ECE
# 999        1100   23     54         ME
#
# [1000 rows x 4 columns]

# %%
from numpy.random.mtrand import sample
# Introduce Missing values in Age, Marks and Department
for col in ["Age","Marks","Department"]:
    df.loc[df.sample(frac=0.5).index,col] = np.nan

df
# Out:
#      Student_ID   Age  Marks Department
# 0           101   NaN   92.0        CSE
# 1           102  21.0    NaN        A&R
# 2           103   NaN    NaN        A&R
# 3           104   NaN   46.0        NaN
# 4           105   NaN   80.0        NaN
# ..          ...   ...    ...        ...
# 995        1096   NaN   48.0        NaN
# 996        1097  21.0    NaN        A&R
# 997        1098   NaN   42.0        CSE
# 998        1099   NaN   62.0        ECE
# 999        1100   NaN    NaN        NaN
#
# [1000 rows x 4 columns]

# %%
# Duplicate Records/Rows
pd.concat([df,df.sample(50)], ignore_index=True)

df
# Out:
#      Student_ID   Age  Marks Department
# 0           101   NaN   92.0        CSE
# 1           102  21.0    NaN        A&R
# 2           103   NaN    NaN        A&R
# 3           104   NaN   46.0        NaN
# 4           105   NaN   80.0        NaN
# ..          ...   ...    ...        ...
# 995        1096   NaN   48.0        NaN
# 996        1097  21.0    NaN        A&R
# 997        1098   NaN   42.0        CSE
# 998        1099   NaN   62.0        ECE
# 999        1100   NaN    NaN        NaN
#
# [1000 rows x 4 columns]

# %%
df.loc[df.sample(10).index,"Age"]= np.nan

df
# Out:
#      Student_ID   Age  Marks Department
# 0           101   NaN   92.0        CSE
# 1           102  21.0    NaN        A&R
# 2           103   NaN    NaN        A&R
# 3           104   NaN   46.0        NaN
# 4           105   NaN   80.0        NaN
# ..          ...   ...    ...        ...
# 995        1096   NaN   48.0        NaN
# 996        1097  21.0    NaN        A&R
# 997        1098   NaN   42.0        CSE
# 998        1099   NaN   62.0        ECE
# 999        1100   NaN    NaN        NaN
#
# [1000 rows x 4 columns]

# %%
#Duplicate invalid ages
df.loc[df.sample(10).index,"Age"]=np.random.choice([-5, 240], size=10)

df
# Out:
#      Student_ID   Age  Marks Department
# 0           101   NaN   92.0        CSE
# 1           102  21.0    NaN        A&R
# 2           103   NaN    NaN        A&R
# 3           104   NaN   46.0        NaN
# 4           105   NaN   80.0        NaN
# ..          ...   ...    ...        ...
# 995        1096   NaN   48.0        NaN
# 996        1097  21.0    NaN        A&R
# 997        1098   NaN   42.0        CSE
# 998        1099   NaN   62.0        ECE
# 999        1100   NaN    NaN        NaN
#
# [1000 rows x 4 columns]

# %%
df.loc[df.sample(60).index,"Marks"]=np.nan
df
# Out:
#      Student_ID   Age  Marks Department
# 0           101   NaN   92.0        CSE
# 1           102  21.0    NaN        A&R
# 2           103   NaN    NaN        A&R
# 3           104   NaN   46.0        NaN
# 4           105   NaN   80.0        NaN
# ..          ...   ...    ...        ...
# 995        1096   NaN   48.0        NaN
# 996        1097  21.0    NaN        A&R
# 997        1098   NaN   42.0        CSE
# 998        1099   NaN    NaN        ECE
# 999        1100   NaN    NaN        NaN
#
# [1000 rows x 4 columns]

# %%
df.loc[df.sample(10).index,"Marks"] = np.random.choice([150, 240], size=10)

df
# Out:
#      Student_ID   Age  Marks Department
# 0           101   NaN   92.0        CSE
# 1           102  21.0    NaN        A&R
# 2           103   NaN    NaN        A&R
# 3           104   NaN   46.0        NaN
# 4           105   NaN   80.0        NaN
# ..          ...   ...    ...        ...
# 995        1096   NaN   48.0        NaN
# 996        1097  21.0    NaN        A&R
# 997        1098   NaN   42.0        CSE
# 998        1099   NaN    NaN        ECE
# 999        1100   NaN    NaN        NaN
#
# [1000 rows x 4 columns]

# %%
df = df.copy()
#Creating a copy of df so that original data doesnt get disturbed

# %%
df.columns =(
    df.columns
    .str.strip()   #Removing spacing from columns
    .str.lower()             #converting column hedings to lowercase
    .str.replace("_","")  #Removing spacing by.
)
df.columns
# Out:
# Index(['studentid', 'age', 'marks', 'department'], dtype='object')

# %%
#Enforcing Correct datatypes
df["age"]=pd.to_numeric(df["age"],errors="coerce")
df
# Out:
#      studentid   age  marks department
# 0          101   NaN   92.0        CSE
# 1          102  21.0    NaN        A&R
# 2          103   NaN    NaN        A&R
# 3          104   NaN   46.0        NaN
# 4          105   NaN   80.0        NaN
# ..         ...   ...    ...        ...
# 995       1096   NaN   48.0        NaN
# 996       1097  21.0    NaN        A&R
# 997       1098   NaN   42.0        CSE
# 998       1099   NaN    NaN        ECE
# 999       1100   NaN    NaN        NaN
#
# [1000 rows x 4 columns]

# %%
# Handling Missing Values using Mean, Median, Categorical

df["age"].fillna(df["age"].median(),inplace=True)
df
# Out:
# /tmp/ipython-input-2156785875.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["age"].fillna(df["age"].median(),inplace=True)
#      studentid   age  marks department
# 0          101  20.0   92.0        CSE
# 1          102  21.0    NaN        A&R
# 2          103  20.0    NaN        A&R
# 3          104  20.0   46.0        NaN
# 4          105  20.0   80.0        NaN
# ..         ...   ...    ...        ...
# 995       1096  20.0   48.0        NaN
# 996       1097  21.0    NaN        A&R
# 997       1098  20.0   42.0        CSE
# 998       1099  20.0    NaN        ECE
# 999       1100  20.0    NaN        NaN
#
# [1000 rows x 4 columns]

# %%
#Handle Duplicates
df.drop_duplicates(inplace=True)
df
# Out:
#      studentid   age  marks department
# 0          101  20.0   92.0        CSE
# 1          102  21.0    NaN        A&R
# 2          103  20.0    NaN        A&R
# 3          104  20.0   46.0        NaN
# 4          105  20.0   80.0        NaN
# ..         ...   ...    ...        ...
# 995       1096  20.0   48.0        NaN
# 996       1097  21.0    NaN        A&R
# 997       1098  20.0   42.0        CSE
# 998       1099  20.0    NaN        ECE
# 999       1100  20.0    NaN        NaN
#
# [1000 rows x 4 columns]

# %% [markdown]
# **Data Validations**

# %%
valid_department = ["CSE","AIML","A&R","ECE"]
df=df["department"].isin(valid_department)

# %%
df
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 995    False
# 996     True
# 997     True
# 998     True
# 999    False
# Name: department, Length: 1000, dtype: bool

# %%
df
# Out:
#      Student_ID  Age  Marks Department
# 0           101   18     92        CSE
# 1           102   21     56        A&R
# 2           103   22     65        A&R
# 3           104   20     46        CSE
# 4           105   18     80        CSE
# ..          ...  ...    ...        ...
# 995        1096   21     48        CSE
# 996        1097   21     76        A&R
# 997        1098   20     42        CSE
# 998        1099   21     62        ECE
# 999        1100   23     54         ME
#
# [1000 rows x 4 columns]

# %%
df=df[df["Age"].between(18,24)]
df
# Out:
#      Student_ID  Age  Marks Department
# 0           101   18     92        CSE
# 1           102   21     56        A&R
# 2           103   22     65        A&R
# 3           104   20     46        CSE
# 4           105   18     80        CSE
# ..          ...  ...    ...        ...
# 995        1096   21     48        CSE
# 996        1097   21     76        A&R
# 997        1098   20     42        CSE
# 998        1099   21     62        ECE
# 999        1100   23     54         ME
#
# [1000 rows x 4 columns]

# %%
df=df[df["Marks"].between(0,100)]
df
# Out:
#      Student_ID  Age  Marks Department
# 0           101   18     92        CSE
# 1           102   21     56        A&R
# 2           103   22     65        A&R
# 3           104   20     46        CSE
# 4           105   18     80        CSE
# ..          ...  ...    ...        ...
# 995        1096   21     48        CSE
# 996        1097   21     76        A&R
# 997        1098   20     42        CSE
# 998        1099   21     62        ECE
# 999        1100   23     54         ME
#
# [1000 rows x 4 columns]
